# %% [markdown]
# # <center>Fashion-MNIST - Multiclass Classification with a CNN using Keras</center>
# <!-- <center><img src="https://drive.google.com/uc?id=1zKjMLp3973vHUH9-K9mzfRhoRW3f7EpA"></center> -->
# <center><img src="https://s3-eu-central-1.amazonaws.com/zalando-wp-zalando-research-production/2017/08/fashion-mnist-sprite.png" width='640', height='350'></center>
#
# In this notebook, we will illustrate multi-class classification for the **Fashion-MNIST dataset** using a Keras based Convolution Neural Networks (CNN). We will develop a base model, which is progressively improved using L2 regularization as well as dropout regularization.  **We will be using Tensorflow's implementation of Keras in this workbook (i.e. all Keras classes are impored from `tensorflow.keras.*` packages)**

# %% [markdown]
# ### <font color='firebrick'>NOTE: This notebook can work on Google Colab as well as offline</font>
# * When running this notebook on Google Colab, please set `USE_COLAB=True` in cell below,  else set `USE_COLAB=False`.
# * `USE_COLAB=True` will setup access to Google Drive for the current user's login (assuming she has a Google ID).
#     * Your Google Drive gets mapped to `/content/drive/My Drive`, and your Notebooks get saved to `/content/drive/My Drive/Colab Notebooks/` folder in your Google Drive.
#     * Code will add `/content/drive/My Drive/Colab Notebooks/` folder to `system.path`. Save your custom Python code files `(*.py)` here, so they are automatically added to `system.path` and you can use them in your notebook. *
# * A `MODEL_STATES` global var is created to point to the _correct_ folder where the model's state (i.e. trained weights & biases) is stored to an `.h5` file.
#     * If `USE_COLAB=True`, `MODEL_STATES` maps to `/content/drive/My Drive/Colab Notebooks/model_states` folder on Google Drive.
#     * Else, `MODEL_STATES` maps to `./model_states` folder on your local disk (i.e a sub-folder of folder where notebook is saved)

# %%
USE_COLAB = True

import os

#@see: https://colab.research.google.com/drive/1srw_HFWQ2SMgmWIawucXfusGzrj1_U0q
if USE_COLAB:
    # Load the Drive helper and mount
    from google.colab import drive

    # This will prompt for authorization.
    gdrive_mount_point = '/content/drive/'
    drive.mount(gdrive_mount_point)
    grive_path = os.path.join(gdrive_mount_point, "My Drive/")
    print('Your Google Drive is mounted at ', grive_path)
    colab_notebooks_path = os.path.join(grive_path, "Colab Notebooks/keras")
    
    if os.path.exists(colab_notebooks_path):
        print('You Colab notebooks are available at ', colab_notebooks_path)
    
        # display list of files
        #!ls '/content/drive/My Drive/Colab Notebooks/'

        # append our Google Drive folder to module search 
        # **NOTE:** comment this line out if you are NOT running this notebook on Google Colab
        import sys
        #sys.path.append("/content/drive/My Drive/Colab Notebooks/")
        sys.path.append(colab_notebooks_path)
        print('NOTE: {} is appended to sys.path!'.format(colab_notebooks_path))
        # and test it
        import kr_helper_funcs as kru
        MODEL_SAVE_DIR = os.path.join(colab_notebooks_path, "model_states")
    else:
        raise IOError("Unable to mount Google Drive!")
else:
    MODEL_SAVE_DIR = os.path.join('.','model_states')
    
if not os.path.exists(MODEL_SAVE_DIR):
    os.mkdir(MODEL_SAVE_DIR)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/
# Your Google Drive is mounted at  /content/drive/My Drive/
# You Colab notebooks are available at  /content/drive/My Drive/Colab Notebooks/keras
# NOTE: /content/drive/My Drive/Colab Notebooks/keras is appended to sys.path!
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# ## About the Fashion-MNIST dataset.
# Fashion-MNIST can be used as drop-in replacement for the original MNIST dataset (of 10 categories of handwritten digits). It shares the same image size (28x28 graysacle) and has 60,000 training and 10,000 testing splits. However, unlike the 'simple' number images, the images from this dataset are a bit involved. So, our CNN network architecture will be different.
#
# Per [Zolando](https://github.com/zalandoresearch/fashion-mnist), the Fashion-MNIST dataset was created as a replacement for the MNIST dataset because:
# * **MNIST is too easy**. Convolutional nets can achieve 99.7% on MNIST. Classic machine learning algorithms can also achieve 97% easily.
# * **MNIST is overused**.
# * **MNIST cannot represent modern CV tasks**
# Take a look at the link above and read the various articles it references.
#
# We have 10 categories of output labels - unlike the MNIST dataset, where they were values for numbers, we have distinct types here.
#
# Label Description
# * 0 - T-shirt/top
# * 1 - Trouser
# * 2 - Pullover
# * 3 - Dress
# * 4 - Coat
# * 5 - Sandal
# * 6 - Shirt
# * 7 - Sneaker
# * 8 - Bag
# * 9 - Ankle boot
#
# Let's begin...

# %%
import os,random
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
print('Using Tensorflow version ', tf.__version__)
# %matplotlib inline

USING_TF2 = tf.__version__.startswith("2")

float_formatter = lambda x: '%.4f' % x
np.set_printoptions(formatter={'float_kind':float_formatter})
np.set_printoptions(threshold=np.inf, suppress=True, precision=4)

plt.style.use("seaborn")

# NOTE: It is important that you set a seed value to get same results in every run.
# Any number is Ok.
seed = 123
random.seed(seed)
np.random.seed(seed)
if USING_TF2:
    tf.random.set_seed(seed)
else:
    tf.set_random_seed(seed)

import warnings
warnings.filterwarnings('ignore')
# Out:
# Using Tensorflow version  2.2.0-rc3

# %% [markdown]
# ### Loading & Preprocessing the Dataset
#
# I am going to load the Fashion-MNIST dataset from the `keras.datasets` library. We'll use the `keras.datasets.fashion_mnist.load_data()` call. The dataset is downloaded the very first time you call it. The function conveniently returns two tuples of data & labels. The images are not normalized - this is something we will handle.

# %%
def load_and_preprocess_data(debug=False):
    
    from tensorflow.keras.datasets.fashion_mnist import load_data
    #from keras.utils import to_categorical

    (X_train, y_train), (X_test, y_test) = load_data()

    if debug:
        print('Before preprocessing:')
        print(' - X_train.shape = {}, y_train.shape = {}'.format(X_train.shape, y_train.shape))
        print(' - X_test.shape = {}, y_test.shape = {}'.format(X_test.shape, y_test.shape))

    # per Andrew Ng's advise in his Structured ML coure (on deeplearning.ai), the test 
    # & cross-validation datasets must come from the same distribution!
    # So, we are going to split X_test/y_test into cross-validation & test datasets.
    # We have 10,000 samples in X_test/y_test - we will assign 8,000 to X_val/y_val & the
    # remaining 2,000 to X_test/y_test (test dataset) AFTER randomly sorting the dataset

    # randomly sort X_test/y_test
    indexes = np.arange(X_test.shape[0])
    for _ in range(5): indexes = np.random.permutation(indexes)  # shuffle 5 times!
    X_test = X_test[indexes]
    y_test = y_test[indexes]
    
    # 'split' into cross-val & test sets (use 6000 records in cross-val set)    
    val_count = 8000
    X_val = X_test[:val_count]
    y_val = y_test[:val_count]
    X_test = X_test[val_count:]
    y_test = y_test[val_count:]

    # keep an non pre-processed copy of X_test/y_test for visualization
    test_images, test_labels = X_test.copy(), y_test.copy()

    # scale the images to between 0-1
    X_train = X_train.astype('float32') / 255.0
    X_val = X_val.astype('float32') / 255.0
    X_test = X_test.astype('float32') / 255.0

    # reshape the image arrays (make 2D arrays instead of 3D arrays)
    X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], X_train.shape[2], 1))
    X_val = np.reshape(X_val, (X_val.shape[0], X_val.shape[1], X_val.shape[2], 1))
    X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], X_test.shape[2], 1))

    if debug:
        print('After preprocessing:')
        print(' - X_train.shape = {}, y_train.shape = {}'.format(X_train.shape, y_train.shape))
        print(' - X_val.shape = {}, y_val.shape = {}'.format(X_val.shape, y_val.shape))
        print(' - X_test.shape = {}, y_test.shape = {}'.format(X_test.shape, y_test.shape))
        print(' - test_images.shape = {}, test_labels.shape = {}'.format(test_images.shape,
            test_labels.shape))

    return (X_train, y_train), (X_val, y_val), (X_test, y_test), (test_images, test_labels)

# %%
def display_sample(sample_images, sample_labels, sample_predictions=None, num_rows=5, num_cols=10,
                   plot_title=None, fig_size=None):
    """ display a random selection of images & corresponding labels, optionally with predictions
        The display is laid out in a grid of num_rows x num_col cells
        If sample_predictions are provided, then each cell's title displays the prediction 
        (if it matches actual) or actual/prediction if there is a mismatch
    """
    import seaborn as sns
    assert sample_images.shape[0] == num_rows * num_cols

    # a dict to help encode/decode the labels
    FASHION_LABELS = {
        0: 'T-shirt/top',
        1: 'Trouser',
        2: 'Pullover',
        3: 'Dress',
        4: 'Coat',
        5: 'Sandal',
        6: 'Shirt',
        7: 'Sneaker',
        8: 'Bag',
        9: 'Ankle boot',
    }

    with sns.axes_style("whitegrid"):
        sns.set_context("notebook", font_scale=1.1)
        sns.set_style({"font.sans-serif": ["Verdana", "Arial", "Calibri", "DejaVu Sans"]})

        f, ax = plt.subplots(num_rows, num_cols, figsize=((14, 9) if fig_size is None else fig_size),
            gridspec_kw={"wspace": 0.02, "hspace": 0.30}, squeeze=True)

        for r in range(num_rows):
            for c in range(num_cols):
                image_index = r * num_cols + c
                ax[r, c].axis("off")
                # show selected image
                ax[r, c].imshow(sample_images[image_index], cmap="Greys", interpolation="nearest")

                if sample_predictions is None:
                    # show the actual labels in the cell title
                    title = ax[r, c].set_title("%s" % FASHION_LABELS[sample_labels[image_index]])
                else:
                    # else check if prediction matches actual value
                    true_label = sample_labels[image_index]
                    pred_label = sample_predictions[image_index]
                    prediction_matches_true = (sample_labels[image_index] == sample_predictions[image_index])
                    if prediction_matches_true:
                        # if actual == prediction, cell title is prediction shown in green font
                        title = FASHION_LABELS[true_label]
                        title_color = 'g'
                    else:
                        # if actual != prediction, cell title is actua/prediction in red font
                        title = '%s/%s' % (FASHION_LABELS[true_label], FASHION_LABELS[pred_label])
                        title_color = 'r'
                    # display cell title
                    title = ax[r, c].set_title(title)
                    plt.setp(title, color=title_color)
        # set plot title, if one specified
        if plot_title is not None:
            f.suptitle(plot_title)

        plt.show()
        plt.close()

# %%
# load & pre-process our dataset
(X_train, y_train), (X_val, y_val), (X_test, y_test), (test_images, test_labels) = \
    load_and_preprocess_data(debug=True)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 8192/5148 [===============================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
# Before preprocessing:
#  - X_train.shape = (60000, 28, 28), y_train.shape = (60000,)
#  - X_test.shape = (10000, 28, 28), y_test.shape = (10000,)
# After preprocessing:
#  - X_train.shape = (60000, 28, 28, 1), y_train.shape = (60000,)
#  - X_val.shape = (8000, 28, 28, 1), y_val.shape = (8000,)
#  - X_test.shape = (2000, 28, 28, 1), y_test.shape = (2000,)
#  - test_images.shape = (2000, 28, 28), test_labels.shape = (2000,)

# %% [markdown]
# Notice the following:
# * **Before Pre-processing**:
#     * We have 60,000 images in the training set & 10,000 images in the test set.
#     * They have shapes of `(60000,28,28)` and `(10000,28,28)` respectively.
# * **After pre-processing**:
#     * The training dataset retains it's 60000 images
#     * The test dataset has been split into a cross-validation set (X_val/y_val) with 8000 samples and a test set (X_test/y_test) with 2000 samples
#     * We have reshaped all the feature (X's) datasets into 3D tensors
#
# Let us randomly select 50 images from the test dataset and see how they look - we will display the images in a 5x10 grid below.

# %%
sample_size = 50
rand_indexes = np.random.randint(0, len(X_test), sample_size)
sample_images = test_images[rand_indexes]
sample_labels = test_labels[rand_indexes]
display_sample(sample_images, sample_labels, plot_title='Sample of %d images' % sample_size)

# %% [markdown]
# ## Keras Model Development
#
# This section includes the following functions:
# * `train_and_evaluate_model()` - trains model on training dataset & evaluates performance on the cross-validation dataset. Saves model to a file name on disk (Google Drive if running in Colab or directory on disk)
# * `do_predictions()` - loads model state from disk and tests it on test dataset and plots predictions on a random sample of non-preprocessed data from the test set.

# %%
# Keras imports (from Tensorflow)
import tensorflow.keras.backend as K
from tensorflow.keras.layers import (Input, Conv2D, MaxPooling2D, Flatten, 
                                     Dense, Dropout, BatchNormalization)
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
import kr_helper_funcs as kru
print('Using Tensorflow\'s implementation of Keras version ', tf.keras.__version__)

K.clear_session()   # start afresh each time!!
# Out:
# Using Tensorflow's implementation of Keras version  2.3.0-tf

# %%
# some globals
IMAGE_HEIGHT, IMAGE_WIDTH, NUM_CHANNELS, NUM_CLASSES = 28, 28, 1, 10

# %%
# cross-train & evaluate model's performance
def train_and_evaluate_model(model, X_train, y_train, X_val, y_val, X_test, y_test,
                             num_epochs=25, batch_size=32, plot_title=None, metric='acccuracy',
                             callbacks=None, model_save_name=None):
    """
    cross train & evaluate model's performance on training, cross-val & test datasets
    @params:
        - X_train/y_train: pre-processed training datasets
        - X_val/y_val: pre-processed cross-validation datasets
        - X_test/y_test: pre-processed testing datasets
        - epochs (optional, default=25) - no of epochs for which training should be done
        - batch_size (optional, default=32) - the batch size to use for mini-batch gradient descent training
        - plot_title (optional, default=None) - plots loss vs epochs and accuracy vs epoch curves if assigned value
            other than None. Uses this assigned value as the plot's title
        - model_save_name (optional, default=None) - the file name to which the Keras model is to be saved to.
    """
    
    # train on X_train/y_train & cross-validate on X_val/y_val
    history = model.fit(X_train, y_train, epochs=num_epochs,
        batch_size=batch_size, validation_data=(X_val, y_val), callbacks=callbacks)
    
    kru.show_plots(history.history, metric=metric, plot_title=plot_title)

    # evaluate metrics
    print("\nEvaluating...", flush=True)
    print('Training data:', flush=True)
    loss, acc = model.evaluate(X_train, y_train, verbose=1)
    print("  Training : loss %.3f - acc %.3f" % (loss, acc))
    print('Cross-validation data:', flush=True)
    loss, acc = model.evaluate(X_val, y_val, verbose=1)
    print("  Cross-val: loss %.3f - acc %.3f" % (loss, acc))
    print('Test data:', flush=True)
    loss, acc = model.evaluate(X_test, y_test, verbose=1)
    print("  Testing  : loss %.3f - acc %.3f" % (loss, acc))
    
    if model_save_name is not None:
        print('Saving model...', flush=True)
        kru.save_model(model, model_save_name, MODEL_SAVE_DIR)

# %%
def do_predictions(model_save_name, X_test, y_test, test_images, test_labels, 
                   plot_title=None, use_tf_keras_impl=False):
    
    def test_model(model, X_test, y_test, test_images, test_labels, plot_title=None):
        print('Evaluating against test data...', flush=True)
        loss, acc = model.evaluate(X_test, y_test)
        print('  - Test data: loss %.3f - acc %.3f' % (loss, acc))

        print('Displaying sample predictions...', flush=True)
        # run predictions
        y_pred = model.predict(X_test)

        # test with 50 random images
        num_images = 50
        rand_indexes = np.random.randint(0, len(X_test), num_images)
        sample_images = test_images[rand_indexes]
        sample_labels = test_labels[rand_indexes]
        sample_predictions = np.argmax(y_pred[rand_indexes], axis=1)

        display_sample(sample_images, sample_labels, sample_predictions,
            num_rows=5, num_cols=10, plot_title=plot_title)
    
    # load the model from saved state (.hd5 archive)
    model = kru.load_model(model_save_name, MODEL_SAVE_DIR)
    
    test_model(model, X_test, y_test, test_images, test_labels, plot_title=plot_title)
    del model

# %% [markdown]
# ## Training Model
# In this section, we _cross-train_ various configurations of the model on `(X_train, y_train)` and `(X_val, y_val)` and record the performance. The model we will use is created in the `build_model()` function below. The following _configurations_ are trained and evaluated:
# >Configuration|
# >:---|
# >**Base Model** (no regularization)|
# >**Base Model + L2 Regularization**|
# >**Base Model + Dropout Regularization**|
# >**Base Model + L2 Regularization + Dropout Regularization**|
#
# You can see how the model's performance improves as overfitting reduces.

# %% [markdown]
# ### Training the _base_ model
# Training model without any regularization - no Batch Normalization, no L2 regularization and no Dropout regularization

# %%
def build_model():
    """
    builds the base Keras model, without any regularization
    """
    K.clear_session()
    
    model = Sequential([
        Conv2D(64, kernel_size=(3, 3), activation='relu', padding='same', 
               input_shape=(IMAGE_HEIGHT, IMAGE_WIDTH, NUM_CHANNELS)),
        BatchNormalization(),
        Conv2D(64, kernel_size=(3, 3), activation='relu'),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2, 2)),

        Conv2D(128, kernel_size=(3, 3), activation='relu', padding='same'),
        BatchNormalization(),
        Conv2D(128, kernel_size=(3, 3), activation='relu'),
        BatchNormalization(),        
        MaxPooling2D(pool_size=(2, 2)),
        
        Conv2D(256, kernel_size=(3, 3), activation='relu', padding='same'),
        BatchNormalization(),
        Conv2D(256, kernel_size=(3, 3), activation='relu'),
        BatchNormalization(),    
        MaxPooling2D(pool_size=(2, 2)),   
        
        Flatten(),
        
        Dense(1024, activation='relu'),
        
        Dense(512, activation='relu'),
        
        Dense(NUM_CLASSES, activation='softmax')
    ])
    
    adam = Adam(lr=0.0001, decay=1e-6)
    model.compile(optimizer=adam,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    return model

# %%
# build the base Keras model - no L2 regularization, no droput regularization
model = build_model()
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 64)        640
# _________________________________________________________________
# batch_normalization (BatchNo (None, 28, 28, 64)        256
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 26, 26, 64)        36928
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 26, 26, 64)        256
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 13, 13, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 13, 13, 128)       73856
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 13, 13, 128)       512
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 11, 11, 128)       147584
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 11, 11, 128)       512
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 128)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 5, 5, 256)         295168
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 5, 5, 256)         1024
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 3, 3, 256)         590080
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 3, 3, 256)         1024
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 1, 1, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              263168
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 1,940,938
# Trainable params: 1,939,146
# Non-trainable params: 1,792
# _________________________________________________________________
# None

# %%
model_name_base = 'kr_fashion_cnn_base'
plot_title_base = 'Keras Base Model'
train_and_evaluate_model(model, X_train, y_train, X_val, y_val, X_test, y_test, 
                         num_epochs=20, batch_size=64, metric='accuracy',
                         plot_title=plot_title_base, model_save_name=model_name_base) 
#del model
# Out:
# Epoch 1/20
# 938/938 [==============================] - 9s 9ms/step - loss: 0.4004 - accuracy: 0.8560 - val_loss: 0.3148 - val_accuracy: 0.8878
# Epoch 2/20
# 938/938 [==============================] - 9s 9ms/step - loss: 0.2454 - accuracy: 0.9108 - val_loss: 0.2905 - val_accuracy: 0.8914
# Epoch 3/20
# 938/938 [==============================] - 9s 9ms/step - loss: 0.1887 - accuracy: 0.9315 - val_loss: 0.2712 - val_accuracy: 0.9010
# Epoch 4/20
# 938/938 [==============================] - 9s 9ms/step - loss: 0.1488 - accuracy: 0.9453 - val_loss: 0.2719 - val_accuracy: 0.9084
# Epoch 5/20
# 938/938 [==============================] - 9s 9ms/step - loss: 0.1172 - accuracy: 0.9562 - val_loss: 0.2899 - val_accuracy: 0.9082
# Epoch 6/20
# 938/938 [==============================] - 9s 9ms/step - loss: 0.0928 - accuracy: 0.9656 - val_loss: 0.2890 - val_accuracy: 0.9120
# Epoch 7/20
# 938/938 [==============================] - 9s 9ms/step - loss: 0.0752 - accuracy: 0.9720 - val_loss: 0.2841 - val_accuracy: 0.9164
# Epoch 8/20
# 938/938 [==============================] - 9s 9ms/step - loss: 0.0612 - accuracy: 0.9770 - val_loss: 0.3219 - val_accuracy: 0.9059
# Epoch 9/20
# 938/938 [==============================] - 9s 9ms/step - loss: 0.0538 - accuracy: 0.9803 - val_loss: 0.3307 - val_accuracy: 0.9151
# Epoch 10/20
# 938/938 [==============================] - 9s 9ms/step - loss: 0.0439 - accuracy: 0.9839 - val_loss: 0.3571 - val_accuracy: 0.9070
# Epoch 11/20
# 938/938 [==============================] - 9s 9ms/step - loss: 0.0394 - accuracy: 0.9857 - val_loss: 0.3742 - val_accuracy: 0.9144
# Epoch 12/20
# 938/938 [==============================] - 9s 9ms/step - loss: 0.0351 - accuracy: 0.9876 - val_loss: 0.3813 - val_accuracy: 0.9149
# Epoch 13/20
# 938/938 [==============================] - 9s 9ms/step - loss: 0.0331 - accuracy: 0.9879 - val_loss: 0.3683 - val_accuracy: 0.9204
# Epoch 14/20
# 938/938 [==============================] - 9s 9ms/step - loss: 0.0291 - accuracy: 0.9894 - val_loss: 0.3891 - val_accuracy: 0.9131
# Epoch 15/20
# 938/938 [==============================] - 9s 9ms/step - loss: 0.0272 - accuracy: 0.9903 - val_loss: 0.4050 - val_accuracy: 0.9144
# Epoch 16/20
# 938/938 [==============================] - 9s 9ms/step - loss: 0.0268 - accuracy: 0.9904 - val_loss: 0.3812 - val_accuracy: 0.9193
# Epoch 17/20
# 938/938 [==============================] - 9s 9ms/step - loss: 0.0255 - accuracy: 0.9912 - val_loss: 0.3886 - val_accuracy: 0.9218
# Epoch 18/20
# 938/938 [==============================] - 9s 9ms/step - loss: 0.0184 - accuracy: 0.9939 - val_loss: 0.4575 - val_accuracy: 0.9147
# Epoch 19/20
# 938/938 [==============================] - 9s 9ms/step - loss: 0.0215 - accuracy: 0.9923 - val_loss: 0.4765 - val_accuracy: 0.9146
# Epoch 20/20
# 938/938 [==============================] - 9s 9ms/step - loss: 0.0198 - accuracy: 0.9933 - val_loss: 0.4619 - val_accuracy: 0.9162
# Evaluating...
# Training data:
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0257 - accuracy: 0.9921
#   Training : loss 0.026 - acc 0.992
# Cross-validation data:
# 250/250 [==============================] - 1s 3ms/step - loss: 0.4619 - accuracy: 0.9162
#   Cross-val: loss 0.462 - acc 0.916
# Test data:
# 63/63 [==============================] - 0s 3ms/step - loss: 0.4581 - accuracy: 0.9175
#   Testing  : loss 0.458 - acc 0.918
# Saving model...
# Saved model to file /content/drive/My Drive/Colab Notebooks/keras/model_states/kr_fashion_cnn_base.h5

# %%
kru.save_model(model, model_name_base, MODEL_SAVE_DIR)
del model
# Out:
# Saved model to file /content/drive/My Drive/Colab Notebooks/keras/model_states/kr_fashion_cnn_base.h5

# %% [markdown]
# #### Observation from training base model:
# See [this Colab Notebook](https://colab.research.google.com/drive/1brSHFOnPQTo0-9vQRC6oslZjAGRbzWuY) for _examples on inserting tables inside markdown cells_
# >Configuration | Training Acc | Cross-val Acc | Test Acc
# >:---|:---:|:---:|:---:|
# >**Base Model**|99-100%|91-92%|91-92%
#
# * Model is overfitting the training data - observe the large (~8%) difference between training & cross-validation accuracies
# * Cross-validation & test accuracies should be almost equal as data is drawn from same population - they are!
# * From the plots you can see that they curves start diverging from around the 5th epoch, suggesting that the model has started overfitting from this epoch itself. You could have stopped training after 5 epochs and got the best results (~95% training accuracy and 90% cross-val accuracy)
#
# Let's run some predictions against the `test` dataset, which the model has not _seen_ during training.
# * I expect to see the same `Test acc` value as seen in the output from training the model

# %%
do_predictions(model_name_base, X_test, y_test, test_images, test_labels, 
               plot_title=plot_title_base, use_tf_keras_impl=True)
# Out:
# Loaded Keras model from /content/drive/My Drive/Colab Notebooks/keras/model_states/kr_fashion_cnn_base.h5
# Evaluating against test data...
# 63/63 [==============================] - 0s 3ms/step - loss: 0.4581 - accuracy: 0.9175
#   - Test data: loss 0.458 - acc 0.918
# Displaying sample predictions...

# %% [markdown]
# ### Using L2 Regularization with Base Model
# In this section we will add L2 Regularization to the base model.
# * A L2 regularizer applies penalties on layer parameters (equal to the `L2 Norm` of weights) during optimization.
# * These penalties are _added to the loss function_ that the network _minimizes_. Thus higher weights/parameters tend to get penalized more, so we eventually end up with simpler models that overfit less.
# * L2 Regularization can be added to any Keras `Conv2D` or `Dense` layer by setting the `kernel_regularizer` parameter to an appropriate value. We use `kernel_regularizer = regularizers.l2(XXXX)`.
# * L2 regularization is applied if you set `use_l2_reg=True` in the `build_model()` function. The penalty applied can be changed by passing your value in the `l2_loss_lambda` parameter of `build_model()` function.
# * In an ideal situation, applying L2 regularization should reduce the gap between `training accuracy` and `cross-val accuracy`, without reducing `cross-cal accuracy` (it could increase!).

# %%
def build_model_l2(l2_loss_lambda):
    """
    Builds Keras model with L2 regularization applied to each Conv2D and Dense layers
    @params:
        - l2_loss_lambda: float, controls amount of regularization to apply
             (optional, default=None)
    """
    K.clear_session()
    
    l2 = None if l2_loss_lambda is None else regularizers.l2(l2_loss_lambda)
    if l2 is not None:
        print('Using L2 regularization - l2_loss_lambda = %.4f' % l2_loss_lambda)    
    
    model = Sequential([
        Conv2D(64, kernel_size=(3, 3), activation='relu', padding='same', kernel_regularizer=l2, 
               input_shape=(IMAGE_HEIGHT, IMAGE_WIDTH, NUM_CHANNELS)),
        BatchNormalization(),
        Conv2D(64, kernel_size=(3, 3), activation='relu', kernel_regularizer=l2),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2, 2)),

        Conv2D(128, kernel_size=(3, 3), activation='relu', padding='same', kernel_regularizer=l2),
        BatchNormalization(),
        Conv2D(128, kernel_size=(3, 3), activation='relu', kernel_regularizer=l2),
        BatchNormalization(),        
        MaxPooling2D(pool_size=(2, 2)),
        
        Conv2D(256, kernel_size=(3, 3), activation='relu', padding='same', kernel_regularizer=l2),
        BatchNormalization(),
        Conv2D(256, kernel_size=(3, 3), activation='relu', kernel_regularizer=l2),
        BatchNormalization(),    
        MaxPooling2D(pool_size=(2, 2)),   
        
        Flatten(),
        
        Dense(1024, activation='relu', kernel_regularizer=l2),
        
        Dense(512, activation='relu', kernel_regularizer=l2),
        
        Dense(NUM_CLASSES, activation='softmax')
    ])
    
    adam = Adam(lr=0.0001, decay=1e-6)
    model.compile(optimizer=adam,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    return model

# %%
l2_loss_lambda = 0.010
model = build_model_l2(l2_loss_lambda=l2_loss_lambda)
print(model.summary())
# Out:
# Using L2 regularization - l2_loss_lambda = 0.0100
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 64)        640
# _________________________________________________________________
# batch_normalization (BatchNo (None, 28, 28, 64)        256
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 26, 26, 64)        36928
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 26, 26, 64)        256
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 13, 13, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 13, 13, 128)       73856
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 13, 13, 128)       512
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 11, 11, 128)       147584
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 11, 11, 128)       512
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 128)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 5, 5, 256)         295168
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 5, 5, 256)         1024
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 3, 3, 256)         590080
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 3, 3, 256)         1024
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 1, 1, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              263168
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 1,940,938
# Trainable params: 1,939,146
# Non-trainable params: 1,792
# _________________________________________________________________
# None

# %%
model_name_l2 = 'kr_fashion_cnn_l2'
plot_title_l2 = 'Keras Model with L2 regularization = %.5f' % l2_loss_lambda
train_and_evaluate_model(model, X_train, y_train, X_val, y_val, X_test, y_test, 
                         num_epochs=30, batch_size=64, metric='accuracy',
                         plot_title=plot_title_l2, model_save_name=model_name_l2)
#del model
# Out:
# Epoch 1/30
# 938/938 [==============================] - 9s 10ms/step - loss: 10.5386 - accuracy: 0.8581 - val_loss: 5.5866 - val_accuracy: 0.8871
# Epoch 2/30
# 938/938 [==============================] - 9s 10ms/step - loss: 3.6201 - accuracy: 0.9059 - val_loss: 2.4151 - val_accuracy: 0.8830
# Epoch 3/30
# 938/938 [==============================] - 9s 10ms/step - loss: 1.7262 - accuracy: 0.9202 - val_loss: 1.3613 - val_accuracy: 0.8967
# Epoch 4/30
# 938/938 [==============================] - 9s 9ms/step - loss: 1.0653 - accuracy: 0.9275 - val_loss: 0.9369 - val_accuracy: 0.9178
# Epoch 5/30
# 938/938 [==============================] - 9s 10ms/step - loss: 0.7806 - accuracy: 0.9332 - val_loss: 0.7899 - val_accuracy: 0.9018
# Epoch 6/30
# 938/938 [==============================] - 9s 9ms/step - loss: 0.6305 - accuracy: 0.9399 - val_loss: 0.6662 - val_accuracy: 0.9097
# Epoch 7/30
# 938/938 [==============================] - 9s 9ms/step - loss: 0.5400 - accuracy: 0.9450 - val_loss: 0.5965 - val_accuracy: 0.9144
# Epoch 8/30
# 938/938 [==============================] - 9s 10ms/step - loss: 0.4802 - accuracy: 0.9498 - val_loss: 0.5987 - val_accuracy: 0.9040
# Epoch 9/30
# 938/938 [==============================] - 9s 9ms/step - loss: 0.4414 - accuracy: 0.9515 - val_loss: 0.5481 - val_accuracy: 0.9109
# Epoch 10/30
# 938/938 [==============================] - 9s 10ms/step - loss: 0.4059 - accuracy: 0.9579 - val_loss: 0.5065 - val_accuracy: 0.9199
# Epoch 11/30
# 938/938 [==============================] - 9s 9ms/step - loss: 0.3815 - accuracy: 0.9611 - val_loss: 0.5293 - val_accuracy: 0.9154
# Epoch 12/30
# 938/938 [==============================] - 9s 9ms/step - loss: 0.3593 - accuracy: 0.9642 - val_loss: 0.4909 - val_accuracy: 0.9197
# Epoch 13/30
# 938/938 [==============================] - 9s 9ms/step - loss: 0.3408 - accuracy: 0.9674 - val_loss: 0.5048 - val_accuracy: 0.9158
# Epoch 14/30
# 938/938 [==============================] - 9s 10ms/step - loss: 0.3310 - accuracy: 0.9683 - val_loss: 0.4803 - val_accuracy: 0.9246
# Epoch 15/30
# 938/938 [==============================] - 9s 10ms/step - loss: 0.3199 - accuracy: 0.9694 - val_loss: 0.4855 - val_accuracy: 0.9197
# Epoch 16/30
# 938/938 [==============================] - 9s 10ms/step - loss: 0.3107 - accuracy: 0.9720 - val_loss: 0.4996 - val_accuracy: 0.9086
# Epoch 17/30
# 938/938 [==============================] - 9s 10ms/step - loss: 0.3010 - accuracy: 0.9724 - val_loss: 0.4827 - val_accuracy: 0.9176
# Epoch 18/30
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2984 - accuracy: 0.9733 - val_loss: 0.4940 - val_accuracy: 0.9130
# Epoch 19/30
# 938/938 [==============================] - 9s 9ms/step - loss: 0.2905 - accuracy: 0.9753 - val_loss: 0.4745 - val_accuracy: 0.9180
# Epoch 20/30
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2795 - accuracy: 0.9773 - val_loss: 0.5232 - val_accuracy: 0.9099
# Epoch 21/30
# 938/938 [==============================] - 9s 9ms/step - loss: 0.2785 - accuracy: 0.9768 - val_loss: 0.5149 - val_accuracy: 0.9036
# Epoch 22/30
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2765 - accuracy: 0.9766 - val_loss: 0.4786 - val_accuracy: 0.9168
# Epoch 23/30
# 938/938 [==============================] - 9s 9ms/step - loss: 0.2697 - accuracy: 0.9789 - val_loss: 0.4915 - val_accuracy: 0.9131
# Epoch 24/30
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2691 - accuracy: 0.9777 - val_loss: 0.4626 - val_accuracy: 0.9243
# Epoch 25/30
# 938/938 [==============================] - 9s 9ms/step - loss: 0.2656 - accuracy: 0.9782 - val_loss: 0.4886 - val_accuracy: 0.9153
# Epoch 26/30
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2577 - accuracy: 0.9809 - val_loss: 0.5074 - val_accuracy: 0.9086
# Epoch 27/30
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2622 - accuracy: 0.9786 - val_loss: 0.5117 - val_accuracy: 0.9064
# Epoch 28/30
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2539 - accuracy: 0.9809 - val_loss: 0.4684 - val_accuracy: 0.9174
# Epoch 29/30
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2546 - accuracy: 0.9805 - val_loss: 0.4592 - val_accuracy: 0.9193
# Epoch 30/30
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2484 - accuracy: 0.9816 - val_loss: 0.4602 - val_accuracy: 0.9212
# Evaluating...
# Training data:
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2366 - accuracy: 0.9870
#   Training : loss 0.237 - acc 0.987
# Cross-validation data:
# 250/250 [==============================] - 1s 3ms/step - loss: 0.4602 - accuracy: 0.9212
#   Cross-val: loss 0.460 - acc 0.921
# Test data:
# 63/63 [==============================] - 0s 3ms/step - loss: 0.4500 - accuracy: 0.9250
#   Testing  : loss 0.450 - acc 0.925
# Saving model...
# Saved model to file /content/drive/My Drive/Colab Notebooks/keras/model_states/kr_fashion_cnn_l2.h5

# %%
kru.save_model(model, model_name_l2, MODEL_SAVE_DIR)
del model
# Out:
# Saved model to file /content/drive/My Drive/Colab Notebooks/keras/model_states/kr_fashion_cnn_l2.h5

# %% [markdown]
# #### Observations - model with L2 Regularization:
# See [this Colab Notebook](https://colab.research.google.com/drive/1brSHFOnPQTo0-9vQRC6oslZjAGRbzWuY) for _examples on inserting tables inside markdown cells_
# >Configuration | Training Acc | Cross-val Acc | Test Acc
# >:---|:---:|:---:|:---:|
# >**Base Model**|99-100%|91-92%|90-91%
# >**L2 Regularization**|98-99%|92-93%|92-93%
#
# * Overfitting has reduced - difference between train & cross-val accuracies is just ~5% (as compared to 9% in the base model)
# * Cross-validation & test accuracies should be almost equal as data is drawn from same population - they are!
# * Also a critical success factor was that these should not be much lesser than the base model's - they have in fact improved!
# * The plots are also much better - notice that the curves are following each other more closely than before - though they are digressing slightly.

# %%
do_predictions(model_name_l2, X_test, y_test, test_images, test_labels, 
               plot_title=plot_title_l2)
# Out:
# Loaded Keras model from /content/drive/My Drive/Colab Notebooks/keras/model_states/kr_fashion_cnn_l2.h5
# Evaluating against test data...
# 63/63 [==============================] - 0s 3ms/step - loss: 0.4500 - accuracy: 0.9250
#   - Test data: loss 0.450 - acc 0.925
# Displaying sample predictions...

# %% [markdown]
# ### Training the model with Dropout Regularization
# Another very effective regularization technique is **Dropout Regularization**. It works by randomly _dropping_ nodes in a layer _during training_ (you specify the percentage of nodes to be dropped). This give the model an 'impression' that a different network is being trained during each epoch, thereby achieving a regularization effect.

# %%
def build_model_do():
    
    model = Sequential([
        Conv2D(64, kernel_size=(3, 3), activation='relu', padding='same', 
               input_shape=(IMAGE_HEIGHT, IMAGE_WIDTH, NUM_CHANNELS)),
        BatchNormalization(),
        Conv2D(64, kernel_size=(3, 3), activation='relu'),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2, 2)),
        Dropout(0.20),

        Conv2D(128, kernel_size=(3, 3), activation='relu', padding='same'),
        BatchNormalization(),
        Conv2D(128, kernel_size=(3, 3), activation='relu'),
        BatchNormalization(),        
        MaxPooling2D(pool_size=(2, 2)),
        Dropout(0.30),        
        
        Conv2D(256, kernel_size=(3, 3), activation='relu', padding='same'),
        BatchNormalization(),
        Conv2D(256, kernel_size=(3, 3), activation='relu'),
        BatchNormalization(),    
        MaxPooling2D(pool_size=(2, 2)),
        Dropout(0.40),        
        
        Flatten(),
        
        Dense(1024, activation='relu'),
        Dropout(0.30),
        
        Dense(512, activation='relu'),
        Dropout(0.20),
        
        Dense(NUM_CLASSES, activation='softmax')
    ])
    
    adam = Adam(lr=0.0001, decay=1e-6)
    model.compile(optimizer=adam,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    return model

# %%
model = build_model_do()
print(model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 28, 28, 64)        640
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 28, 28, 64)        256
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 26, 26, 64)        36928
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 26, 26, 64)        256
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 13, 13, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 13, 13, 64)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 13, 13, 128)       73856
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 13, 13, 128)       512
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 11, 11, 128)       147584
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 11, 11, 128)       512
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 5, 5, 128)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 5, 5, 128)         0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 5, 5, 256)         295168
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 5, 5, 256)         1024
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 3, 3, 256)         590080
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 3, 3, 256)         1024
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 1, 1, 256)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1, 1, 256)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1024)              263168
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 1,940,938
# Trainable params: 1,939,146
# Non-trainable params: 1,792
# _________________________________________________________________
# None

# %%
model_name_do = 'kr_fashion_cnn_do'
plot_title_do = 'Keras Model with dropout regularization'
train_and_evaluate_model(model, X_train, y_train, X_val, y_val, X_test, y_test, 
                         num_epochs=30, batch_size=64, metric='accuracy',
                         plot_title=plot_title_do, model_save_name=model_name_do)
# Out:
# Epoch 1/30
# 938/938 [==============================] - 9s 10ms/step - loss: 0.7145 - accuracy: 0.7368 - val_loss: 0.4308 - val_accuracy: 0.8369
# Epoch 2/30
# 938/938 [==============================] - 9s 9ms/step - loss: 0.4230 - accuracy: 0.8465 - val_loss: 0.3489 - val_accuracy: 0.8729
# Epoch 3/30
# 938/938 [==============================] - 9s 9ms/step - loss: 0.3474 - accuracy: 0.8759 - val_loss: 0.2971 - val_accuracy: 0.8936
# Epoch 4/30
# 938/938 [==============================] - 9s 9ms/step - loss: 0.3073 - accuracy: 0.8884 - val_loss: 0.2842 - val_accuracy: 0.8941
# Epoch 5/30
# 938/938 [==============================] - 9s 9ms/step - loss: 0.2782 - accuracy: 0.8988 - val_loss: 0.2755 - val_accuracy: 0.8945
# Epoch 6/30
# 938/938 [==============================] - 9s 9ms/step - loss: 0.2553 - accuracy: 0.9069 - val_loss: 0.2386 - val_accuracy: 0.9110
# Epoch 7/30
# 938/938 [==============================] - 9s 9ms/step - loss: 0.2389 - accuracy: 0.9123 - val_loss: 0.2300 - val_accuracy: 0.9174
# Epoch 8/30
# 938/938 [==============================] - 9s 9ms/step - loss: 0.2221 - accuracy: 0.9191 - val_loss: 0.2239 - val_accuracy: 0.9195
# Epoch 9/30
# 938/938 [==============================] - 9s 9ms/step - loss: 0.2103 - accuracy: 0.9232 - val_loss: 0.2079 - val_accuracy: 0.9237
# Epoch 10/30
# 938/938 [==============================] - 9s 9ms/step - loss: 0.1990 - accuracy: 0.9260 - val_loss: 0.2077 - val_accuracy: 0.9247
# Epoch 11/30
# 938/938 [==============================] - 9s 9ms/step - loss: 0.1855 - accuracy: 0.9317 - val_loss: 0.2166 - val_accuracy: 0.9234
# Epoch 12/30
# 938/938 [==============================] - 9s 9ms/step - loss: 0.1787 - accuracy: 0.9345 - val_loss: 0.2019 - val_accuracy: 0.9285
# Epoch 13/30
# 938/938 [==============================] - 9s 9ms/step - loss: 0.1663 - accuracy: 0.9385 - val_loss: 0.2152 - val_accuracy: 0.9230
# Epoch 14/30
# 938/938 [==============================] - 9s 9ms/step - loss: 0.1580 - accuracy: 0.9421 - val_loss: 0.1979 - val_accuracy: 0.9308
# Epoch 15/30
# 938/938 [==============================] - 9s 9ms/step - loss: 0.1483 - accuracy: 0.9446 - val_loss: 0.2227 - val_accuracy: 0.9199
# Epoch 16/30
# 938/938 [==============================] - 9s 9ms/step - loss: 0.1464 - accuracy: 0.9457 - val_loss: 0.2051 - val_accuracy: 0.9283
# Epoch 17/30
# 938/938 [==============================] - 9s 9ms/step - loss: 0.1367 - accuracy: 0.9498 - val_loss: 0.1997 - val_accuracy: 0.9299
# Epoch 18/30
# 938/938 [==============================] - 9s 9ms/step - loss: 0.1303 - accuracy: 0.9510 - val_loss: 0.2014 - val_accuracy: 0.9308
# Epoch 19/30
# 938/938 [==============================] - 9s 10ms/step - loss: 0.1265 - accuracy: 0.9531 - val_loss: 0.2000 - val_accuracy: 0.9310
# Epoch 20/30
# 938/938 [==============================] - 9s 9ms/step - loss: 0.1203 - accuracy: 0.9548 - val_loss: 0.2066 - val_accuracy: 0.9312
# Epoch 21/30
# 938/938 [==============================] - 9s 9ms/step - loss: 0.1152 - accuracy: 0.9580 - val_loss: 0.2299 - val_accuracy: 0.9252
# Epoch 22/30
# 938/938 [==============================] - 9s 9ms/step - loss: 0.1063 - accuracy: 0.9602 - val_loss: 0.2074 - val_accuracy: 0.9323
# Epoch 23/30
# 938/938 [==============================] - 9s 9ms/step - loss: 0.1009 - accuracy: 0.9621 - val_loss: 0.2098 - val_accuracy: 0.9354
# Epoch 24/30
# 938/938 [==============================] - 9s 9ms/step - loss: 0.0997 - accuracy: 0.9624 - val_loss: 0.2298 - val_accuracy: 0.9300
# Epoch 25/30
# 938/938 [==============================] - 9s 9ms/step - loss: 0.0986 - accuracy: 0.9639 - val_loss: 0.2180 - val_accuracy: 0.9325
# Epoch 26/30
# 938/938 [==============================] - 9s 9ms/step - loss: 0.0910 - accuracy: 0.9655 - val_loss: 0.2100 - val_accuracy: 0.9344
# Epoch 27/30
# 938/938 [==============================] - 9s 9ms/step - loss: 0.0886 - accuracy: 0.9666 - val_loss: 0.2188 - val_accuracy: 0.9324
# Epoch 28/30
# 938/938 [==============================] - 9s 9ms/step - loss: 0.0849 - accuracy: 0.9683 - val_loss: 0.2226 - val_accuracy: 0.9336
# Epoch 29/30
# 938/938 [==============================] - 9s 9ms/step - loss: 0.0805 - accuracy: 0.9697 - val_loss: 0.2180 - val_accuracy: 0.9342
# Epoch 30/30
# 938/938 [==============================] - 9s 9ms/step - loss: 0.0766 - accuracy: 0.9708 - val_loss: 0.2353 - val_accuracy: 0.9348
# Evaluating...
# Training data:
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0300 - accuracy: 0.9912
#   Training : loss 0.030 - acc 0.991
# Cross-validation data:
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2353 - accuracy: 0.9348
#   Cross-val: loss 0.235 - acc 0.935
# Test data:
# 63/63 [==============================] - 0s 3ms/step - loss: 0.2129 - accuracy: 0.9345
#   Testing  : loss 0.213 - acc 0.934
# Saving model...
# Saved model to file /content/drive/My Drive/Colab Notebooks/keras/model_states/kr_fashion_cnn_do.h5

# %%
kru.save_model(model, model_name_do, MODEL_SAVE_DIR)
del model
# Out:
# Saved model to file /content/drive/My Drive/Colab Notebooks/keras/model_states/kr_fashion_cnn_do.h5

# %% [markdown]
# #### Observation - model with dropout regularization:
# See [this Colab Notebook](https://colab.research.google.com/drive/1brSHFOnPQTo0-9vQRC6oslZjAGRbzWuY) for _examples on inserting tables inside markdown cells_
# >Configuration | Training Acc | Cross-val Acc | Test Acc
# >:---|:---:|:---:|:---:|
# >**Base Model**|99-100%|91-92%|90-91%
# >**L2 Regularization**|98-99%|92-93%|92-93%
# >**Dropout Reg**|99-100%|93-94%|93-94%
#
# * Dropput regularization appears to be working better for this model - overfitting has reduced further, by another 1%.
# * Cross-validation & test accuracies have also improved by 1% or so.
# * The plots are diverging after 10 epochs.

# %%
do_predictions(model_name_do, X_test, y_test, test_images, test_labels, plot_title=plot_title_do)
# Out:
# Loaded Keras model from /content/drive/My Drive/Colab Notebooks/keras/model_states/kr_fashion_cnn_do.h5
# Evaluating against test data...
# 63/63 [==============================] - 0s 3ms/step - loss: 0.2129 - accuracy: 0.9345
#   - Test data: loss 0.213 - acc 0.934
# Displaying sample predictions...

# %% [markdown]
# ### Using Both L2 regularization and Dropout Regularization
# Let's try adding both L2 regularization as well as dropout regularization. We observed that we are getting rather good test accuracy with dropout regularization. So, I'll be applying just a _slight amount_ of L2 regularization. We'll use a very small value for `l2_loss_lambda`.

# %%
def build_model_l2_do(l2_loss_lambda=None):
    
    l2 = None if l2_loss_lambda is None else regularizers.l2(l2_loss_lambda)
    if l2 is not None:
        print('Using L2 regularization - l2_loss_lambda = %.7f' % l2_loss_lambda)
    
    model = Sequential([
        Conv2D(64, kernel_size=(3, 3), activation='relu', padding='same', kernel_regularizer=l2,
               input_shape=(IMAGE_HEIGHT, IMAGE_WIDTH, NUM_CHANNELS)),
        BatchNormalization(),
        Conv2D(64, kernel_size=(3, 3), activation='relu', kernel_regularizer=l2),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2, 2)),
        Dropout(0.20),

        Conv2D(128, kernel_size=(3, 3), activation='relu', padding='same', kernel_regularizer=l2),
        BatchNormalization(),
        Conv2D(128, kernel_size=(3, 3), activation='relu', kernel_regularizer=l2),
        BatchNormalization(),        
        MaxPooling2D(pool_size=(2, 2)),
        Dropout(0.30),        
        
        Conv2D(256, kernel_size=(3, 3), activation='relu', padding='same', kernel_regularizer=l2),
        BatchNormalization(),
        Conv2D(256, kernel_size=(3, 3), activation='relu', kernel_regularizer=l2),
        BatchNormalization(),    
        MaxPooling2D(pool_size=(2, 2)),
        Dropout(0.40),        
        
        Flatten(),
        
        Dense(1024, activation='relu', kernel_regularizer=l2),
        Dropout(0.30),
        
        Dense(512, activation='relu', kernel_regularizer=l2),
        Dropout(0.20),
        
        Dense(NUM_CLASSES, activation='softmax')
    ])
    
    adam = Adam(lr=0.0001, decay=1e-6)
    model.compile(optimizer=adam,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    return model

# %%
l2_loss_lambda_2 = 0.00020
model = build_model_l2_do(l2_loss_lambda=l2_loss_lambda_2)
print(model.summary())
# Out:
# Using L2 regularization - l2_loss_lambda = 0.0002000
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_24 (Conv2D)           (None, 28, 28, 64)        640
# _________________________________________________________________
# batch_normalization_24 (Batc (None, 28, 28, 64)        256
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 26, 26, 64)        36928
# _________________________________________________________________
# batch_normalization_25 (Batc (None, 26, 26, 64)        256
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 13, 13, 64)        0
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 13, 13, 64)        0
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 13, 13, 128)       73856
# _________________________________________________________________
# batch_normalization_26 (Batc (None, 13, 13, 128)       512
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 11, 11, 128)       147584
# _________________________________________________________________
# batch_normalization_27 (Batc (None, 11, 11, 128)       512
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 5, 5, 128)         0
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 5, 5, 128)         0
# _________________________________________________________________
# conv2d_28 (Conv2D)           (None, 5, 5, 256)         295168
# _________________________________________________________________
# batch_normalization_28 (Batc (None, 5, 5, 256)         1024
# _________________________________________________________________
# conv2d_29 (Conv2D)           (None, 3, 3, 256)         590080
# _________________________________________________________________
# batch_normalization_29 (Batc (None, 3, 3, 256)         1024
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 1, 1, 256)         0
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 1, 1, 256)         0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 256)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 1024)              263168
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_13 (Dense)             (None, 512)               524800
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_14 (Dense)             (None, 10)                5130
# =================================================================
# Total params: 1,940,938
# Trainable params: 1,939,146
# Non-trainable params: 1,792
# _________________________________________________________________
# None

# %%
# training for more epochs as we have greater regularization values...
model_name_do_l2 = 'kr_fashion_cnn_l2_do' 
plot_title_do_l2 = 'Keras Model with dropout & l2 regularization = %.7f' % l2_loss_lambda_2
train_and_evaluate_model(model, X_train, y_train, X_val, y_val, X_test, y_test, 
                         num_epochs=50, batch_size=64, metric='accuracy',
                         plot_title=plot_title_do_l2, model_save_name=model_name_do_l2)
# Out:
# Epoch 1/50
# 938/938 [==============================] - 9s 10ms/step - loss: 1.0722 - accuracy: 0.7371 - val_loss: 0.7896 - val_accuracy: 0.8363
# Epoch 2/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.7658 - accuracy: 0.8480 - val_loss: 0.7148 - val_accuracy: 0.8622
# Epoch 3/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.6846 - accuracy: 0.8758 - val_loss: 0.6416 - val_accuracy: 0.8899
# Epoch 4/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.6375 - accuracy: 0.8899 - val_loss: 0.6011 - val_accuracy: 0.8984
# Epoch 5/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.5956 - accuracy: 0.8990 - val_loss: 0.6427 - val_accuracy: 0.8723
# Epoch 6/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.5613 - accuracy: 0.9079 - val_loss: 0.5283 - val_accuracy: 0.9151
# Epoch 7/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.5249 - accuracy: 0.9153 - val_loss: 0.5134 - val_accuracy: 0.9150
# Epoch 8/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.4957 - accuracy: 0.9197 - val_loss: 0.4899 - val_accuracy: 0.9219
# Epoch 9/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.4728 - accuracy: 0.9236 - val_loss: 0.4770 - val_accuracy: 0.9218
# Epoch 10/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.4459 - accuracy: 0.9286 - val_loss: 0.4608 - val_accuracy: 0.9200
# Epoch 11/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.4227 - accuracy: 0.9330 - val_loss: 0.4375 - val_accuracy: 0.9262
# Epoch 12/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.4016 - accuracy: 0.9361 - val_loss: 0.4245 - val_accuracy: 0.9259
# Epoch 13/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.3829 - accuracy: 0.9395 - val_loss: 0.4127 - val_accuracy: 0.9281
# Epoch 14/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.3652 - accuracy: 0.9425 - val_loss: 0.4141 - val_accuracy: 0.9237
# Epoch 15/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.3489 - accuracy: 0.9449 - val_loss: 0.4081 - val_accuracy: 0.9246
# Epoch 16/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.3325 - accuracy: 0.9480 - val_loss: 0.3980 - val_accuracy: 0.9294
# Epoch 17/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.3202 - accuracy: 0.9501 - val_loss: 0.3804 - val_accuracy: 0.9317
# Epoch 18/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.3057 - accuracy: 0.9532 - val_loss: 0.3754 - val_accuracy: 0.9290
# Epoch 19/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2934 - accuracy: 0.9551 - val_loss: 0.3886 - val_accuracy: 0.9243
# Epoch 20/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2832 - accuracy: 0.9562 - val_loss: 0.3918 - val_accuracy: 0.9231
# Epoch 21/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2732 - accuracy: 0.9595 - val_loss: 0.3887 - val_accuracy: 0.9304
# Epoch 22/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2614 - accuracy: 0.9604 - val_loss: 0.3730 - val_accuracy: 0.9301
# Epoch 23/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2525 - accuracy: 0.9627 - val_loss: 0.3566 - val_accuracy: 0.9359
# Epoch 24/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2442 - accuracy: 0.9643 - val_loss: 0.3668 - val_accuracy: 0.9319
# Epoch 25/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2362 - accuracy: 0.9661 - val_loss: 0.3633 - val_accuracy: 0.9305
# Epoch 26/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2306 - accuracy: 0.9676 - val_loss: 0.3454 - val_accuracy: 0.9360
# Epoch 27/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2228 - accuracy: 0.9681 - val_loss: 0.3501 - val_accuracy: 0.9354
# Epoch 28/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2165 - accuracy: 0.9701 - val_loss: 0.3579 - val_accuracy: 0.9340
# Epoch 29/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2087 - accuracy: 0.9728 - val_loss: 0.3383 - val_accuracy: 0.9361
# Epoch 30/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2061 - accuracy: 0.9729 - val_loss: 0.3475 - val_accuracy: 0.9362
# Epoch 31/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2002 - accuracy: 0.9737 - val_loss: 0.3675 - val_accuracy: 0.9339
# Epoch 32/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.1952 - accuracy: 0.9749 - val_loss: 0.3778 - val_accuracy: 0.9295
# Epoch 33/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.1930 - accuracy: 0.9752 - val_loss: 0.3484 - val_accuracy: 0.9396
# Epoch 34/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.1889 - accuracy: 0.9773 - val_loss: 0.3426 - val_accuracy: 0.9369
# Epoch 35/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.1847 - accuracy: 0.9776 - val_loss: 0.3481 - val_accuracy: 0.9373
# Epoch 36/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.1812 - accuracy: 0.9780 - val_loss: 0.3475 - val_accuracy: 0.9361
# Epoch 37/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.1783 - accuracy: 0.9783 - val_loss: 0.3626 - val_accuracy: 0.9359
# Epoch 38/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.1747 - accuracy: 0.9799 - val_loss: 0.3418 - val_accuracy: 0.9362
# Epoch 39/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.1723 - accuracy: 0.9807 - val_loss: 0.3578 - val_accuracy: 0.9361
# Epoch 40/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.1673 - accuracy: 0.9814 - val_loss: 0.3727 - val_accuracy: 0.9352
# Epoch 41/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.1673 - accuracy: 0.9808 - val_loss: 0.3541 - val_accuracy: 0.9380
# Epoch 42/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.1639 - accuracy: 0.9823 - val_loss: 0.3816 - val_accuracy: 0.9315
# Epoch 43/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.1609 - accuracy: 0.9826 - val_loss: 0.3411 - val_accuracy: 0.9390
# Epoch 44/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.1590 - accuracy: 0.9837 - val_loss: 0.3728 - val_accuracy: 0.9364
# Epoch 45/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.1590 - accuracy: 0.9825 - val_loss: 0.3610 - val_accuracy: 0.9392
# Epoch 46/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.1553 - accuracy: 0.9839 - val_loss: 0.3735 - val_accuracy: 0.9356
# Epoch 47/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.1561 - accuracy: 0.9832 - val_loss: 0.3752 - val_accuracy: 0.9385
# Epoch 48/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.1528 - accuracy: 0.9849 - val_loss: 0.3545 - val_accuracy: 0.9383
# Epoch 49/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.1504 - accuracy: 0.9850 - val_loss: 0.3554 - val_accuracy: 0.9388
# Epoch 50/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.1520 - accuracy: 0.9846 - val_loss: 0.3565 - val_accuracy: 0.9413
# Evaluating...
# Training data:
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1152 - accuracy: 0.9984
#   Training : loss 0.115 - acc 0.998
# Cross-validation data:
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3565 - accuracy: 0.9413
#   Cross-val: loss 0.356 - acc 0.941
# Test data:
# 63/63 [==============================] - 0s 3ms/step - loss: 0.3611 - accuracy: 0.9395
#   Testing  : loss 0.361 - acc 0.939
# Saving model...
# Saved model to file /content/drive/My Drive/Colab Notebooks/keras/model_states/kr_fashion_cnn_l2_do.h5

# %%
kru.save_model(model, model_name_do_l2, MODEL_SAVE_DIR)
del model
# Out:
# Saved model to file /content/drive/My Drive/Colab Notebooks/keras/model_states/kr_fashion_cnn_l2_do.h5

# %% [markdown]
# #### Observation - model with both L2 and Dropout regularization.
# See [this Colab Notebook](https://colab.research.google.com/drive/1brSHFOnPQTo0-9vQRC6oslZjAGRbzWuY) for _examples on inserting tables inside markdown cells_
# >Configuration | Training Acc | Cross-val Acc | Test Acc
# >:---|:---:|:---:|:---:|
# >**Base Model**|99-100%|91-92%|90-91%
# >**L2 Regularization**|98-99%|92-93%|92-93%
# >**Dropout Reg**|99-100%|93-94%|93-94%
# >**Both L2 & Dropout Reg**|99-100%|94-95%|94-95%
#
# * This is slightly better than the model with just L2 or just dropout regularization - we are getting a slightly better test accuracy, with the overfitting beging in the same range as before.

# %%
do_predictions(model_name_do_l2, X_test, y_test, test_images, test_labels, plot_title=plot_title_do_l2)
# Out:
# Loaded Keras model from /content/drive/My Drive/Colab Notebooks/keras/model_states/kr_fashion_cnn_l2_do.h5
# Evaluating against test data...
# 63/63 [==============================] - 0s 3ms/step - loss: 0.3611 - accuracy: 0.9395
#   - Test data: loss 0.361 - acc 0.939
# Displaying sample predictions...

# %% [markdown]
# ### Using Image Augmentation
#
# One of the main reasons for model overfitting that we are trying to fit a complex model to limited training data. Keras comes to the rescue by providing `Image Augmentation` technique that let's us artifically increase the amount and variety of training data that we feed to the model. This way, the model learns more intricate patterns and is able to generalize better to data it has not seen. In this section we will implement Image Augmentation on the model that used both L2 as well as Dropout Regularization before.

# %%
def train_and_evaluate_model_aug(model, X_train, y_train, X_val, y_val, X_test, y_test,
                                 num_epochs=100, batch_size=32, 
                                 plot_title=None, metric='accuracy',
                                 learning_rate_scheduler=None,
                                 callbacks=None, model_save_name=None):
    from tensorflow.keras.preprocessing.image import ImageDataGenerator

    # NOTE: our datasets have already been scaled 
    train_datagen = ImageDataGenerator( 
        rotation_range=10,        # randomly rotate between 0-rotation_range angle
        width_shift_range=0.2,    # randomly shift horizontally by this much
        height_shift_range=0.2,   # randomly shift vertically by this much
        shear_range=0.2,          # randomly shear by this much
        zoom_range=0.2,           # randomly zoom (80% - 120%)
        horizontal_flip=True,
        fill_mode='nearest'       # fill any pixels lost in xform with nearest
    )

    val_datagen = ImageDataGenerator()
    test_datagen = ImageDataGenerator()

    #train_datagen.fit(X_train)

    # fit the data generator on training data & validate on
    num_train_batches = len(X_train) // batch_size
    num_train_batches += (0 if len(X_train) % batch_size == 0 else 1)     
    num_val_batches = len(X_val) // batch_size
    num_val_batches += (0 if len(X_val) % batch_size == 0 else 1)     
    num_test_batches = len(X_test) // batch_size
    num_test_batches += (0 if len(X_test) % batch_size == 0 else 1)    
    
    train_generator = train_datagen.flow(X_train, y_train, 
                                         batch_size=batch_size,
                                         seed=123)
    val_generator = train_datagen.flow(X_val, y_val, 
                                         batch_size=batch_size,
                                         seed=123)
    test_generator = test_datagen.flow(X_test, y_test, 
                                       batch_size=batch_size,
                                       seed=123)

    callback = None if learning_rate_scheduler is None else [learning_rate_scheduler]

    history = model.fit_generator(train_generator,
                                  steps_per_epoch = num_train_batches, 
                                  epochs = num_epochs,
                                  validation_data = val_generator,
                                  callbacks=callback,
                                  validation_steps = num_val_batches)
    
    kru.show_plots(history.history, metric=metric, plot_title=plot_title)

    # evaluate metrics
    print("\nEvaluating...", flush=True)
    print('Training data:', flush=True)
    loss, acc = model.evaluate_generator(train_generator, 
                                         steps=num_train_batches,
                                         verbose=1)
    print("  Training : loss %.3f - acc %.3f" % (loss, acc))
    print('Cross-validation data:', flush=True)
    loss, acc = model.evaluate_generator(val_generator, 
                                         steps=num_val_batches,
                                         verbose=1)
    print("  Cross-val: loss %.3f - acc %.3f" % (loss, acc))    
    print('Test data:', flush=True)
    loss, acc = model.evaluate_generator(test_generator, 
                                         steps=num_test_batches,
                                         verbose=1)
    print("  Testing  : loss %.3f - acc %.3f" % (loss, acc))
    
    if model_save_name is not None:
        print('Saving model...', flush=True)
        kru.save_model(model, model_save_name, MODEL_SAVE_DIR)

# %%
def build_model_l2_do_aug(l2_loss_lambda=None):

    K.clear_session()
    
    l2 = None if l2_loss_lambda is None else regularizers.l2(l2_loss_lambda)
    if l2 is not None:
        print('Using L2 regularization - l2_loss_lambda = %.7f' % l2_loss_lambda)
    
    model = Sequential([
        Conv2D(64, kernel_size=(3, 3), activation='relu', padding='same', kernel_regularizer=l2,
               input_shape=(IMAGE_HEIGHT, IMAGE_WIDTH, NUM_CHANNELS)),
        BatchNormalization(),
        Conv2D(64, kernel_size=(3, 3), activation='relu', kernel_regularizer=l2),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2, 2)),
        Dropout(0.20),

        Conv2D(128, kernel_size=(3, 3), activation='relu', padding='same', kernel_regularizer=l2),
        BatchNormalization(),
        Conv2D(128, kernel_size=(3, 3), activation='relu', kernel_regularizer=l2),
        BatchNormalization(),        
        MaxPooling2D(pool_size=(2, 2)),
        Dropout(0.30),        
        
        Conv2D(256, kernel_size=(3, 3), activation='relu', padding='same', kernel_regularizer=l2),
        BatchNormalization(),
        Conv2D(256, kernel_size=(3, 3), activation='relu', kernel_regularizer=l2),
        BatchNormalization(),    
        MaxPooling2D(pool_size=(2, 2)),
        Dropout(0.40),        
        
        Flatten(),
        
        Dense(1024, activation='relu', kernel_regularizer=l2),
        Dropout(0.30),
        
        Dense(512, activation='relu', kernel_regularizer=l2),
        Dropout(0.20),
        
        Dense(NUM_CLASSES, activation='softmax')
    ])
    
    adam = Adam(lr=0.0001, decay=1e-6)
    model.compile(optimizer=adam,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    return model

# %%
l2_loss_lambda_2 = 0.00020
model = build_model_l2_do_aug(l2_loss_lambda=l2_loss_lambda_2)
print(model.summary())
# Out:
# Using L2 regularization - l2_loss_lambda = 0.0002000
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 64)        640
# _________________________________________________________________
# batch_normalization (BatchNo (None, 28, 28, 64)        256
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 26, 26, 64)        36928
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 26, 26, 64)        256
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 13, 13, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 13, 13, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 13, 13, 128)       73856
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 13, 13, 128)       512
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 11, 11, 128)       147584
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 11, 11, 128)       512
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 128)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 5, 5, 128)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 5, 5, 256)         295168
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 5, 5, 256)         1024
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 3, 3, 256)         590080
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 3, 3, 256)         1024
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 1, 1, 256)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1, 1, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              263168
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 1,940,938
# Trainable params: 1,939,146
# Non-trainable params: 1,792
# _________________________________________________________________
# None

# %%
from tensorflow.keras.callbacks import LearningRateScheduler

model_name_aug = 'kr_fashion_cnn_l2_do_aug' 
plot_title_aug = 'Keras Model with image augmentation' 

def schedule_lr(epoch):
    if epoch < 150:
        return 0.001
    else:
        return 0.001 * tf.math.exp(0.1 * (10 - epoch))

lr_scheduler = LearningRateScheduler(schedule_lr)

train_and_evaluate_model_aug(model, X_train, y_train, X_val, y_val, X_test, y_test, 
                             num_epochs=200, batch_size=64, metric='accuracy',
                             #learning_rate_scheduler=lr_scheduler,
                             plot_title=plot_title_aug)
# Out:
# WARNING:tensorflow:From <ipython-input-11-ce4da1a27cd4>:49: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/200
# 938/938 [==============================] - 21s 22ms/step - loss: 1.5241 - accuracy: 0.5714 - val_loss: 1.1269 - val_accuracy: 0.7051
# Epoch 2/200
# 938/938 [==============================] - 20s 22ms/step - loss: 1.0969 - accuracy: 0.7207 - val_loss: 0.9844 - val_accuracy: 0.7646
# Epoch 3/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.9773 - accuracy: 0.7645 - val_loss: 0.8771 - val_accuracy: 0.8029
# Epoch 4/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.8960 - accuracy: 0.7943 - val_loss: 0.8150 - val_accuracy: 0.8195
# Epoch 5/200
# 938/938 [==============================] - 20s 22ms/step - loss: 0.8411 - accuracy: 0.8097 - val_loss: 0.8202 - val_accuracy: 0.8101
# Epoch 6/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.7958 - accuracy: 0.8222 - val_loss: 0.7514 - val_accuracy: 0.8319
# Epoch 7/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.7611 - accuracy: 0.8321 - val_loss: 0.7165 - val_accuracy: 0.8447
# Epoch 8/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.7267 - accuracy: 0.8400 - val_loss: 0.6707 - val_accuracy: 0.8541
# Epoch 9/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.6986 - accuracy: 0.8474 - val_loss: 0.7297 - val_accuracy: 0.8307
# Epoch 10/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.6712 - accuracy: 0.8513 - val_loss: 0.6273 - val_accuracy: 0.8677
# Epoch 11/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.6466 - accuracy: 0.8571 - val_loss: 0.6292 - val_accuracy: 0.8641
# Epoch 12/200
# 938/938 [==============================] - 20s 22ms/step - loss: 0.6251 - accuracy: 0.8609 - val_loss: 0.5947 - val_accuracy: 0.8716
# Epoch 13/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.6047 - accuracy: 0.8638 - val_loss: 0.5748 - val_accuracy: 0.8708
# Epoch 14/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.5902 - accuracy: 0.8669 - val_loss: 0.5506 - val_accuracy: 0.8774
# Epoch 15/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.5685 - accuracy: 0.8706 - val_loss: 0.5461 - val_accuracy: 0.8767
# Epoch 16/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.5539 - accuracy: 0.8731 - val_loss: 0.5201 - val_accuracy: 0.8844
# Epoch 17/200
# 938/938 [==============================] - 20s 22ms/step - loss: 0.5376 - accuracy: 0.8760 - val_loss: 0.5156 - val_accuracy: 0.8779
# Epoch 18/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.5252 - accuracy: 0.8779 - val_loss: 0.5094 - val_accuracy: 0.8781
# Epoch 19/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.5172 - accuracy: 0.8785 - val_loss: 0.4762 - val_accuracy: 0.8919
# Epoch 20/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.5029 - accuracy: 0.8806 - val_loss: 0.4774 - val_accuracy: 0.8904
# Epoch 21/200
# 938/938 [==============================] - 20s 22ms/step - loss: 0.4911 - accuracy: 0.8842 - val_loss: 0.4631 - val_accuracy: 0.8921
# Epoch 22/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.4797 - accuracy: 0.8874 - val_loss: 0.4650 - val_accuracy: 0.8885
# Epoch 23/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.4725 - accuracy: 0.8867 - val_loss: 0.4486 - val_accuracy: 0.8932
# Epoch 24/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.4638 - accuracy: 0.8884 - val_loss: 0.4551 - val_accuracy: 0.8882
# Epoch 25/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.4535 - accuracy: 0.8907 - val_loss: 0.4330 - val_accuracy: 0.8949
# Epoch 26/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.4441 - accuracy: 0.8932 - val_loss: 0.4515 - val_accuracy: 0.8857
# Epoch 27/200
# 938/938 [==============================] - 20s 22ms/step - loss: 0.4365 - accuracy: 0.8928 - val_loss: 0.4059 - val_accuracy: 0.9024
# Epoch 28/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.4317 - accuracy: 0.8927 - val_loss: 0.4092 - val_accuracy: 0.8988
# Epoch 29/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.4255 - accuracy: 0.8959 - val_loss: 0.4122 - val_accuracy: 0.8946
# Epoch 30/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.4223 - accuracy: 0.8949 - val_loss: 0.4007 - val_accuracy: 0.9034
# Epoch 31/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.4091 - accuracy: 0.8997 - val_loss: 0.4137 - val_accuracy: 0.8951
# Epoch 32/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.4054 - accuracy: 0.8986 - val_loss: 0.4144 - val_accuracy: 0.8949
# Epoch 33/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.4010 - accuracy: 0.8995 - val_loss: 0.3854 - val_accuracy: 0.9031
# Epoch 34/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.3961 - accuracy: 0.9005 - val_loss: 0.4059 - val_accuracy: 0.8956
# Epoch 35/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.3918 - accuracy: 0.9007 - val_loss: 0.3797 - val_accuracy: 0.9057
# Epoch 36/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.3890 - accuracy: 0.9006 - val_loss: 0.3826 - val_accuracy: 0.9004
# Epoch 37/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.3865 - accuracy: 0.9009 - val_loss: 0.3938 - val_accuracy: 0.9004
# Epoch 38/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.3782 - accuracy: 0.9034 - val_loss: 0.3647 - val_accuracy: 0.9079
# Epoch 39/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.3752 - accuracy: 0.9048 - val_loss: 0.3686 - val_accuracy: 0.9093
# Epoch 40/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.3735 - accuracy: 0.9042 - val_loss: 0.3948 - val_accuracy: 0.8991
# Epoch 41/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.3690 - accuracy: 0.9057 - val_loss: 0.3651 - val_accuracy: 0.9054
# Epoch 42/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.3671 - accuracy: 0.9057 - val_loss: 0.3524 - val_accuracy: 0.9107
# Epoch 43/200
# 938/938 [==============================] - 20s 22ms/step - loss: 0.3604 - accuracy: 0.9081 - val_loss: 0.3533 - val_accuracy: 0.9114
# Epoch 44/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.3633 - accuracy: 0.9066 - val_loss: 0.3808 - val_accuracy: 0.8991
# Epoch 45/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.3574 - accuracy: 0.9087 - val_loss: 0.3566 - val_accuracy: 0.9099
# Epoch 46/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.3550 - accuracy: 0.9091 - val_loss: 0.3653 - val_accuracy: 0.9076
# Epoch 47/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.3532 - accuracy: 0.9097 - val_loss: 0.3448 - val_accuracy: 0.9091
# Epoch 48/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.3476 - accuracy: 0.9113 - val_loss: 0.3536 - val_accuracy: 0.9087
# Epoch 49/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.3455 - accuracy: 0.9117 - val_loss: 0.3352 - val_accuracy: 0.9137
# Epoch 50/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.3452 - accuracy: 0.9114 - val_loss: 0.3481 - val_accuracy: 0.9105
# Epoch 51/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.3421 - accuracy: 0.9124 - val_loss: 0.3501 - val_accuracy: 0.9071
# Epoch 52/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.3386 - accuracy: 0.9125 - val_loss: 0.3488 - val_accuracy: 0.9082
# Epoch 53/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.3385 - accuracy: 0.9129 - val_loss: 0.3563 - val_accuracy: 0.9069
# Epoch 54/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.3365 - accuracy: 0.9122 - val_loss: 0.3395 - val_accuracy: 0.9111
# Epoch 55/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.3364 - accuracy: 0.9131 - val_loss: 0.3443 - val_accuracy: 0.9079
# Epoch 56/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.3302 - accuracy: 0.9148 - val_loss: 0.3364 - val_accuracy: 0.9124
# Epoch 57/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.3304 - accuracy: 0.9146 - val_loss: 0.3432 - val_accuracy: 0.9062
# Epoch 58/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.3292 - accuracy: 0.9142 - val_loss: 0.3225 - val_accuracy: 0.9194
# Epoch 59/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.3257 - accuracy: 0.9161 - val_loss: 0.3367 - val_accuracy: 0.9158
# Epoch 60/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.3260 - accuracy: 0.9164 - val_loss: 0.3168 - val_accuracy: 0.9196
# Epoch 61/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.3208 - accuracy: 0.9173 - val_loss: 0.3325 - val_accuracy: 0.9120
# Epoch 62/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.3210 - accuracy: 0.9172 - val_loss: 0.3240 - val_accuracy: 0.9172
# Epoch 63/200
# 938/938 [==============================] - 19s 21ms/step - loss: 0.3222 - accuracy: 0.9161 - val_loss: 0.3340 - val_accuracy: 0.9147
# Epoch 64/200
# 938/938 [==============================] - 19s 21ms/step - loss: 0.3185 - accuracy: 0.9168 - val_loss: 0.3170 - val_accuracy: 0.9174
# Epoch 65/200
# 938/938 [==============================] - 19s 21ms/step - loss: 0.3184 - accuracy: 0.9172 - val_loss: 0.3311 - val_accuracy: 0.9129
# Epoch 66/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.3155 - accuracy: 0.9172 - val_loss: 0.3078 - val_accuracy: 0.9189
# Epoch 67/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.3167 - accuracy: 0.9170 - val_loss: 0.3202 - val_accuracy: 0.9166
# Epoch 68/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.3141 - accuracy: 0.9183 - val_loss: 0.3229 - val_accuracy: 0.9141
# Epoch 69/200
# 938/938 [==============================] - 19s 21ms/step - loss: 0.3142 - accuracy: 0.9180 - val_loss: 0.3271 - val_accuracy: 0.9125
# Epoch 70/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.3122 - accuracy: 0.9198 - val_loss: 0.3191 - val_accuracy: 0.9140
# Epoch 71/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.3082 - accuracy: 0.9198 - val_loss: 0.3168 - val_accuracy: 0.9220
# Epoch 72/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.3062 - accuracy: 0.9208 - val_loss: 0.3251 - val_accuracy: 0.9153
# Epoch 73/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.3074 - accuracy: 0.9202 - val_loss: 0.3145 - val_accuracy: 0.9200
# Epoch 74/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.3048 - accuracy: 0.9205 - val_loss: 0.3159 - val_accuracy: 0.9129
# Epoch 75/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.3083 - accuracy: 0.9191 - val_loss: 0.3178 - val_accuracy: 0.9159
# Epoch 76/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.3062 - accuracy: 0.9204 - val_loss: 0.3360 - val_accuracy: 0.9084
# Epoch 77/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.3040 - accuracy: 0.9214 - val_loss: 0.3043 - val_accuracy: 0.9214
# Epoch 78/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.3022 - accuracy: 0.9205 - val_loss: 0.3198 - val_accuracy: 0.9134
# Epoch 79/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.3015 - accuracy: 0.9202 - val_loss: 0.3207 - val_accuracy: 0.9162
# Epoch 80/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.2995 - accuracy: 0.9228 - val_loss: 0.3102 - val_accuracy: 0.9204
# Epoch 81/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.3007 - accuracy: 0.9222 - val_loss: 0.3207 - val_accuracy: 0.9164
# Epoch 82/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.2991 - accuracy: 0.9227 - val_loss: 0.3036 - val_accuracy: 0.9218
# Epoch 83/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.2978 - accuracy: 0.9229 - val_loss: 0.3039 - val_accuracy: 0.9196
# Epoch 84/200
# 938/938 [==============================] - 19s 21ms/step - loss: 0.2983 - accuracy: 0.9233 - val_loss: 0.3038 - val_accuracy: 0.9216
# Epoch 85/200
# 938/938 [==============================] - 19s 21ms/step - loss: 0.2969 - accuracy: 0.9230 - val_loss: 0.3075 - val_accuracy: 0.9212
# Epoch 86/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.2938 - accuracy: 0.9240 - val_loss: 0.3041 - val_accuracy: 0.9204
# Epoch 87/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.2956 - accuracy: 0.9241 - val_loss: 0.3192 - val_accuracy: 0.9172
# Epoch 88/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.2980 - accuracy: 0.9221 - val_loss: 0.3131 - val_accuracy: 0.9186
# Epoch 89/200
# 938/938 [==============================] - 19s 21ms/step - loss: 0.2918 - accuracy: 0.9240 - val_loss: 0.3064 - val_accuracy: 0.9219
# Epoch 90/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.2920 - accuracy: 0.9242 - val_loss: 0.3198 - val_accuracy: 0.9168
# Epoch 91/200
# 938/938 [==============================] - 19s 21ms/step - loss: 0.2923 - accuracy: 0.9243 - val_loss: 0.3027 - val_accuracy: 0.9239
# Epoch 92/200
# 938/938 [==============================] - 19s 21ms/step - loss: 0.2938 - accuracy: 0.9243 - val_loss: 0.3085 - val_accuracy: 0.9186
# Epoch 93/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.2902 - accuracy: 0.9244 - val_loss: 0.3137 - val_accuracy: 0.9199
# Epoch 94/200
# 938/938 [==============================] - 19s 21ms/step - loss: 0.2905 - accuracy: 0.9240 - val_loss: 0.3098 - val_accuracy: 0.9178
# Epoch 95/200
# 938/938 [==============================] - 19s 21ms/step - loss: 0.2880 - accuracy: 0.9256 - val_loss: 0.2935 - val_accuracy: 0.9280
# Epoch 96/200
# 938/938 [==============================] - 19s 21ms/step - loss: 0.2897 - accuracy: 0.9258 - val_loss: 0.3012 - val_accuracy: 0.9249
# Epoch 97/200
# 938/938 [==============================] - 19s 21ms/step - loss: 0.2890 - accuracy: 0.9259 - val_loss: 0.3092 - val_accuracy: 0.9187
# Epoch 98/200
# 938/938 [==============================] - 19s 21ms/step - loss: 0.2873 - accuracy: 0.9261 - val_loss: 0.2979 - val_accuracy: 0.9234
# Epoch 99/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.2877 - accuracy: 0.9259 - val_loss: 0.3028 - val_accuracy: 0.9230
# Epoch 100/200
# 938/938 [==============================] - 19s 21ms/step - loss: 0.2878 - accuracy: 0.9256 - val_loss: 0.2995 - val_accuracy: 0.9225
# Epoch 101/200
# 938/938 [==============================] - 19s 21ms/step - loss: 0.2865 - accuracy: 0.9260 - val_loss: 0.3037 - val_accuracy: 0.9184
# Epoch 102/200
# 938/938 [==============================] - 19s 21ms/step - loss: 0.2835 - accuracy: 0.9278 - val_loss: 0.2959 - val_accuracy: 0.9237
# Epoch 103/200
# 938/938 [==============================] - 19s 21ms/step - loss: 0.2849 - accuracy: 0.9256 - val_loss: 0.2940 - val_accuracy: 0.9234
# Epoch 104/200
# 938/938 [==============================] - 19s 21ms/step - loss: 0.2824 - accuracy: 0.9276 - val_loss: 0.3119 - val_accuracy: 0.9191
# Epoch 105/200
# 938/938 [==============================] - 19s 20ms/step - loss: 0.2812 - accuracy: 0.9274 - val_loss: 0.3020 - val_accuracy: 0.9235
# Epoch 106/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.2807 - accuracy: 0.9281 - val_loss: 0.3068 - val_accuracy: 0.9175
# Epoch 107/200
# 938/938 [==============================] - 19s 21ms/step - loss: 0.2812 - accuracy: 0.9285 - val_loss: 0.2951 - val_accuracy: 0.9256
# Epoch 108/200
# 938/938 [==============================] - 19s 21ms/step - loss: 0.2819 - accuracy: 0.9270 - val_loss: 0.2907 - val_accuracy: 0.9250
# Epoch 109/200
# 938/938 [==============================] - 19s 21ms/step - loss: 0.2801 - accuracy: 0.9281 - val_loss: 0.3071 - val_accuracy: 0.9180
# Epoch 110/200
# 938/938 [==============================] - 19s 21ms/step - loss: 0.2809 - accuracy: 0.9270 - val_loss: 0.3023 - val_accuracy: 0.9239
# Epoch 111/200
# 938/938 [==============================] - 19s 21ms/step - loss: 0.2755 - accuracy: 0.9303 - val_loss: 0.3044 - val_accuracy: 0.9206
# Epoch 112/200
# 938/938 [==============================] - 19s 21ms/step - loss: 0.2787 - accuracy: 0.9281 - val_loss: 0.2872 - val_accuracy: 0.9270
# Epoch 113/200
# 938/938 [==============================] - 19s 21ms/step - loss: 0.2767 - accuracy: 0.9292 - val_loss: 0.2904 - val_accuracy: 0.9250
# Epoch 114/200
# 938/938 [==============================] - 19s 21ms/step - loss: 0.2796 - accuracy: 0.9282 - val_loss: 0.2955 - val_accuracy: 0.9237
# Epoch 115/200
# 938/938 [==============================] - 19s 21ms/step - loss: 0.2758 - accuracy: 0.9297 - val_loss: 0.2933 - val_accuracy: 0.9225
# Epoch 116/200
# 938/938 [==============================] - 19s 21ms/step - loss: 0.2750 - accuracy: 0.9306 - val_loss: 0.3047 - val_accuracy: 0.9190
# Epoch 117/200
# 938/938 [==============================] - 19s 21ms/step - loss: 0.2755 - accuracy: 0.9294 - val_loss: 0.2950 - val_accuracy: 0.9250
# Epoch 118/200
# 938/938 [==============================] - 19s 21ms/step - loss: 0.2766 - accuracy: 0.9280 - val_loss: 0.3067 - val_accuracy: 0.9184
# Epoch 119/200
# 938/938 [==============================] - 19s 21ms/step - loss: 0.2734 - accuracy: 0.9291 - val_loss: 0.2962 - val_accuracy: 0.9184
# Epoch 120/200
# 938/938 [==============================] - 19s 21ms/step - loss: 0.2727 - accuracy: 0.9311 - val_loss: 0.2882 - val_accuracy: 0.9201
# Epoch 121/200
# 938/938 [==============================] - 19s 21ms/step - loss: 0.2731 - accuracy: 0.9312 - val_loss: 0.3003 - val_accuracy: 0.9222
# Epoch 122/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.2747 - accuracy: 0.9297 - val_loss: 0.2947 - val_accuracy: 0.9225
# Epoch 123/200
# 938/938 [==============================] - 19s 21ms/step - loss: 0.2702 - accuracy: 0.9317 - val_loss: 0.2976 - val_accuracy: 0.9209
# Epoch 124/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.2708 - accuracy: 0.9308 - val_loss: 0.3030 - val_accuracy: 0.9225
# Epoch 125/200
# 938/938 [==============================] - 19s 21ms/step - loss: 0.2716 - accuracy: 0.9317 - val_loss: 0.2988 - val_accuracy: 0.9236
# Epoch 126/200
# 938/938 [==============================] - 19s 21ms/step - loss: 0.2714 - accuracy: 0.9314 - val_loss: 0.3021 - val_accuracy: 0.9206
# Epoch 127/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.2744 - accuracy: 0.9294 - val_loss: 0.3011 - val_accuracy: 0.9190
# Epoch 128/200
# 938/938 [==============================] - 20s 22ms/step - loss: 0.2725 - accuracy: 0.9306 - val_loss: 0.2815 - val_accuracy: 0.9300
# Epoch 129/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.2683 - accuracy: 0.9321 - val_loss: 0.2909 - val_accuracy: 0.9230
# Epoch 130/200
# 938/938 [==============================] - 19s 21ms/step - loss: 0.2688 - accuracy: 0.9327 - val_loss: 0.2878 - val_accuracy: 0.9273
# Epoch 131/200
# 938/938 [==============================] - 19s 21ms/step - loss: 0.2672 - accuracy: 0.9318 - val_loss: 0.2973 - val_accuracy: 0.9220
# Epoch 132/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.2698 - accuracy: 0.9319 - val_loss: 0.2935 - val_accuracy: 0.9245
# Epoch 133/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.2704 - accuracy: 0.9313 - val_loss: 0.2863 - val_accuracy: 0.9250
# Epoch 134/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.2673 - accuracy: 0.9324 - val_loss: 0.3045 - val_accuracy: 0.9215
# Epoch 135/200
# 938/938 [==============================] - 21s 22ms/step - loss: 0.2669 - accuracy: 0.9329 - val_loss: 0.2844 - val_accuracy: 0.9254
# Epoch 136/200
# 938/938 [==============================] - 21s 22ms/step - loss: 0.2682 - accuracy: 0.9317 - val_loss: 0.3012 - val_accuracy: 0.9239
# Epoch 137/200
# 938/938 [==============================] - 20s 22ms/step - loss: 0.2683 - accuracy: 0.9319 - val_loss: 0.2819 - val_accuracy: 0.9283
# Epoch 138/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.2666 - accuracy: 0.9325 - val_loss: 0.2915 - val_accuracy: 0.9246
# Epoch 139/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.2651 - accuracy: 0.9331 - val_loss: 0.2960 - val_accuracy: 0.9234
# Epoch 140/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.2655 - accuracy: 0.9329 - val_loss: 0.2796 - val_accuracy: 0.9279
# Epoch 141/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.2637 - accuracy: 0.9339 - val_loss: 0.2927 - val_accuracy: 0.9249
# Epoch 142/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.2654 - accuracy: 0.9332 - val_loss: 0.2858 - val_accuracy: 0.9246
# Epoch 143/200
# 938/938 [==============================] - 19s 21ms/step - loss: 0.2654 - accuracy: 0.9330 - val_loss: 0.2872 - val_accuracy: 0.9252
# Epoch 144/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.2641 - accuracy: 0.9330 - val_loss: 0.2933 - val_accuracy: 0.9215
# Epoch 145/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.2636 - accuracy: 0.9337 - val_loss: 0.2876 - val_accuracy: 0.9239
# Epoch 146/200
# 938/938 [==============================] - 19s 21ms/step - loss: 0.2613 - accuracy: 0.9345 - val_loss: 0.2802 - val_accuracy: 0.9277
# Epoch 147/200
# 938/938 [==============================] - 19s 21ms/step - loss: 0.2628 - accuracy: 0.9341 - val_loss: 0.2886 - val_accuracy: 0.9247
# Epoch 148/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.2635 - accuracy: 0.9336 - val_loss: 0.2862 - val_accuracy: 0.9279
# Epoch 149/200
# 938/938 [==============================] - 19s 21ms/step - loss: 0.2631 - accuracy: 0.9326 - val_loss: 0.2902 - val_accuracy: 0.9270
# Epoch 150/200
# 938/938 [==============================] - 19s 21ms/step - loss: 0.2599 - accuracy: 0.9338 - val_loss: 0.2899 - val_accuracy: 0.9215
# Epoch 151/200
# 938/938 [==============================] - 19s 21ms/step - loss: 0.2616 - accuracy: 0.9336 - val_loss: 0.3139 - val_accuracy: 0.9189
# Epoch 152/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.2631 - accuracy: 0.9340 - val_loss: 0.2969 - val_accuracy: 0.9205
# Epoch 153/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.2606 - accuracy: 0.9341 - val_loss: 0.3032 - val_accuracy: 0.9159
# Epoch 154/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.2609 - accuracy: 0.9333 - val_loss: 0.2758 - val_accuracy: 0.9309
# Epoch 155/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.2616 - accuracy: 0.9342 - val_loss: 0.2848 - val_accuracy: 0.9277
# Epoch 156/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.2582 - accuracy: 0.9350 - val_loss: 0.2734 - val_accuracy: 0.9285
# Epoch 157/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.2600 - accuracy: 0.9345 - val_loss: 0.2783 - val_accuracy: 0.9275
# Epoch 158/200
# 938/938 [==============================] - 19s 21ms/step - loss: 0.2594 - accuracy: 0.9339 - val_loss: 0.2952 - val_accuracy: 0.9214
# Epoch 159/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.2595 - accuracy: 0.9340 - val_loss: 0.2896 - val_accuracy: 0.9262
# Epoch 160/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.2596 - accuracy: 0.9348 - val_loss: 0.2878 - val_accuracy: 0.9252
# Epoch 161/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.2578 - accuracy: 0.9357 - val_loss: 0.2891 - val_accuracy: 0.9229
# Epoch 162/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.2582 - accuracy: 0.9352 - val_loss: 0.2742 - val_accuracy: 0.9290
# Epoch 163/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.2578 - accuracy: 0.9349 - val_loss: 0.2979 - val_accuracy: 0.9210
# Epoch 164/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.2599 - accuracy: 0.9349 - val_loss: 0.3018 - val_accuracy: 0.9230
# Epoch 165/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.2556 - accuracy: 0.9353 - val_loss: 0.2809 - val_accuracy: 0.9283
# Epoch 166/200
# 938/938 [==============================] - 19s 21ms/step - loss: 0.2576 - accuracy: 0.9338 - val_loss: 0.2736 - val_accuracy: 0.9302
# Epoch 167/200
# 938/938 [==============================] - 19s 21ms/step - loss: 0.2572 - accuracy: 0.9362 - val_loss: 0.2795 - val_accuracy: 0.9254
# Epoch 168/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.2585 - accuracy: 0.9348 - val_loss: 0.2967 - val_accuracy: 0.9236
# Epoch 169/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.2565 - accuracy: 0.9363 - val_loss: 0.2877 - val_accuracy: 0.9255
# Epoch 170/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.2554 - accuracy: 0.9360 - val_loss: 0.2843 - val_accuracy: 0.9268
# Epoch 171/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.2551 - accuracy: 0.9359 - val_loss: 0.2889 - val_accuracy: 0.9249
# Epoch 172/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.2548 - accuracy: 0.9369 - val_loss: 0.2827 - val_accuracy: 0.9270
# Epoch 173/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.2566 - accuracy: 0.9348 - val_loss: 0.2876 - val_accuracy: 0.9243
# Epoch 174/200
# 938/938 [==============================] - 19s 21ms/step - loss: 0.2517 - accuracy: 0.9372 - val_loss: 0.2926 - val_accuracy: 0.9259
# Epoch 175/200
# 938/938 [==============================] - 19s 21ms/step - loss: 0.2552 - accuracy: 0.9362 - val_loss: 0.2827 - val_accuracy: 0.9269
# Epoch 176/200
# 938/938 [==============================] - 19s 21ms/step - loss: 0.2533 - accuracy: 0.9362 - val_loss: 0.2806 - val_accuracy: 0.9290
# Epoch 177/200
# 938/938 [==============================] - 19s 21ms/step - loss: 0.2529 - accuracy: 0.9368 - val_loss: 0.3002 - val_accuracy: 0.9204
# Epoch 178/200
# 938/938 [==============================] - 19s 21ms/step - loss: 0.2550 - accuracy: 0.9377 - val_loss: 0.2745 - val_accuracy: 0.9314
# Epoch 179/200
# 938/938 [==============================] - 19s 21ms/step - loss: 0.2533 - accuracy: 0.9364 - val_loss: 0.2800 - val_accuracy: 0.9274
# Epoch 180/200
# 938/938 [==============================] - 19s 21ms/step - loss: 0.2534 - accuracy: 0.9370 - val_loss: 0.2933 - val_accuracy: 0.9269
# Epoch 181/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.2538 - accuracy: 0.9365 - val_loss: 0.2798 - val_accuracy: 0.9290
# Epoch 182/200
# 938/938 [==============================] - 19s 21ms/step - loss: 0.2527 - accuracy: 0.9360 - val_loss: 0.2979 - val_accuracy: 0.9230
# Epoch 183/200
# 938/938 [==============================] - 19s 21ms/step - loss: 0.2533 - accuracy: 0.9379 - val_loss: 0.2868 - val_accuracy: 0.9274
# Epoch 184/200
# 938/938 [==============================] - 19s 21ms/step - loss: 0.2535 - accuracy: 0.9369 - val_loss: 0.2983 - val_accuracy: 0.9237
# Epoch 185/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.2542 - accuracy: 0.9363 - val_loss: 0.2856 - val_accuracy: 0.9249
# Epoch 186/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.2504 - accuracy: 0.9367 - val_loss: 0.2742 - val_accuracy: 0.9290
# Epoch 187/200
# 938/938 [==============================] - 19s 21ms/step - loss: 0.2515 - accuracy: 0.9365 - val_loss: 0.2901 - val_accuracy: 0.9256
# Epoch 188/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.2511 - accuracy: 0.9367 - val_loss: 0.2831 - val_accuracy: 0.9264
# Epoch 189/200
# 938/938 [==============================] - 20s 22ms/step - loss: 0.2524 - accuracy: 0.9375 - val_loss: 0.2833 - val_accuracy: 0.9264
# Epoch 190/200
# 938/938 [==============================] - 20s 22ms/step - loss: 0.2531 - accuracy: 0.9362 - val_loss: 0.2860 - val_accuracy: 0.9229
# Epoch 191/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.2503 - accuracy: 0.9374 - val_loss: 0.2709 - val_accuracy: 0.9315
# Epoch 192/200
# 938/938 [==============================] - 20s 22ms/step - loss: 0.2550 - accuracy: 0.9373 - val_loss: 0.2812 - val_accuracy: 0.9276
# Epoch 193/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.2495 - accuracy: 0.9388 - val_loss: 0.2796 - val_accuracy: 0.9264
# Epoch 194/200
# 938/938 [==============================] - 19s 21ms/step - loss: 0.2488 - accuracy: 0.9379 - val_loss: 0.2908 - val_accuracy: 0.9226
# Epoch 195/200
# 938/938 [==============================] - 19s 21ms/step - loss: 0.2500 - accuracy: 0.9374 - val_loss: 0.2813 - val_accuracy: 0.9290
# Epoch 196/200
# 938/938 [==============================] - 19s 21ms/step - loss: 0.2468 - accuracy: 0.9388 - val_loss: 0.2920 - val_accuracy: 0.9254
# Epoch 197/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.2464 - accuracy: 0.9395 - val_loss: 0.2862 - val_accuracy: 0.9295
# Epoch 198/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.2483 - accuracy: 0.9386 - val_loss: 0.2834 - val_accuracy: 0.9269
# Epoch 199/200
# 938/938 [==============================] - 20s 21ms/step - loss: 0.2481 - accuracy: 0.9380 - val_loss: 0.2889 - val_accuracy: 0.9269
# Epoch 200/200
# 938/938 [==============================] - 19s 21ms/step - loss: 0.2466 - accuracy: 0.9387 - val_loss: 0.2956 - val_accuracy: 0.9251
# Evaluating...
# Training data:
# WARNING:tensorflow:From <ipython-input-11-ce4da1a27cd4>:58: Model.evaluate_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.evaluate, which supports generators.
# 938/938 [==============================] - 15s 17ms/step - loss: 0.2140 - accuracy: 0.9512
#   Training : loss 0.214 - acc 0.951
# Cross-validation data:
# 125/125 [==============================] - 3s 21ms/step - loss: 0.2937 - accuracy: 0.9218
#   Cross-val: loss 0.294 - acc 0.922
# Test data:
# 32/32 [==============================] - 0s 5ms/step - loss: 0.3087 - accuracy: 0.9260
#   Testing  : loss 0.309 - acc 0.926

# %%
kru.save_model(model, model_name_aug, MODEL_SAVE_DIR)
del model
# Out:
# Saved model to file /content/drive/My Drive/Colab Notebooks/keras/model_states/kr_fashion_cnn_l2_do_aug.h5

# %% [markdown]
# #### Observation - model with Image Augmentation
# See [this Colab Notebook](https://colab.research.google.com/drive/1brSHFOnPQTo0-9vQRC6oslZjAGRbzWuY) for _examples on inserting tables inside markdown cells_
# >Configuration | Training Acc | Cross-val Acc | Test Acc
# >:---|:---:|:---:|:---:|
# >**Base Model**|99-100%|91-92%|90-91%
# >**L2 Regularization**|98-99%|92-93%|92-93%
# >**Dropout Reg**|99-100%|93-94%|93-94%
# >**Both L2 & Dropout Reg**|99-100%|93-94%|94-95%
# >**With Image Aug**|95-96%|92-93%|92-93%
#
# * Notice that the cross-validation plots are tracking the training plots (both loss and accuracy) - there is some divergence, but very little.
# * We observe a 3% difference between training and cross-validation accuracy, which indicates that we have some overfitting, but not much.
# * Extrapolating the loss and accuracy curves, it appears that they will diverge further if we train for more epochs. At the 100th epoch divergence is ~2%

# %%
do_predictions(model_name_aug, X_test, y_test, test_images, test_labels, 
               plot_title=plot_title_aug)
# Out:
# Loaded Keras model from /content/drive/My Drive/Colab Notebooks/keras/model_states/kr_fashion_cnn_l2_do_aug.h5
# Evaluating against test data...
# 63/63 [==============================] - 0s 3ms/step - loss: 0.3128 - accuracy: 0.9260
#   - Test data: loss 0.313 - acc 0.926
# Displaying sample predictions...

# %% [markdown]
# ## Summary
# * In this workbook we created a CNN with Keras to classify the Fashion-MNIST dataset.
# * Since the images are more complex than our digits images, the model was more complex than the MNIST Digits model
# * The base model overfit the training data significantly (~8%), but we were able to reduce this by implementing regularization techniques like L2 regularization and dropout regularization
# * Finally, we implemented Image Augmentation, where we observed that our cross-validation curves tracked the training curves for most of the iterations. We did not see significant degredation of performance viz-a-viz the regularized versions without Image Augmentation.
# # <center> - - END - - </center>
