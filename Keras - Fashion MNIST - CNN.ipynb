# %% [markdown]
# # <center>Fashion-MNIST - Multiclass Classification with a CNN using Keras</center>
# <!-- <center><img src="https://drive.google.com/uc?id=1zKjMLp3973vHUH9-K9mzfRhoRW3f7EpA"></center> -->
# <center><img src="https://s3-eu-central-1.amazonaws.com/zalando-wp-zalando-research-production/2017/08/fashion-mnist-sprite.png" width='640', height='350'></center>
#
# In this notebook, we will illustrate multi-class classification for the **Fashion-MNIST dataset** using a Keras based Convolution Neural Networks (CNN). We will develop a base model, which is progressively improved using L2 regularization as well as dropout regularization.  **We will be using Tensorflow's implementation of Keras in this workbook (i.e. all Keras classes are impored from `tensorflow.keras.*` packages)**

# %% [markdown]
# ### <font color='firebrick'>NOTE: This notebook can work on Google Colab as well as offline</font>
# * When running this notebook on Google Colab, please set `USE_COLAB=True` in cell below,  else set `USE_COLAB=False`.
# * `USE_COLAB=True` will setup access to Google Drive for the current user's login (assuming she has a Google ID).
#     * Your Google Drive gets mapped to `/content/drive/My Drive`, and your Notebooks get saved to `/content/drive/My Drive/Colab Notebooks/` folder in your Google Drive.
#     * Code will add `/content/drive/My Drive/Colab Notebooks/` folder to `system.path`. Save your custom Python code files `(*.py)` here, so they are automatically added to `system.path` and you can use them in your notebook. *
# * A `MODEL_STATES` global var is created to point to the _correct_ folder where the model's state (i.e. trained weights & biases) is stored to an `.h5` file.
#     * If `USE_COLAB=True`, `MODEL_STATES` maps to `/content/drive/My Drive/Colab Notebooks/model_states` folder on Google Drive.
#     * Else, `MODEL_STATES` maps to `./model_states` folder on your local disk (i.e a sub-folder of folder where notebook is saved)

# %%
# NOTE: set USE_COLAB = True if running on Google Colab, else set to False
USE_COLAB = True

import os

#@see: https://colab.research.google.com/drive/1srw_HFWQ2SMgmWIawucXfusGzrj1_U0q
if USE_COLAB:
    # Load the Drive helper and mount
    from google.colab import drive

    # This will prompt for authorization.
    gdrive_mount_point = '/content/drive/'
    drive.mount(gdrive_mount_point)
    grive_path = os.path.join(gdrive_mount_point, "My Drive/")
    print('Your Google Drive is mounted at ', grive_path)
    colab_notebooks_path = os.path.join(grive_path, "Colab Notebooks/keras")
    
    if os.path.exists(colab_notebooks_path):
        print('You Colab notebooks are available at ', colab_notebooks_path)
    
        # display list of files
        #!ls '/content/drive/My Drive/Colab Notebooks/'

        # append our Google Drive folder to module search 
        # **NOTE:** comment this line out if you are NOT running this notebook on Google Colab
        import sys
        #sys.path.append("/content/drive/My Drive/Colab Notebooks/")
        sys.path.append(colab_notebooks_path)
        print('NOTE: {} is appended to sys.path!'.format(colab_notebooks_path))
        # and test it
        import kr_helper_funcs as kru
        MODEL_SAVE_DIR = os.path.join(colab_notebooks_path, "model_states")
    else:
        raise IOError("Unable to mount Google Drive!")
else:
    MODEL_SAVE_DIR = os.path.join('.','model_states')
    
if not os.path.exists(MODEL_SAVE_DIR):
    os.mkdir(MODEL_SAVE_DIR)
# Out:
# Mounted at /content/drive/
# Your Google Drive is mounted at  /content/drive/My Drive/
# You Colab notebooks are available at  /content/drive/My Drive/Colab Notebooks/keras
# NOTE: /content/drive/My Drive/Colab Notebooks/keras is appended to sys.path!

# %% [markdown]
# ## About the Fashion-MNIST dataset.
# Fashion-MNIST can be used as drop-in replacement for the original MNIST dataset (of 10 categories of handwritten digits). It shares the same image size (28x28 graysacle) and has 60,000 training and 10,000 testing splits. However, unlike the 'simple' number images, the images from this dataset are a bit involved. So, our CNN network architecture will be different.
#
# Per [Zolando](https://github.com/zalandoresearch/fashion-mnist), the Fashion-MNIST dataset was created as a replacement for the MNIST dataset because:
# * **MNIST is too easy**. Convolutional nets can achieve 99.7% on MNIST. Classic machine learning algorithms can also achieve 97% easily.
# * **MNIST is overused**.
# * **MNIST cannot represent modern CV tasks**
# Take a look at the link above and read the various articles it references.
#
# We have 10 categories of output labels - unlike the MNIST dataset, where they were values for numbers, we have distinct types here.
#
# Label Description
# * 0 - T-shirt/top
# * 1 - Trouser
# * 2 - Pullover
# * 3 - Dress
# * 4 - Coat
# * 5 - Sandal
# * 6 - Shirt
# * 7 - Sneaker
# * 8 - Bag
# * 9 - Ankle boot
#
# Let's begin...

# %%
import warnings
warnings.filterwarnings('ignore')

import os,random
# reduce warnings overload from Tensorflow
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
print('Using Tensorflow version ', tf.__version__)
# %matplotlib inline

import kr_helper_funcs as kru

seed = kru.seed_all()
kru.setupModules()

# USING_TF2 = tf.__version__.startswith("2")

# float_formatter = lambda x: '%.4f' % x
# np.set_printoptions(formatter={'float_kind':float_formatter})
# np.set_printoptions(threshold=np.inf, suppress=True, precision=4)

# plt.style.use("seaborn")

# # NOTE: It is important that you set a seed value to get same results in every run.
# # Any number is Ok.
# seed = 123
# random.seed(seed)
# np.random.seed(seed)
# if USING_TF2:
#     tf.random.set_seed(seed)
# else:
#     tf.set_random_seed(seed)

# import warnings
# warnings.filterwarnings('ignore')
# Out:
# Using Tensorflow version  2.8.2

# %% [markdown]
# ### Loading & Preprocessing the Dataset
#
# I am going to load the Fashion-MNIST dataset from the `keras.datasets` library. We'll use the `keras.datasets.fashion_mnist.load_data()` call. The dataset is downloaded the very first time you call it. The function conveniently returns two tuples of data & labels. The images are not normalized - this is something we will handle.

# %%
def load_and_preprocess_data(debug=False):
    
    from tensorflow.keras.datasets.fashion_mnist import load_data
    #from keras.utils import to_categorical

    (X_train, y_train), (X_test, y_test) = load_data()

    if debug:
        print('Before preprocessing:')
        print(' - X_train.shape = {}, y_train.shape = {}'.format(X_train.shape, y_train.shape))
        print(' - X_test.shape = {}, y_test.shape = {}'.format(X_test.shape, y_test.shape))

    # per Andrew Ng's advise in his Structured ML coure (on deeplearning.ai), the test 
    # & cross-validation datasets must come from the same distribution!
    # So, we are going to split X_test/y_test into cross-validation & test datasets.
    # We have 10,000 samples in X_test/y_test - we will assign 8,000 to X_val/y_val & the
    # remaining 2,000 to X_test/y_test (test dataset) AFTER randomly sorting the dataset

    # randomly sort X_test/y_test
    indexes = np.arange(X_test.shape[0])
    for _ in range(5): indexes = np.random.permutation(indexes)  # shuffle 5 times!
    X_test = X_test[indexes]
    y_test = y_test[indexes]
    
    # 'split' into cross-val & test sets (use 6000 records in cross-val set)    
    val_count = 8000
    X_val = X_test[:val_count]
    y_val = y_test[:val_count]
    X_test = X_test[val_count:]
    y_test = y_test[val_count:]

    # keep an non pre-processed copy of X_test/y_test for visualization
    test_images, test_labels = X_test.copy(), y_test.copy()

    # scale the images to between 0-1
    X_train = X_train.astype('float32') / 255.0
    X_val = X_val.astype('float32') / 255.0
    X_test = X_test.astype('float32') / 255.0

    # reshape the image arrays (make 2D arrays instead of 3D arrays)
    X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], X_train.shape[2], 1))
    X_val = np.reshape(X_val, (X_val.shape[0], X_val.shape[1], X_val.shape[2], 1))
    X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], X_test.shape[2], 1))

    if debug:
        print('After preprocessing:')
        print(' - X_train.shape = {}, y_train.shape = {}'.format(X_train.shape, y_train.shape))
        print(' - X_val.shape = {}, y_val.shape = {}'.format(X_val.shape, y_val.shape))
        print(' - X_test.shape = {}, y_test.shape = {}'.format(X_test.shape, y_test.shape))
        print(' - test_images.shape = {}, test_labels.shape = {}'.format(test_images.shape,
            test_labels.shape))

    return (X_train, y_train), (X_val, y_val), (X_test, y_test), (test_images, test_labels)

# %%
def display_sample(sample_images, sample_labels, sample_predictions=None, num_rows=5, num_cols=10,
                   plot_title=None, fig_size=None):
    """ display a random selection of images & corresponding labels, optionally with predictions
        The display is laid out in a grid of num_rows x num_col cells
        If sample_predictions are provided, then each cell's title displays the prediction 
        (if it matches actual) or actual/prediction if there is a mismatch
    """
    import seaborn as sns
    assert sample_images.shape[0] == num_rows * num_cols

    # a dict to help encode/decode the labels
    FASHION_LABELS = {
        0: 'T-shirt/top',
        1: 'Trouser',
        2: 'Pullover',
        3: 'Dress',
        4: 'Coat',
        5: 'Sandal',
        6: 'Shirt',
        7: 'Sneaker',
        8: 'Bag',
        9: 'Ankle boot',
    }

    with sns.axes_style("whitegrid"):
        sns.set_context("notebook", font_scale=1.1)
        sns.set_style({"font.sans-serif": ["Verdana", "Arial", "Calibri", "DejaVu Sans"]})

        f, ax = plt.subplots(num_rows, num_cols, figsize=((14, 9) if fig_size is None else fig_size),
            gridspec_kw={"wspace": 0.02, "hspace": 0.30}, squeeze=True)

        for r in range(num_rows):
            for c in range(num_cols):
                image_index = r * num_cols + c
                ax[r, c].axis("off")
                # show selected image
                ax[r, c].imshow(sample_images[image_index], cmap="Greys", interpolation="nearest")

                if sample_predictions is None:
                    # show the actual labels in the cell title
                    title = ax[r, c].set_title("%s" % FASHION_LABELS[sample_labels[image_index]])
                else:
                    # else check if prediction matches actual value
                    true_label = sample_labels[image_index]
                    pred_label = sample_predictions[image_index]
                    prediction_matches_true = (sample_labels[image_index] == sample_predictions[image_index])
                    if prediction_matches_true:
                        # if actual == prediction, cell title is prediction shown in green font
                        title = FASHION_LABELS[true_label]
                        title_color = 'g'
                    else:
                        # if actual != prediction, cell title is actua/prediction in red font
                        title = '%s/%s' % (FASHION_LABELS[true_label], FASHION_LABELS[pred_label])
                        title_color = 'r'
                    # display cell title
                    title = ax[r, c].set_title(title)
                    plt.setp(title, color=title_color)
        # set plot title, if one specified
        if plot_title is not None:
            f.suptitle(plot_title)

        plt.show()
        plt.close()

# %%
# load & pre-process our dataset
(X_train, y_train), (X_val, y_val), (X_test, y_test), (test_images, test_labels) = \
    load_and_preprocess_data(debug=True)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# 40960/29515 [=========================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# 26435584/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 16384/5148 [===============================================================================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
# 4431872/4422102 [==============================] - 0s 0us/step
# Before preprocessing:
#  - X_train.shape = (60000, 28, 28), y_train.shape = (60000,)
#  - X_test.shape = (10000, 28, 28), y_test.shape = (10000,)
# After preprocessing:
#  - X_train.shape = (60000, 28, 28, 1), y_train.shape = (60000,)
#  - X_val.shape = (8000, 28, 28, 1), y_val.shape = (8000,)
#  - X_test.shape = (2000, 28, 28, 1), y_test.shape = (2000,)
#  - test_images.shape = (2000, 28, 28), test_labels.shape = (2000,)

# %% [markdown]
# Notice the following:
# * **Before Pre-processing**:
#     * We have 60,000 images in the training set & 10,000 images in the test set.
#     * They have shapes of `(60000,28,28)` and `(10000,28,28)` respectively.
# * **After pre-processing**:
#     * The training dataset retains it's 60000 images
#     * The test dataset has been split into a cross-validation set (X_val/y_val) with 8000 samples and a test set (X_test/y_test) with 2000 samples
#     * We have reshaped all the feature (X's) datasets into 3D tensors
#
# Let us randomly select 50 images from the test dataset and see how they look - we will display the images in a 5x10 grid below.

# %%
sample_size = 50
rand_indexes = np.random.randint(0, len(X_test), sample_size)
sample_images = test_images[rand_indexes]
sample_labels = test_labels[rand_indexes]
display_sample(sample_images, sample_labels, plot_title='Sample of %d images' % sample_size)

# %% [markdown]
# ## Keras Model Development
#
# This section includes the following functions:
# * `train_and_evaluate_model()` - trains model on training dataset & evaluates performance on the cross-validation dataset. Saves model to a file name on disk (Google Drive if running in Colab or directory on disk)
# * `do_predictions()` - loads model state from disk and tests it on test dataset and plots predictions on a random sample of non-preprocessed data from the test set.

# %%
# Keras imports (from Tensorflow)
import tensorflow.keras.backend as K
from tensorflow.keras.layers import (Input, Conv2D, MaxPooling2D, Flatten, 
                                     Dense, Dropout, BatchNormalization)
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
import kr_helper_funcs as kru
print('Using Tensorflow\'s implementation of Keras version ', tf.keras.__version__)

K.clear_session()   # start afresh each time!!
# Out:
# Using Tensorflow's implementation of Keras version  2.8.0

# %%
# some globals
IMAGE_HEIGHT, IMAGE_WIDTH, NUM_CHANNELS, NUM_CLASSES = 28, 28, 1, 10

# %%
# cross-train & evaluate model's performance
def train_and_evaluate_model(model, X_train, y_train, X_val, y_val, X_test, y_test,
                             num_epochs=25, batch_size=32, plot_title=None, metric='acccuracy',
                             callbacks=None, model_save_path=None):
    """
    cross train & evaluate model's performance on training, cross-val & test datasets
    @params:
        - X_train/y_train: pre-processed training datasets
        - X_val/y_val: pre-processed cross-validation datasets
        - X_test/y_test: pre-processed testing datasets
        - epochs (optional, default=25) - no of epochs for which training should be done
        - batch_size (optional, default=32) - the batch size to use for mini-batch gradient descent training
        - plot_title (optional, default=None) - plots loss vs epochs and accuracy vs epoch curves if assigned value
            other than None. Uses this assigned value as the plot's title
        - model_save_path (optional, default=None) - the file path to which the Keras model is to be saved to.
    """
    
    # train on X_train/y_train & cross-validate on X_val/y_val
    history = model.fit(X_train, y_train, epochs=num_epochs,
        batch_size=batch_size, validation_data=(X_val, y_val), callbacks=callbacks)
    
    kru.show_plots(history.history, metric=metric, plot_title=plot_title)

    # evaluate metrics
    print("\nEvaluating...", flush=True)
    print('Training data:', flush=True)
    loss, acc = model.evaluate(X_train, y_train, verbose=1)
    print("  Training : loss %.3f - acc %.3f" % (loss, acc))
    print('Cross-validation data:', flush=True)
    loss, acc = model.evaluate(X_val, y_val, verbose=1)
    print("  Cross-val: loss %.3f - acc %.3f" % (loss, acc))
    print('Test data:', flush=True)
    loss, acc = model.evaluate(X_test, y_test, verbose=1)
    print("  Testing  : loss %.3f - acc %.3f" % (loss, acc))
    
    if model_save_path is not None:
        print('Saving model...', flush=True)
        kru.save_model(model, model_save_path)

# %%
def do_predictions(model, X_test, y_test, test_images, test_labels, 
                   plot_title=None, use_tf_keras_impl=False):
    
    def test_model(model, X_test, y_test, test_images, test_labels, plot_title=None):
        print('Evaluating against test data...', flush=True)
        loss, acc = model.evaluate(X_test, y_test)
        print('  - Test data: loss %.3f - acc %.3f' % (loss, acc))

        print('Displaying sample predictions...', flush=True)
        # run predictions
        y_pred = model.predict(X_test)

        # test with 50 random images
        num_images = 50
        rand_indexes = np.random.randint(0, len(X_test), num_images)
        sample_images = test_images[rand_indexes]
        sample_labels = test_labels[rand_indexes]
        sample_predictions = np.argmax(y_pred[rand_indexes], axis=1)

        display_sample(sample_images, sample_labels, sample_predictions,
            num_rows=5, num_cols=10, plot_title=plot_title)
    
    test_model(model, X_test, y_test, test_images, test_labels, plot_title=plot_title)
    del model

# %% [markdown]
# ## Training Model
# In this section, we _cross-train_ various configurations of the model on `(X_train, y_train)` and `(X_val, y_val)` and record the performance. The model we will use is created in the `build_model()` function below. The following _configurations_ are trained and evaluated:
# >Configuration|
# >:---|
# >**Base Model** (no regularization)|
# >**Base Model + L2 Regularization**|
# >**Base Model + Dropout Regularization**|
# >**Base Model + L2 Regularization + Dropout Regularization**|
#
# You can see how the model's performance improves as overfitting reduces.

# %% [markdown]
# ### Training the _base_ model
# Training model without any regularization - no Batch Normalization, no L2 regularization and no Dropout regularization

# %%
def build_model():
    """
    builds the base Keras model, without any regularization
    """
    K.clear_session()
    
    model = Sequential([
        Conv2D(64, kernel_size=(3, 3), activation='relu', padding='same', 
               input_shape=(IMAGE_HEIGHT, IMAGE_WIDTH, NUM_CHANNELS)),
        BatchNormalization(),
        Conv2D(64, kernel_size=(3, 3), activation='relu'),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2, 2)),

        Conv2D(128, kernel_size=(3, 3), activation='relu', padding='same'),
        BatchNormalization(),
        Conv2D(128, kernel_size=(3, 3), activation='relu'),
        BatchNormalization(),        
        MaxPooling2D(pool_size=(2, 2)),
        
        Conv2D(256, kernel_size=(3, 3), activation='relu', padding='same'),
        BatchNormalization(),
        Conv2D(256, kernel_size=(3, 3), activation='relu'),
        BatchNormalization(),    
        MaxPooling2D(pool_size=(2, 2)),   
        
        Flatten(),
        
        Dense(1024, activation='relu'),
        
        Dense(512, activation='relu'),
        
        Dense(NUM_CLASSES, activation='softmax')
    ])
    
    adam = Adam(lr=0.0001, decay=1e-6)
    model.compile(optimizer=adam,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    return model

# %%
# build the base Keras model - no L2 regularization, no droput regularization
model = build_model()
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 28, 64)        640
#
#  batch_normalization (BatchN  (None, 28, 28, 64)       256
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 26, 26, 64)        36928
#
#  batch_normalization_1 (Batc  (None, 26, 26, 64)       256
#  hNormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 64)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 13, 13, 128)       73856
#
#  batch_normalization_2 (Batc  (None, 13, 13, 128)      512
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 11, 11, 128)       147584
#
#  batch_normalization_3 (Batc  (None, 11, 11, 128)      512
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 128)        0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 5, 5, 256)         295168
#
#  batch_normalization_4 (Batc  (None, 5, 5, 256)        1024
#  hNormalization)
#
#  conv2d_5 (Conv2D)           (None, 3, 3, 256)         590080
#
#  batch_normalization_5 (Batc  (None, 3, 3, 256)        1024
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 1, 1, 256)        0
#  2D)
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense (Dense)               (None, 1024)              263168
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  dense_2 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 1,940,938
# Trainable params: 1,939,146
# Non-trainable params: 1,792
# _________________________________________________________________
# None

# %%
plot_title_base = 'Keras Base Model'
train_and_evaluate_model(model, X_train, y_train, X_val, y_val, X_test, y_test, 
                         num_epochs=20, batch_size=64, metric='accuracy',
                         plot_title=plot_title_base) 
#del model
# Out:
# Epoch 1/20
# 938/938 [==============================] - 20s 10ms/step - loss: 0.3954 - accuracy: 0.8580 - val_loss: 0.2976 - val_accuracy: 0.8917
# Epoch 2/20
# 938/938 [==============================] - 9s 9ms/step - loss: 0.2373 - accuracy: 0.9120 - val_loss: 0.2895 - val_accuracy: 0.8949
# Epoch 3/20
# 938/938 [==============================] - 9s 9ms/step - loss: 0.1830 - accuracy: 0.9322 - val_loss: 0.2619 - val_accuracy: 0.9082
# Epoch 4/20
# 938/938 [==============================] - 9s 9ms/step - loss: 0.1431 - accuracy: 0.9471 - val_loss: 0.2647 - val_accuracy: 0.9119
# Epoch 5/20
# 938/938 [==============================] - 9s 9ms/step - loss: 0.1117 - accuracy: 0.9581 - val_loss: 0.3120 - val_accuracy: 0.9054
# Epoch 6/20
# 938/938 [==============================] - 9s 9ms/step - loss: 0.0878 - accuracy: 0.9674 - val_loss: 0.3021 - val_accuracy: 0.9105
# Epoch 7/20
# 938/938 [==============================] - 9s 9ms/step - loss: 0.0730 - accuracy: 0.9731 - val_loss: 0.3236 - val_accuracy: 0.9115
# Epoch 8/20
# 938/938 [==============================] - 9s 9ms/step - loss: 0.0565 - accuracy: 0.9794 - val_loss: 0.4452 - val_accuracy: 0.8905
# Epoch 9/20
# 938/938 [==============================] - 9s 9ms/step - loss: 0.0501 - accuracy: 0.9816 - val_loss: 0.4172 - val_accuracy: 0.9000
# Epoch 10/20
# 938/938 [==============================] - 9s 9ms/step - loss: 0.0427 - accuracy: 0.9840 - val_loss: 0.3912 - val_accuracy: 0.9060
# Epoch 11/20
# 938/938 [==============================] - 9s 9ms/step - loss: 0.0374 - accuracy: 0.9860 - val_loss: 0.3986 - val_accuracy: 0.9109
# Epoch 12/20
# 938/938 [==============================] - 9s 9ms/step - loss: 0.0300 - accuracy: 0.9894 - val_loss: 0.4192 - val_accuracy: 0.9103
# Epoch 13/20
# 938/938 [==============================] - 9s 9ms/step - loss: 0.0335 - accuracy: 0.9875 - val_loss: 0.4054 - val_accuracy: 0.9135
# Epoch 14/20
# 938/938 [==============================] - 9s 9ms/step - loss: 0.0267 - accuracy: 0.9905 - val_loss: 0.4141 - val_accuracy: 0.9094
# Epoch 15/20
# 938/938 [==============================] - 9s 9ms/step - loss: 0.0241 - accuracy: 0.9914 - val_loss: 0.3973 - val_accuracy: 0.9166
# Epoch 16/20
# 938/938 [==============================] - 9s 9ms/step - loss: 0.0259 - accuracy: 0.9908 - val_loss: 0.4457 - val_accuracy: 0.9145
# Epoch 17/20
# 938/938 [==============================] - 9s 9ms/step - loss: 0.0233 - accuracy: 0.9917 - val_loss: 0.4253 - val_accuracy: 0.9165
# Epoch 18/20
# 938/938 [==============================] - 9s 9ms/step - loss: 0.0250 - accuracy: 0.9911 - val_loss: 0.3903 - val_accuracy: 0.9131
# Epoch 19/20
# 938/938 [==============================] - 9s 9ms/step - loss: 0.0197 - accuracy: 0.9930 - val_loss: 0.4246 - val_accuracy: 0.9170
# Epoch 20/20
# 938/938 [==============================] - 9s 9ms/step - loss: 0.0175 - accuracy: 0.9936 - val_loss: 0.4592 - val_accuracy: 0.9158
# Evaluating...
# Training data:
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0212 - accuracy: 0.9922
#   Training : loss 0.021 - acc 0.992
# Cross-validation data:
# 250/250 [==============================] - 1s 3ms/step - loss: 0.4592 - accuracy: 0.9158
#   Cross-val: loss 0.459 - acc 0.916
# Test data:
# 63/63 [==============================] - 0s 4ms/step - loss: 0.4389 - accuracy: 0.9155
#   Testing  : loss 0.439 - acc 0.915

# %%
model_save_path1 = os.path.join(MODEL_SAVE_DIR, 'kr_fashion_cnn_base.h5')
kru.save_model(model, model_save_path1)
del model
# Out:
# Keras model saved to /content/drive/My Drive/Colab Notebooks/keras/model_states/kr_fashion_cnn_base.h5

# %% [markdown]
# #### Observation from training base model:
# See [this Colab Notebook](https://colab.research.google.com/drive/1brSHFOnPQTo0-9vQRC6oslZjAGRbzWuY) for _examples on inserting tables inside markdown cells_
# >Configuration | Training Acc | Cross-val Acc | Test Acc
# >:---|:---:|:---:|:---:|
# >**Base Model**|98-99%|91-92%|91-92%
#
# * Model is overfitting the training data - observe the large (~8%) difference between training & cross-validation accuracies
# * Cross-validation & test accuracies should be almost equal as data is drawn from same population - they are!
# * From the plots you can see that they curves start diverging from around the 5th epoch, suggesting that the model has started overfitting from this epoch itself. You could have stopped training after 5 epochs and got the best results (~95% training accuracy and 90% cross-val accuracy)
#
# Let's run some predictions against the `test` dataset, which the model has not _seen_ during training.
# * I expect to see the same `Test acc` value as seen in the output from training the model

# %%
# load model before predictions
model_save_path1 = os.path.join(MODEL_SAVE_DIR, 'kr_fashion_cnn_base.h5')
model = kru.load_model(model_save_path1)
print(model.summary())
# Out:
# Keras model loaded from /content/drive/My Drive/Colab Notebooks/keras/model_states/kr_fashion_cnn_base.h5
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 28, 64)        640
#
#  batch_normalization (BatchN  (None, 28, 28, 64)       256
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 26, 26, 64)        36928
#
#  batch_normalization_1 (Batc  (None, 26, 26, 64)       256
#  hNormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 64)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 13, 13, 128)       73856
#
#  batch_normalization_2 (Batc  (None, 13, 13, 128)      512
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 11, 11, 128)       147584
#
#  batch_normalization_3 (Batc  (None, 11, 11, 128)      512
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 128)        0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 5, 5, 256)         295168
#
#  batch_normalization_4 (Batc  (None, 5, 5, 256)        1024
#  hNormalization)
#
#  conv2d_5 (Conv2D)           (None, 3, 3, 256)         590080
#
#  batch_normalization_5 (Batc  (None, 3, 3, 256)        1024
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 1, 1, 256)        0
#  2D)
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense (Dense)               (None, 1024)              263168
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  dense_2 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 1,940,938
# Trainable params: 1,939,146
# Non-trainable params: 1,792
# _________________________________________________________________
# None

# %%
do_predictions(model, X_test, y_test, test_images, test_labels, 
               plot_title=plot_title_base, use_tf_keras_impl=True)
# Out:
# Evaluating against test data...
# 63/63 [==============================] - 0s 3ms/step - loss: 0.4389 - accuracy: 0.9155
#   - Test data: loss 0.439 - acc 0.915
# Displaying sample predictions...

# %%
del model

# %% [markdown]
# ### Using L2 Regularization with Base Model
# In this section we will add L2 Regularization to the base model.
# * A L2 regularizer applies penalties on layer parameters (equal to the `L2 Norm` of weights) during optimization.
# * These penalties are _added to the loss function_ that the network _minimizes_. Thus higher weights/parameters tend to get penalized more, so we eventually end up with simpler models that overfit less.
# * L2 Regularization can be added to any Keras `Conv2D` or `Dense` layer by setting the `kernel_regularizer` parameter to an appropriate value. We use `kernel_regularizer = regularizers.l2(XXXX)`.
# * L2 regularization is applied if you set `use_l2_reg=True` in the `build_model()` function. The penalty applied can be changed by passing your value in the `l2_loss_lambda` parameter of `build_model()` function.
# * In an ideal situation, applying L2 regularization should reduce the gap between `training accuracy` and `cross-val accuracy`, without reducing `cross-cal accuracy` (it could increase!).

# %%
def build_model_l2(l2_loss_lambda):
    """
    Builds Keras model with L2 regularization applied to each Conv2D and Dense layers
    @params:
        - l2_loss_lambda: float, controls amount of regularization to apply
             (optional, default=None)
    """
    K.clear_session()
    
    l2 = None if l2_loss_lambda is None else regularizers.l2(l2_loss_lambda)
    if l2 is not None:
        print('Using L2 regularization - l2_loss_lambda = %.4f' % l2_loss_lambda)    
    
    model = Sequential([
        Conv2D(64, kernel_size=(3, 3), activation='relu', padding='same', kernel_regularizer=l2, 
               input_shape=(IMAGE_HEIGHT, IMAGE_WIDTH, NUM_CHANNELS)),
        BatchNormalization(),
        Conv2D(64, kernel_size=(3, 3), activation='relu', kernel_regularizer=l2),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2, 2)),

        Conv2D(128, kernel_size=(3, 3), activation='relu', padding='same', kernel_regularizer=l2),
        BatchNormalization(),
        Conv2D(128, kernel_size=(3, 3), activation='relu', kernel_regularizer=l2),
        BatchNormalization(),        
        MaxPooling2D(pool_size=(2, 2)),
        
        Conv2D(256, kernel_size=(3, 3), activation='relu', padding='same', kernel_regularizer=l2),
        BatchNormalization(),
        Conv2D(256, kernel_size=(3, 3), activation='relu', kernel_regularizer=l2),
        BatchNormalization(),    
        MaxPooling2D(pool_size=(2, 2)),   
        
        Flatten(),
        
        Dense(1024, activation='relu', kernel_regularizer=l2),
        
        Dense(512, activation='relu', kernel_regularizer=l2),
        
        Dense(NUM_CLASSES, activation='softmax')
    ])
    
    adam = Adam(lr=0.0001, decay=1e-6)
    model.compile(optimizer=adam,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    return model

# %%
l2_loss_lambda = 0.010
model = build_model_l2(l2_loss_lambda=l2_loss_lambda)
print(model.summary())
# Out:
# Using L2 regularization - l2_loss_lambda = 0.0100
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 28, 64)        640
#
#  batch_normalization (BatchN  (None, 28, 28, 64)       256
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 26, 26, 64)        36928
#
#  batch_normalization_1 (Batc  (None, 26, 26, 64)       256
#  hNormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 64)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 13, 13, 128)       73856
#
#  batch_normalization_2 (Batc  (None, 13, 13, 128)      512
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 11, 11, 128)       147584
#
#  batch_normalization_3 (Batc  (None, 11, 11, 128)      512
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 128)        0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 5, 5, 256)         295168
#
#  batch_normalization_4 (Batc  (None, 5, 5, 256)        1024
#  hNormalization)
#
#  conv2d_5 (Conv2D)           (None, 3, 3, 256)         590080
#
#  batch_normalization_5 (Batc  (None, 3, 3, 256)        1024
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 1, 1, 256)        0
#  2D)
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense (Dense)               (None, 1024)              263168
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  dense_2 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 1,940,938
# Trainable params: 1,939,146
# Non-trainable params: 1,792
# _________________________________________________________________
# None

# %%
plot_title_l2 = 'Keras Model with L2 regularization = %.5f' % l2_loss_lambda
train_and_evaluate_model(model, X_train, y_train, X_val, y_val, X_test, y_test, 
                         num_epochs=30, batch_size=64, metric='accuracy',
                         plot_title=plot_title_l2)
#del model
# Out:
# Epoch 1/30
# 938/938 [==============================] - 11s 10ms/step - loss: 10.5021 - accuracy: 0.8569 - val_loss: 5.5562 - val_accuracy: 0.8910
# Epoch 2/30
# 938/938 [==============================] - 9s 10ms/step - loss: 3.6229 - accuracy: 0.9078 - val_loss: 2.4240 - val_accuracy: 0.8874
# Epoch 3/30
# 938/938 [==============================] - 9s 10ms/step - loss: 1.7507 - accuracy: 0.9213 - val_loss: 1.3998 - val_accuracy: 0.8945
# Epoch 4/30
# 938/938 [==============================] - 9s 10ms/step - loss: 1.0931 - accuracy: 0.9277 - val_loss: 0.9929 - val_accuracy: 0.9075
# Epoch 5/30
# 938/938 [==============================] - 9s 10ms/step - loss: 0.8002 - accuracy: 0.9363 - val_loss: 0.7906 - val_accuracy: 0.9095
# Epoch 6/30
# 938/938 [==============================] - 9s 10ms/step - loss: 0.6479 - accuracy: 0.9407 - val_loss: 0.6750 - val_accuracy: 0.9141
# Epoch 7/30
# 938/938 [==============================] - 9s 10ms/step - loss: 0.5549 - accuracy: 0.9467 - val_loss: 0.6681 - val_accuracy: 0.8978
# Epoch 8/30
# 938/938 [==============================] - 9s 10ms/step - loss: 0.4975 - accuracy: 0.9490 - val_loss: 0.5679 - val_accuracy: 0.9225
# Epoch 9/30
# 938/938 [==============================] - 9s 10ms/step - loss: 0.4473 - accuracy: 0.9540 - val_loss: 0.5837 - val_accuracy: 0.9043
# Epoch 10/30
# 938/938 [==============================] - 9s 10ms/step - loss: 0.4160 - accuracy: 0.9566 - val_loss: 0.5219 - val_accuracy: 0.9181
# Epoch 11/30
# 938/938 [==============================] - 9s 10ms/step - loss: 0.3896 - accuracy: 0.9607 - val_loss: 0.5058 - val_accuracy: 0.9189
# Epoch 12/30
# 938/938 [==============================] - 9s 10ms/step - loss: 0.3715 - accuracy: 0.9621 - val_loss: 0.4755 - val_accuracy: 0.9262
# Epoch 13/30
# 938/938 [==============================] - 9s 10ms/step - loss: 0.3513 - accuracy: 0.9656 - val_loss: 0.4969 - val_accuracy: 0.9171
# Epoch 14/30
# 938/938 [==============================] - 9s 10ms/step - loss: 0.3361 - accuracy: 0.9683 - val_loss: 0.4808 - val_accuracy: 0.9175
# Epoch 15/30
# 938/938 [==============================] - 9s 10ms/step - loss: 0.3286 - accuracy: 0.9689 - val_loss: 0.4836 - val_accuracy: 0.9209
# Epoch 16/30
# 938/938 [==============================] - 9s 10ms/step - loss: 0.3167 - accuracy: 0.9711 - val_loss: 0.4750 - val_accuracy: 0.9193
# Epoch 17/30
# 938/938 [==============================] - 9s 10ms/step - loss: 0.3081 - accuracy: 0.9723 - val_loss: 0.4761 - val_accuracy: 0.9174
# Epoch 18/30
# 938/938 [==============================] - 9s 10ms/step - loss: 0.3007 - accuracy: 0.9735 - val_loss: 0.5218 - val_accuracy: 0.9134
# Epoch 19/30
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2962 - accuracy: 0.9743 - val_loss: 0.5063 - val_accuracy: 0.9124
# Epoch 20/30
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2871 - accuracy: 0.9763 - val_loss: 0.4637 - val_accuracy: 0.9277
# Epoch 21/30
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2868 - accuracy: 0.9757 - val_loss: 0.4705 - val_accuracy: 0.9201
# Epoch 22/30
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2775 - accuracy: 0.9776 - val_loss: 0.4942 - val_accuracy: 0.9161
# Epoch 23/30
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2778 - accuracy: 0.9773 - val_loss: 0.4791 - val_accuracy: 0.9204
# Epoch 24/30
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2749 - accuracy: 0.9775 - val_loss: 0.5176 - val_accuracy: 0.9124
# Epoch 25/30
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2698 - accuracy: 0.9791 - val_loss: 0.4712 - val_accuracy: 0.9193
# Epoch 26/30
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2666 - accuracy: 0.9790 - val_loss: 0.5059 - val_accuracy: 0.9112
# Epoch 27/30
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2651 - accuracy: 0.9792 - val_loss: 0.5087 - val_accuracy: 0.9166
# Epoch 28/30
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2565 - accuracy: 0.9808 - val_loss: 0.4774 - val_accuracy: 0.9183
# Epoch 29/30
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2588 - accuracy: 0.9802 - val_loss: 0.4762 - val_accuracy: 0.9201
# Epoch 30/30
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2560 - accuracy: 0.9803 - val_loss: 0.4820 - val_accuracy: 0.9166
# Evaluating...
# Training data:
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2556 - accuracy: 0.9809
#   Training : loss 0.256 - acc 0.981
# Cross-validation data:
# 250/250 [==============================] - 1s 3ms/step - loss: 0.4820 - accuracy: 0.9166
#   Cross-val: loss 0.482 - acc 0.917
# Test data:
# 63/63 [==============================] - 0s 4ms/step - loss: 0.4680 - accuracy: 0.9215
#   Testing  : loss 0.468 - acc 0.922

# %%
model_save_path2 = os.path.join(MODEL_SAVE_DIR, 'kr_fashion_cnn_l2.h5')
kru.save_model(model, model_save_path2)
del model
# Out:
# Keras model saved to /content/drive/My Drive/Colab Notebooks/keras/model_states/kr_fashion_cnn_l2.h5

# %% [markdown]
# #### Observations - model with L2 Regularization:
# See [this Colab Notebook](https://colab.research.google.com/drive/1brSHFOnPQTo0-9vQRC6oslZjAGRbzWuY) for _examples on inserting tables inside markdown cells_
# >Configuration | Training Acc | Cross-val Acc | Test Acc
# >:---|:---:|:---:|:---:|
# >**Base Model**|99-100%|91-92%|90-91%
# >**L2 Regularization**|97-98%|92-93%|92-93%
#
# * Overfitting has reduced - difference between train & cross-val accuracies is just ~5% (as compared to 9% in the base model)
# * Cross-validation & test accuracies should be almost equal as data is drawn from same population - they are!
# * Also a critical success factor was that these should not be much lesser than the base model's - they have in fact improved!
# * The plots are also much better - notice that the curves are following each other more closely than before - though they are digressing slightly.

# %%
model_save_path2 = os.path.join(MODEL_SAVE_DIR, 'kr_fashion_cnn_l2.h5')
model = kru.load_model(model_save_path2)
print(model.summary())
# Out:
# Keras model loaded from /content/drive/My Drive/Colab Notebooks/keras/model_states/kr_fashion_cnn_l2.h5
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 28, 64)        640
#
#  batch_normalization (BatchN  (None, 28, 28, 64)       256
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 26, 26, 64)        36928
#
#  batch_normalization_1 (Batc  (None, 26, 26, 64)       256
#  hNormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 64)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 13, 13, 128)       73856
#
#  batch_normalization_2 (Batc  (None, 13, 13, 128)      512
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 11, 11, 128)       147584
#
#  batch_normalization_3 (Batc  (None, 11, 11, 128)      512
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 128)        0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 5, 5, 256)         295168
#
#  batch_normalization_4 (Batc  (None, 5, 5, 256)        1024
#  hNormalization)
#
#  conv2d_5 (Conv2D)           (None, 3, 3, 256)         590080
#
#  batch_normalization_5 (Batc  (None, 3, 3, 256)        1024
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 1, 1, 256)        0
#  2D)
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense (Dense)               (None, 1024)              263168
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  dense_2 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 1,940,938
# Trainable params: 1,939,146
# Non-trainable params: 1,792
# _________________________________________________________________
# None

# %%
do_predictions(model, X_test, y_test, test_images, test_labels, 
               plot_title=plot_title_l2)
# Out:
# Evaluating against test data...
# 63/63 [==============================] - 0s 3ms/step - loss: 0.4680 - accuracy: 0.9215
#   - Test data: loss 0.468 - acc 0.922
# Displaying sample predictions...

# %% [markdown]
# ### Training the model with Dropout Regularization
# Another very effective regularization technique is **Dropout Regularization**. It works by randomly _dropping_ nodes in a layer _during training_ (you specify the percentage of nodes to be dropped). This give the model an 'impression' that a different network is being trained during each epoch, thereby achieving a regularization effect.

# %%
def build_model_do():
    
    model = Sequential([
        Conv2D(64, kernel_size=(3, 3), activation='relu', padding='same', 
               input_shape=(IMAGE_HEIGHT, IMAGE_WIDTH, NUM_CHANNELS)),
        BatchNormalization(),
        Conv2D(64, kernel_size=(3, 3), activation='relu'),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2, 2)),
        Dropout(0.20),

        Conv2D(128, kernel_size=(3, 3), activation='relu', padding='same'),
        BatchNormalization(),
        Conv2D(128, kernel_size=(3, 3), activation='relu'),
        BatchNormalization(),        
        MaxPooling2D(pool_size=(2, 2)),
        Dropout(0.30),        
        
        Conv2D(256, kernel_size=(3, 3), activation='relu', padding='same'),
        BatchNormalization(),
        Conv2D(256, kernel_size=(3, 3), activation='relu'),
        BatchNormalization(),    
        MaxPooling2D(pool_size=(2, 2)),
        Dropout(0.40),        
        
        Flatten(),
        
        Dense(1024, activation='relu'),
        Dropout(0.30),
        
        Dense(512, activation='relu'),
        Dropout(0.20),
        
        Dense(NUM_CLASSES, activation='softmax')
    ])
    
    adam = Adam(lr=0.0001, decay=1e-6)
    model.compile(optimizer=adam,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    return model

# %%
model = build_model_do()
print(model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 28, 28, 64)        640
#
#  batch_normalization_6 (Batc  (None, 28, 28, 64)       256
#  hNormalization)
#
#  conv2d_7 (Conv2D)           (None, 26, 26, 64)        36928
#
#  batch_normalization_7 (Batc  (None, 26, 26, 64)       256
#  hNormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 13, 13, 64)       0
#  2D)
#
#  dropout (Dropout)           (None, 13, 13, 64)        0
#
#  conv2d_8 (Conv2D)           (None, 13, 13, 128)       73856
#
#  batch_normalization_8 (Batc  (None, 13, 13, 128)      512
#  hNormalization)
#
#  conv2d_9 (Conv2D)           (None, 11, 11, 128)       147584
#
#  batch_normalization_9 (Batc  (None, 11, 11, 128)      512
#  hNormalization)
#
#  max_pooling2d_4 (MaxPooling  (None, 5, 5, 128)        0
#  2D)
#
#  dropout_1 (Dropout)         (None, 5, 5, 128)         0
#
#  conv2d_10 (Conv2D)          (None, 5, 5, 256)         295168
#
#  batch_normalization_10 (Bat  (None, 5, 5, 256)        1024
#  chNormalization)
#
#  conv2d_11 (Conv2D)          (None, 3, 3, 256)         590080
#
#  batch_normalization_11 (Bat  (None, 3, 3, 256)        1024
#  chNormalization)
#
#  max_pooling2d_5 (MaxPooling  (None, 1, 1, 256)        0
#  2D)
#
#  dropout_2 (Dropout)         (None, 1, 1, 256)         0
#
#  flatten_1 (Flatten)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 1024)              263168
#
#  dropout_3 (Dropout)         (None, 1024)              0
#
#  dense_4 (Dense)             (None, 512)               524800
#
#  dropout_4 (Dropout)         (None, 512)               0
#
#  dense_5 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 1,940,938
# Trainable params: 1,939,146
# Non-trainable params: 1,792
# _________________________________________________________________
# None

# %%
plot_title_do = 'Keras Model with dropout regularization'
train_and_evaluate_model(model, X_train, y_train, X_val, y_val, X_test, y_test, 
                         num_epochs=30, batch_size=64, metric='accuracy',
                         plot_title=plot_title_do)
# Out:
# Epoch 1/30
# 938/938 [==============================] - 10s 10ms/step - loss: 0.7186 - accuracy: 0.7382 - val_loss: 0.4271 - val_accuracy: 0.8446
# Epoch 2/30
# 938/938 [==============================] - 9s 9ms/step - loss: 0.4231 - accuracy: 0.8463 - val_loss: 0.3556 - val_accuracy: 0.8700
# Epoch 3/30
# 938/938 [==============================] - 9s 9ms/step - loss: 0.3492 - accuracy: 0.8751 - val_loss: 0.3046 - val_accuracy: 0.8860
# Epoch 4/30
# 938/938 [==============================] - 9s 9ms/step - loss: 0.3050 - accuracy: 0.8892 - val_loss: 0.2889 - val_accuracy: 0.8957
# Epoch 5/30
# 938/938 [==============================] - 9s 9ms/step - loss: 0.2770 - accuracy: 0.9000 - val_loss: 0.2595 - val_accuracy: 0.9047
# Epoch 6/30
# 938/938 [==============================] - 9s 9ms/step - loss: 0.2539 - accuracy: 0.9075 - val_loss: 0.2493 - val_accuracy: 0.9090
# Epoch 7/30
# 938/938 [==============================] - 9s 9ms/step - loss: 0.2388 - accuracy: 0.9131 - val_loss: 0.2331 - val_accuracy: 0.9126
# Epoch 8/30
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2239 - accuracy: 0.9183 - val_loss: 0.2385 - val_accuracy: 0.9149
# Epoch 9/30
# 938/938 [==============================] - 9s 9ms/step - loss: 0.2111 - accuracy: 0.9230 - val_loss: 0.2326 - val_accuracy: 0.9175
# Epoch 10/30
# 938/938 [==============================] - 9s 9ms/step - loss: 0.1979 - accuracy: 0.9279 - val_loss: 0.2168 - val_accuracy: 0.9191
# Epoch 11/30
# 938/938 [==============================] - 9s 9ms/step - loss: 0.1875 - accuracy: 0.9313 - val_loss: 0.2081 - val_accuracy: 0.9250
# Epoch 12/30
# 938/938 [==============================] - 9s 9ms/step - loss: 0.1771 - accuracy: 0.9359 - val_loss: 0.2066 - val_accuracy: 0.9304
# Epoch 13/30
# 938/938 [==============================] - 9s 9ms/step - loss: 0.1662 - accuracy: 0.9386 - val_loss: 0.2105 - val_accuracy: 0.9261
# Epoch 14/30
# 938/938 [==============================] - 9s 9ms/step - loss: 0.1612 - accuracy: 0.9403 - val_loss: 0.2222 - val_accuracy: 0.9221
# Epoch 15/30
# 938/938 [==============================] - 9s 9ms/step - loss: 0.1515 - accuracy: 0.9436 - val_loss: 0.2114 - val_accuracy: 0.9279
# Epoch 16/30
# 938/938 [==============================] - 9s 9ms/step - loss: 0.1459 - accuracy: 0.9459 - val_loss: 0.2109 - val_accuracy: 0.9293
# Epoch 17/30
# 938/938 [==============================] - 9s 9ms/step - loss: 0.1388 - accuracy: 0.9485 - val_loss: 0.2022 - val_accuracy: 0.9327
# Epoch 18/30
# 938/938 [==============================] - 9s 9ms/step - loss: 0.1322 - accuracy: 0.9514 - val_loss: 0.2052 - val_accuracy: 0.9299
# Epoch 19/30
# 938/938 [==============================] - 9s 9ms/step - loss: 0.1260 - accuracy: 0.9530 - val_loss: 0.2273 - val_accuracy: 0.9246
# Epoch 20/30
# 938/938 [==============================] - 9s 10ms/step - loss: 0.1184 - accuracy: 0.9550 - val_loss: 0.2091 - val_accuracy: 0.9301
# Epoch 21/30
# 938/938 [==============================] - 9s 10ms/step - loss: 0.1145 - accuracy: 0.9577 - val_loss: 0.2037 - val_accuracy: 0.9373
# Epoch 22/30
# 938/938 [==============================] - 9s 9ms/step - loss: 0.1087 - accuracy: 0.9588 - val_loss: 0.2167 - val_accuracy: 0.9299
# Epoch 23/30
# 938/938 [==============================] - 9s 9ms/step - loss: 0.1057 - accuracy: 0.9604 - val_loss: 0.2084 - val_accuracy: 0.9350
# Epoch 24/30
# 938/938 [==============================] - 9s 9ms/step - loss: 0.1011 - accuracy: 0.9617 - val_loss: 0.2274 - val_accuracy: 0.9315
# Epoch 25/30
# 938/938 [==============================] - 9s 9ms/step - loss: 0.0933 - accuracy: 0.9645 - val_loss: 0.2197 - val_accuracy: 0.9330
# Epoch 26/30
# 938/938 [==============================] - 9s 9ms/step - loss: 0.0944 - accuracy: 0.9644 - val_loss: 0.2244 - val_accuracy: 0.9354
# Epoch 27/30
# 938/938 [==============================] - 9s 9ms/step - loss: 0.0889 - accuracy: 0.9670 - val_loss: 0.2272 - val_accuracy: 0.9355
# Epoch 28/30
# 938/938 [==============================] - 9s 9ms/step - loss: 0.0839 - accuracy: 0.9691 - val_loss: 0.2368 - val_accuracy: 0.9351
# Epoch 29/30
# 938/938 [==============================] - 9s 9ms/step - loss: 0.0810 - accuracy: 0.9696 - val_loss: 0.2355 - val_accuracy: 0.9337
# Epoch 30/30
# 938/938 [==============================] - 9s 9ms/step - loss: 0.0769 - accuracy: 0.9708 - val_loss: 0.2346 - val_accuracy: 0.9356
# Evaluating...
# Training data:
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0323 - accuracy: 0.9891
#   Training : loss 0.032 - acc 0.989
# Cross-validation data:
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2346 - accuracy: 0.9356
#   Cross-val: loss 0.235 - acc 0.936
# Test data:
# 63/63 [==============================] - 0s 3ms/step - loss: 0.1997 - accuracy: 0.9415
#   Testing  : loss 0.200 - acc 0.942

# %%
model_save_path3 = os.path.join(MODEL_SAVE_DIR, 'kr_fashion_cnn_do.h5')
kru.save_model(model, model_save_path3)
del model
# Out:
# Keras model saved to /content/drive/My Drive/Colab Notebooks/keras/model_states/kr_fashion_cnn_do.h5

# %% [markdown]
# #### Observation - model with dropout regularization:
# See [this Colab Notebook](https://colab.research.google.com/drive/1brSHFOnPQTo0-9vQRC6oslZjAGRbzWuY) for _examples on inserting tables inside markdown cells_
# >Configuration | Training Acc | Cross-val Acc | Test Acc
# >:---|:---:|:---:|:---:|
# >**Base Model**|99-100%|91-92%|90-91%
# >**L2 Regularization**|98-99%|92-93%|92-93%
# >**Dropout Reg**|98-99%|93-94%|93-94%
#
# * Dropput regularization appears to be working better for this model - overfitting has reduced further, by another 1%.
# * Cross-validation & test accuracies have also improved by 1% or so.
# * The plots are diverging after 10 epochs.

# %%
model_save_path3 = os.path.join(MODEL_SAVE_DIR, 'kr_fashion_cnn_do.h5')
model = kru.load_model(model_save_path3)
print(model.summary())
# Out:
# Keras model loaded from /content/drive/My Drive/Colab Notebooks/keras/model_states/kr_fashion_cnn_do.h5
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 28, 28, 64)        640
#
#  batch_normalization_6 (Batc  (None, 28, 28, 64)       256
#  hNormalization)
#
#  conv2d_7 (Conv2D)           (None, 26, 26, 64)        36928
#
#  batch_normalization_7 (Batc  (None, 26, 26, 64)       256
#  hNormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 13, 13, 64)       0
#  2D)
#
#  dropout (Dropout)           (None, 13, 13, 64)        0
#
#  conv2d_8 (Conv2D)           (None, 13, 13, 128)       73856
#
#  batch_normalization_8 (Batc  (None, 13, 13, 128)      512
#  hNormalization)
#
#  conv2d_9 (Conv2D)           (None, 11, 11, 128)       147584
#
#  batch_normalization_9 (Batc  (None, 11, 11, 128)      512
#  hNormalization)
#
#  max_pooling2d_4 (MaxPooling  (None, 5, 5, 128)        0
#  2D)
#
#  dropout_1 (Dropout)         (None, 5, 5, 128)         0
#
#  conv2d_10 (Conv2D)          (None, 5, 5, 256)         295168
#
#  batch_normalization_10 (Bat  (None, 5, 5, 256)        1024
#  chNormalization)
#
#  conv2d_11 (Conv2D)          (None, 3, 3, 256)         590080
#
#  batch_normalization_11 (Bat  (None, 3, 3, 256)        1024
#  chNormalization)
#
#  max_pooling2d_5 (MaxPooling  (None, 1, 1, 256)        0
#  2D)
#
#  dropout_2 (Dropout)         (None, 1, 1, 256)         0
#
#  flatten_1 (Flatten)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 1024)              263168
#
#  dropout_3 (Dropout)         (None, 1024)              0
#
#  dense_4 (Dense)             (None, 512)               524800
#
#  dropout_4 (Dropout)         (None, 512)               0
#
#  dense_5 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 1,940,938
# Trainable params: 1,939,146
# Non-trainable params: 1,792
# _________________________________________________________________
# None

# %%
do_predictions(model, X_test, y_test, test_images, test_labels, plot_title=plot_title_do)
# Out:
# Evaluating against test data...
# 63/63 [==============================] - 0s 3ms/step - loss: 0.1997 - accuracy: 0.9415
#   - Test data: loss 0.200 - acc 0.942
# Displaying sample predictions...

# %%
del model

# %% [markdown]
# ### Using Both L2 regularization and Dropout Regularization
# Let's try adding both L2 regularization as well as dropout regularization. We observed that we are getting rather good test accuracy with dropout regularization. So, I'll be applying just a _slight amount_ of L2 regularization. We'll use a very small value for `l2_loss_lambda`.

# %%
def build_model_l2_do(l2_loss_lambda=None):
    
    l2 = None if l2_loss_lambda is None else regularizers.l2(l2_loss_lambda)
    if l2 is not None:
        print('Using L2 regularization - l2_loss_lambda = %.7f' % l2_loss_lambda)
    
    model = Sequential([
        Conv2D(64, kernel_size=(3, 3), activation='relu', padding='same', kernel_regularizer=l2,
               input_shape=(IMAGE_HEIGHT, IMAGE_WIDTH, NUM_CHANNELS)),
        BatchNormalization(),
        Conv2D(64, kernel_size=(3, 3), activation='relu', kernel_regularizer=l2),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2, 2)),
        Dropout(0.20),

        Conv2D(128, kernel_size=(3, 3), activation='relu', padding='same', kernel_regularizer=l2),
        BatchNormalization(),
        Conv2D(128, kernel_size=(3, 3), activation='relu', kernel_regularizer=l2),
        BatchNormalization(),        
        MaxPooling2D(pool_size=(2, 2)),
        Dropout(0.30),        
        
        Conv2D(256, kernel_size=(3, 3), activation='relu', padding='same', kernel_regularizer=l2),
        BatchNormalization(),
        Conv2D(256, kernel_size=(3, 3), activation='relu', kernel_regularizer=l2),
        BatchNormalization(),    
        MaxPooling2D(pool_size=(2, 2)),
        Dropout(0.40),        
        
        Flatten(),
        
        Dense(1024, activation='relu', kernel_regularizer=l2),
        Dropout(0.30),
        
        Dense(512, activation='relu', kernel_regularizer=l2),
        Dropout(0.20),
        
        Dense(NUM_CLASSES, activation='softmax')
    ])
    
    adam = Adam(lr=0.0001, decay=1e-6)
    model.compile(optimizer=adam,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    return model

# %%
l2_loss_lambda_2 = 0.00020
model = build_model_l2_do(l2_loss_lambda=l2_loss_lambda_2)
print(model.summary())
# Out:
# Using L2 regularization - l2_loss_lambda = 0.0002000
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_12 (Conv2D)          (None, 28, 28, 64)        640
#
#  batch_normalization_12 (Bat  (None, 28, 28, 64)       256
#  chNormalization)
#
#  conv2d_13 (Conv2D)          (None, 26, 26, 64)        36928
#
#  batch_normalization_13 (Bat  (None, 26, 26, 64)       256
#  chNormalization)
#
#  max_pooling2d_6 (MaxPooling  (None, 13, 13, 64)       0
#  2D)
#
#  dropout_5 (Dropout)         (None, 13, 13, 64)        0
#
#  conv2d_14 (Conv2D)          (None, 13, 13, 128)       73856
#
#  batch_normalization_14 (Bat  (None, 13, 13, 128)      512
#  chNormalization)
#
#  conv2d_15 (Conv2D)          (None, 11, 11, 128)       147584
#
#  batch_normalization_15 (Bat  (None, 11, 11, 128)      512
#  chNormalization)
#
#  max_pooling2d_7 (MaxPooling  (None, 5, 5, 128)        0
#  2D)
#
#  dropout_6 (Dropout)         (None, 5, 5, 128)         0
#
#  conv2d_16 (Conv2D)          (None, 5, 5, 256)         295168
#
#  batch_normalization_16 (Bat  (None, 5, 5, 256)        1024
#  chNormalization)
#
#  conv2d_17 (Conv2D)          (None, 3, 3, 256)         590080
#
#  batch_normalization_17 (Bat  (None, 3, 3, 256)        1024
#  chNormalization)
#
#  max_pooling2d_8 (MaxPooling  (None, 1, 1, 256)        0
#  2D)
#
#  dropout_7 (Dropout)         (None, 1, 1, 256)         0
#
#  flatten_2 (Flatten)         (None, 256)               0
#
#  dense_6 (Dense)             (None, 1024)              263168
#
#  dropout_8 (Dropout)         (None, 1024)              0
#
#  dense_7 (Dense)             (None, 512)               524800
#
#  dropout_9 (Dropout)         (None, 512)               0
#
#  dense_8 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 1,940,938
# Trainable params: 1,939,146
# Non-trainable params: 1,792
# _________________________________________________________________
# None

# %%
# training for more epochs as we have greater regularization values...
plot_title_do_l2 = 'Keras Model with dropout & l2 regularization = %.7f' % l2_loss_lambda_2
train_and_evaluate_model(model, X_train, y_train, X_val, y_val, X_test, y_test, 
                         num_epochs=50, batch_size=64, metric='accuracy',
                         plot_title=plot_title_do_l2)
# Out:
# Epoch 1/50
# 938/938 [==============================] - 11s 10ms/step - loss: 1.0825 - accuracy: 0.7366 - val_loss: 0.7863 - val_accuracy: 0.8389
# Epoch 2/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.7666 - accuracy: 0.8492 - val_loss: 0.7009 - val_accuracy: 0.8715
# Epoch 3/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.6823 - accuracy: 0.8763 - val_loss: 0.6444 - val_accuracy: 0.8840
# Epoch 4/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.6296 - accuracy: 0.8903 - val_loss: 0.5875 - val_accuracy: 0.9038
# Epoch 5/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.5901 - accuracy: 0.9015 - val_loss: 0.5788 - val_accuracy: 0.9019
# Epoch 6/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.5522 - accuracy: 0.9091 - val_loss: 0.5382 - val_accuracy: 0.9122
# Epoch 7/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.5223 - accuracy: 0.9162 - val_loss: 0.5276 - val_accuracy: 0.9120
# Epoch 8/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.4963 - accuracy: 0.9201 - val_loss: 0.4970 - val_accuracy: 0.9186
# Epoch 9/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.4684 - accuracy: 0.9250 - val_loss: 0.4947 - val_accuracy: 0.9128
# Epoch 10/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.4443 - accuracy: 0.9291 - val_loss: 0.4644 - val_accuracy: 0.9231
# Epoch 11/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.4206 - accuracy: 0.9333 - val_loss: 0.4388 - val_accuracy: 0.9259
# Epoch 12/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.4006 - accuracy: 0.9370 - val_loss: 0.4367 - val_accuracy: 0.9255
# Epoch 13/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.3795 - accuracy: 0.9416 - val_loss: 0.4168 - val_accuracy: 0.9268
# Epoch 14/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.3631 - accuracy: 0.9439 - val_loss: 0.4143 - val_accuracy: 0.9293
# Epoch 15/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.3459 - accuracy: 0.9467 - val_loss: 0.4010 - val_accuracy: 0.9298
# Epoch 16/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.3328 - accuracy: 0.9486 - val_loss: 0.3966 - val_accuracy: 0.9290
# Epoch 17/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.3162 - accuracy: 0.9518 - val_loss: 0.3845 - val_accuracy: 0.9315
# Epoch 18/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.3046 - accuracy: 0.9541 - val_loss: 0.3752 - val_accuracy: 0.9286
# Epoch 19/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2916 - accuracy: 0.9568 - val_loss: 0.3683 - val_accuracy: 0.9333
# Epoch 20/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2794 - accuracy: 0.9586 - val_loss: 0.4023 - val_accuracy: 0.9205
# Epoch 21/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2696 - accuracy: 0.9606 - val_loss: 0.3723 - val_accuracy: 0.9317
# Epoch 22/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2617 - accuracy: 0.9618 - val_loss: 0.3672 - val_accuracy: 0.9335
# Epoch 23/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2518 - accuracy: 0.9632 - val_loss: 0.3638 - val_accuracy: 0.9339
# Epoch 24/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2417 - accuracy: 0.9649 - val_loss: 0.3628 - val_accuracy: 0.9340
# Epoch 25/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2352 - accuracy: 0.9663 - val_loss: 0.3605 - val_accuracy: 0.9348
# Epoch 26/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2273 - accuracy: 0.9690 - val_loss: 0.3610 - val_accuracy: 0.9310
# Epoch 27/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2233 - accuracy: 0.9689 - val_loss: 0.3757 - val_accuracy: 0.9304
# Epoch 28/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2178 - accuracy: 0.9700 - val_loss: 0.3552 - val_accuracy: 0.9356
# Epoch 29/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2098 - accuracy: 0.9725 - val_loss: 0.3553 - val_accuracy: 0.9358
# Epoch 30/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2046 - accuracy: 0.9730 - val_loss: 0.3529 - val_accuracy: 0.9390
# Epoch 31/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2032 - accuracy: 0.9735 - val_loss: 0.3469 - val_accuracy: 0.9380
# Epoch 32/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.1941 - accuracy: 0.9760 - val_loss: 0.3512 - val_accuracy: 0.9388
# Epoch 33/50
# 938/938 [==============================] - 10s 10ms/step - loss: 0.1916 - accuracy: 0.9761 - val_loss: 0.3505 - val_accuracy: 0.9348
# Epoch 34/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.1855 - accuracy: 0.9774 - val_loss: 0.3737 - val_accuracy: 0.9324
# Epoch 35/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.1832 - accuracy: 0.9776 - val_loss: 0.3614 - val_accuracy: 0.9384
# Epoch 36/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.1800 - accuracy: 0.9790 - val_loss: 0.3431 - val_accuracy: 0.9401
# Epoch 37/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.1776 - accuracy: 0.9789 - val_loss: 0.3554 - val_accuracy: 0.9374
# Epoch 38/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.1726 - accuracy: 0.9808 - val_loss: 0.3662 - val_accuracy: 0.9339
# Epoch 39/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.1720 - accuracy: 0.9805 - val_loss: 0.3612 - val_accuracy: 0.9336
# Epoch 40/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.1701 - accuracy: 0.9811 - val_loss: 0.3395 - val_accuracy: 0.9355
# Epoch 41/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.1680 - accuracy: 0.9814 - val_loss: 0.3513 - val_accuracy: 0.9385
# Epoch 42/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.1652 - accuracy: 0.9815 - val_loss: 0.3448 - val_accuracy: 0.9419
# Epoch 43/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.1604 - accuracy: 0.9836 - val_loss: 0.3536 - val_accuracy: 0.9370
# Epoch 44/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.1607 - accuracy: 0.9825 - val_loss: 0.3383 - val_accuracy: 0.9379
# Epoch 45/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.1584 - accuracy: 0.9830 - val_loss: 0.3661 - val_accuracy: 0.9365
# Epoch 46/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.1556 - accuracy: 0.9843 - val_loss: 0.3552 - val_accuracy: 0.9388
# Epoch 47/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.1530 - accuracy: 0.9848 - val_loss: 0.3624 - val_accuracy: 0.9383
# Epoch 48/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.1516 - accuracy: 0.9852 - val_loss: 0.3640 - val_accuracy: 0.9381
# Epoch 49/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.1513 - accuracy: 0.9849 - val_loss: 0.3858 - val_accuracy: 0.9380
# Epoch 50/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.1484 - accuracy: 0.9861 - val_loss: 0.3714 - val_accuracy: 0.9389
# Evaluating...
# Training data:
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1143 - accuracy: 0.9986
#   Training : loss 0.114 - acc 0.999
# Cross-validation data:
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3714 - accuracy: 0.9389
#   Cross-val: loss 0.371 - acc 0.939
# Test data:
# 63/63 [==============================] - 0s 4ms/step - loss: 0.3350 - accuracy: 0.9400
#   Testing  : loss 0.335 - acc 0.940

# %%
model_save_path4 = os.path.join(MODEL_SAVE_DIR, 'kr_fashion_cnn_l2_do.h5')
kru.save_model(model, model_save_path4)
del model
# Out:
# Keras model saved to /content/drive/My Drive/Colab Notebooks/keras/model_states/kr_fashion_cnn_l2_do.h5

# %% [markdown]
# #### Observation - model with both L2 and Dropout regularization.
# See [this Colab Notebook](https://colab.research.google.com/drive/1brSHFOnPQTo0-9vQRC6oslZjAGRbzWuY) for _examples on inserting tables inside markdown cells_
# >Configuration | Training Acc | Cross-val Acc | Test Acc
# >:---|:---:|:---:|:---:|
# >**Base Model**|99-100%|91-92%|90-91%
# >**L2 Regularization**|98-99%|92-93%|92-93%
# >**Dropout Reg**|99-100%|93-94%|93-94%
# >**Both L2 & Dropout Reg**|99-100%|94-95%|94-95%
#
# * This is slightly better than the model with just L2 or just dropout regularization - we are getting a slightly better test accuracy, with the overfitting beging in the same range as before.

# %%
model_save_path4 = os.path.join(MODEL_SAVE_DIR, 'kr_fashion_cnn_l2_do.h5')
model = kru.load_model(model_save_path4)
print(model.summary())
# Out:
# Keras model loaded from /content/drive/My Drive/Colab Notebooks/keras/model_states/kr_fashion_cnn_l2_do.h5
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_12 (Conv2D)          (None, 28, 28, 64)        640
#
#  batch_normalization_12 (Bat  (None, 28, 28, 64)       256
#  chNormalization)
#
#  conv2d_13 (Conv2D)          (None, 26, 26, 64)        36928
#
#  batch_normalization_13 (Bat  (None, 26, 26, 64)       256
#  chNormalization)
#
#  max_pooling2d_6 (MaxPooling  (None, 13, 13, 64)       0
#  2D)
#
#  dropout_5 (Dropout)         (None, 13, 13, 64)        0
#
#  conv2d_14 (Conv2D)          (None, 13, 13, 128)       73856
#
#  batch_normalization_14 (Bat  (None, 13, 13, 128)      512
#  chNormalization)
#
#  conv2d_15 (Conv2D)          (None, 11, 11, 128)       147584
#
#  batch_normalization_15 (Bat  (None, 11, 11, 128)      512
#  chNormalization)
#
#  max_pooling2d_7 (MaxPooling  (None, 5, 5, 128)        0
#  2D)
#
#  dropout_6 (Dropout)         (None, 5, 5, 128)         0
#
#  conv2d_16 (Conv2D)          (None, 5, 5, 256)         295168
#
#  batch_normalization_16 (Bat  (None, 5, 5, 256)        1024
#  chNormalization)
#
#  conv2d_17 (Conv2D)          (None, 3, 3, 256)         590080
#
#  batch_normalization_17 (Bat  (None, 3, 3, 256)        1024
#  chNormalization)
#
#  max_pooling2d_8 (MaxPooling  (None, 1, 1, 256)        0
#  2D)
#
#  dropout_7 (Dropout)         (None, 1, 1, 256)         0
#
#  flatten_2 (Flatten)         (None, 256)               0
#
#  dense_6 (Dense)             (None, 1024)              263168
#
#  dropout_8 (Dropout)         (None, 1024)              0
#
#  dense_7 (Dense)             (None, 512)               524800
#
#  dropout_9 (Dropout)         (None, 512)               0
#
#  dense_8 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 1,940,938
# Trainable params: 1,939,146
# Non-trainable params: 1,792
# _________________________________________________________________
# None

# %%
do_predictions(model, X_test, y_test, test_images, test_labels, plot_title=plot_title_do_l2)
# Out:
# Evaluating against test data...
# 63/63 [==============================] - 0s 3ms/step - loss: 0.3350 - accuracy: 0.9400
#   - Test data: loss 0.335 - acc 0.940
# Displaying sample predictions...

# %%
del model

# %% [markdown]
# ### Using Image Augmentation
#
# One of the main reasons for model overfitting that we are trying to fit a complex model to limited training data. Keras comes to the rescue by providing `Image Augmentation` technique that let's us artifically increase the amount and variety of training data that we feed to the model. This way, the model learns more intricate patterns and is able to generalize better to data it has not seen. In this section we will implement Image Augmentation on the model that used both L2 as well as Dropout Regularization before.

# %%
def train_and_evaluate_model_aug(model, X_train, y_train, X_val, y_val, X_test, y_test,
                                 num_epochs=100, batch_size=32, 
                                 plot_title=None, metric='accuracy',
                                 learning_rate_scheduler=None,
                                 callbacks=None, model_save_name=None):
    from tensorflow.keras.preprocessing.image import ImageDataGenerator

    # NOTE: our datasets have already been scaled 
    train_datagen = ImageDataGenerator( 
        rotation_range=10,        # randomly rotate between 0-rotation_range angle
        width_shift_range=0.2,    # randomly shift horizontally by this much
        height_shift_range=0.2,   # randomly shift vertically by this much
        shear_range=0.2,          # randomly shear by this much
        zoom_range=0.2,           # randomly zoom (80% - 120%)
        horizontal_flip=True,
        fill_mode='nearest'       # fill any pixels lost in xform with nearest
    )

    val_datagen = ImageDataGenerator()
    test_datagen = ImageDataGenerator()

    #train_datagen.fit(X_train)

    # fit the data generator on training data & validate on
    num_train_batches = len(X_train) // batch_size
    num_train_batches += (0 if len(X_train) % batch_size == 0 else 1)     
    num_val_batches = len(X_val) // batch_size
    num_val_batches += (0 if len(X_val) % batch_size == 0 else 1)     
    num_test_batches = len(X_test) // batch_size
    num_test_batches += (0 if len(X_test) % batch_size == 0 else 1)    
    
    train_generator = train_datagen.flow(X_train, y_train, 
                                         batch_size=batch_size,
                                         seed=123)
    val_generator = train_datagen.flow(X_val, y_val, 
                                         batch_size=batch_size,
                                         seed=123)
    test_generator = test_datagen.flow(X_test, y_test, 
                                       batch_size=batch_size,
                                       seed=123)

    callback = None if learning_rate_scheduler is None else [learning_rate_scheduler]

    history = model.fit_generator(train_generator,
                                  steps_per_epoch = num_train_batches, 
                                  epochs = num_epochs,
                                  validation_data = val_generator,
                                  callbacks=callback,
                                  validation_steps = num_val_batches)
    
    kru.show_plots(history.history, metric=metric, plot_title=plot_title)

    # evaluate metrics
    print("\nEvaluating...", flush=True)
    print('Training data:', flush=True)
    loss, acc = model.evaluate_generator(train_generator, 
                                         steps=num_train_batches,
                                         verbose=1)
    print("  Training : loss %.3f - acc %.3f" % (loss, acc))
    print('Cross-validation data:', flush=True)
    loss, acc = model.evaluate_generator(val_generator, 
                                         steps=num_val_batches,
                                         verbose=1)
    print("  Cross-val: loss %.3f - acc %.3f" % (loss, acc))    
    print('Test data:', flush=True)
    loss, acc = model.evaluate_generator(test_generator, 
                                         steps=num_test_batches,
                                         verbose=1)
    print("  Testing  : loss %.3f - acc %.3f" % (loss, acc))
    
    if model_save_name is not None:
        print('Saving model...', flush=True)
        kru.save_model(model, model_save_name, MODEL_SAVE_DIR)

# %%
def build_model_l2_do_aug(l2_loss_lambda=None):

    K.clear_session()
    
    l2 = None if l2_loss_lambda is None else regularizers.l2(l2_loss_lambda)
    if l2 is not None:
        print('Using L2 regularization - l2_loss_lambda = %.7f' % l2_loss_lambda)
    
    model = Sequential([
        Conv2D(64, kernel_size=(3, 3), activation='relu', padding='same', kernel_regularizer=l2,
               input_shape=(IMAGE_HEIGHT, IMAGE_WIDTH, NUM_CHANNELS)),
        BatchNormalization(),
        Conv2D(64, kernel_size=(3, 3), activation='relu', kernel_regularizer=l2),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2, 2)),
        Dropout(0.20),

        Conv2D(128, kernel_size=(3, 3), activation='relu', padding='same', kernel_regularizer=l2),
        BatchNormalization(),
        Conv2D(128, kernel_size=(3, 3), activation='relu', kernel_regularizer=l2),
        BatchNormalization(),        
        MaxPooling2D(pool_size=(2, 2)),
        Dropout(0.30),        
        
        Conv2D(256, kernel_size=(3, 3), activation='relu', padding='same', kernel_regularizer=l2),
        BatchNormalization(),
        Conv2D(256, kernel_size=(3, 3), activation='relu', kernel_regularizer=l2),
        BatchNormalization(),    
        MaxPooling2D(pool_size=(2, 2)),
        Dropout(0.40),        
        
        Flatten(),
        
        Dense(1024, activation='relu', kernel_regularizer=l2),
        Dropout(0.30),
        
        Dense(512, activation='relu', kernel_regularizer=l2),
        Dropout(0.20),
        
        Dense(NUM_CLASSES, activation='softmax')
    ])
    
    adam = Adam(lr=0.0001, decay=1e-6)
    model.compile(optimizer=adam,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    return model

# %%
l2_loss_lambda_2 = 0.00020
model = build_model_l2_do_aug(l2_loss_lambda=l2_loss_lambda_2)
print(model.summary())
# Out:
# Using L2 regularization - l2_loss_lambda = 0.0002000
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 28, 64)        640
#
#  batch_normalization (BatchN  (None, 28, 28, 64)       256
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 26, 26, 64)        36928
#
#  batch_normalization_1 (Batc  (None, 26, 26, 64)       256
#  hNormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 64)       0
#  )
#
#  dropout (Dropout)           (None, 13, 13, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 13, 13, 128)       73856
#
#  batch_normalization_2 (Batc  (None, 13, 13, 128)      512
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 11, 11, 128)       147584
#
#  batch_normalization_3 (Batc  (None, 11, 11, 128)      512
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 128)        0
#  2D)
#
#  dropout_1 (Dropout)         (None, 5, 5, 128)         0
#
#  conv2d_4 (Conv2D)           (None, 5, 5, 256)         295168
#
#  batch_normalization_4 (Batc  (None, 5, 5, 256)        1024
#  hNormalization)
#
#  conv2d_5 (Conv2D)           (None, 3, 3, 256)         590080
#
#  batch_normalization_5 (Batc  (None, 3, 3, 256)        1024
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 1, 1, 256)        0
#  2D)
#
#  dropout_2 (Dropout)         (None, 1, 1, 256)         0
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense (Dense)               (None, 1024)              263168
#
#  dropout_3 (Dropout)         (None, 1024)              0
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  dropout_4 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 1,940,938
# Trainable params: 1,939,146
# Non-trainable params: 1,792
# _________________________________________________________________
# None

# %%
from tensorflow.keras.callbacks import LearningRateScheduler

plot_title_aug = 'Keras Model with image augmentation' 

def schedule_lr(epoch):
    if epoch < 150:
        return 0.001
    else:
        return 0.001 * tf.math.exp(0.1 * (10 - epoch))

lr_scheduler = LearningRateScheduler(schedule_lr)

train_and_evaluate_model_aug(model, X_train, y_train, X_val, y_val, X_test, y_test, 
                             num_epochs=200, batch_size=64, metric='accuracy',
                             #learning_rate_scheduler=lr_scheduler,
                             plot_title=plot_title_aug)
# Out:
# Epoch 1/200
# 938/938 [==============================] - 30s 19ms/step - loss: 1.5116 - accuracy: 0.5755 - val_loss: 1.1052 - val_accuracy: 0.7121
# Epoch 2/200
# 938/938 [==============================] - 17s 18ms/step - loss: 1.0992 - accuracy: 0.7189 - val_loss: 0.9771 - val_accuracy: 0.7625
# Epoch 3/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.9824 - accuracy: 0.7619 - val_loss: 0.8809 - val_accuracy: 0.7931
# Epoch 4/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.9018 - accuracy: 0.7905 - val_loss: 0.8570 - val_accuracy: 0.8079
# Epoch 5/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.8492 - accuracy: 0.8071 - val_loss: 0.7782 - val_accuracy: 0.8260
# Epoch 6/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.7984 - accuracy: 0.8207 - val_loss: 0.7473 - val_accuracy: 0.8365
# Epoch 7/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.7613 - accuracy: 0.8297 - val_loss: 0.7080 - val_accuracy: 0.8534
# Epoch 8/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.7304 - accuracy: 0.8383 - val_loss: 0.7146 - val_accuracy: 0.8430
# Epoch 9/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.7021 - accuracy: 0.8450 - val_loss: 0.6692 - val_accuracy: 0.8511
# Epoch 10/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.6760 - accuracy: 0.8496 - val_loss: 0.6748 - val_accuracy: 0.8481
# Epoch 11/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.6510 - accuracy: 0.8563 - val_loss: 0.6054 - val_accuracy: 0.8701
# Epoch 12/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.6269 - accuracy: 0.8598 - val_loss: 0.5965 - val_accuracy: 0.8654
# Epoch 13/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.6057 - accuracy: 0.8640 - val_loss: 0.5933 - val_accuracy: 0.8649
# Epoch 14/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.5886 - accuracy: 0.8676 - val_loss: 0.5693 - val_accuracy: 0.8684
# Epoch 15/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.5703 - accuracy: 0.8719 - val_loss: 0.5541 - val_accuracy: 0.8749
# Epoch 16/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.5531 - accuracy: 0.8744 - val_loss: 0.5264 - val_accuracy: 0.8816
# Epoch 17/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.5416 - accuracy: 0.8749 - val_loss: 0.5165 - val_accuracy: 0.8839
# Epoch 18/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.5272 - accuracy: 0.8771 - val_loss: 0.5136 - val_accuracy: 0.8799
# Epoch 19/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.5133 - accuracy: 0.8799 - val_loss: 0.5053 - val_accuracy: 0.8750
# Epoch 20/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.5027 - accuracy: 0.8811 - val_loss: 0.4889 - val_accuracy: 0.8884
# Epoch 21/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.4928 - accuracy: 0.8829 - val_loss: 0.4882 - val_accuracy: 0.8779
# Epoch 22/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.4828 - accuracy: 0.8857 - val_loss: 0.4620 - val_accuracy: 0.8929
# Epoch 23/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.4725 - accuracy: 0.8870 - val_loss: 0.4471 - val_accuracy: 0.8945
# Epoch 24/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.4615 - accuracy: 0.8881 - val_loss: 0.5104 - val_accuracy: 0.8636
# Epoch 25/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.4542 - accuracy: 0.8907 - val_loss: 0.4410 - val_accuracy: 0.8964
# Epoch 26/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.4469 - accuracy: 0.8918 - val_loss: 0.4322 - val_accuracy: 0.8969
# Epoch 27/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.4396 - accuracy: 0.8924 - val_loss: 0.4456 - val_accuracy: 0.8892
# Epoch 28/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.4331 - accuracy: 0.8933 - val_loss: 0.4220 - val_accuracy: 0.8957
# Epoch 29/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.4264 - accuracy: 0.8948 - val_loss: 0.4165 - val_accuracy: 0.8994
# Epoch 30/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.4175 - accuracy: 0.8968 - val_loss: 0.4166 - val_accuracy: 0.8966
# Epoch 31/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.4134 - accuracy: 0.8970 - val_loss: 0.3978 - val_accuracy: 0.8996
# Epoch 32/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.4049 - accuracy: 0.8997 - val_loss: 0.3886 - val_accuracy: 0.9040
# Epoch 33/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.4040 - accuracy: 0.8984 - val_loss: 0.4003 - val_accuracy: 0.9007
# Epoch 34/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.4007 - accuracy: 0.8993 - val_loss: 0.3931 - val_accuracy: 0.9001
# Epoch 35/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.3923 - accuracy: 0.9028 - val_loss: 0.3809 - val_accuracy: 0.9046
# Epoch 36/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.3868 - accuracy: 0.9013 - val_loss: 0.4204 - val_accuracy: 0.8894
# Epoch 37/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.3858 - accuracy: 0.9023 - val_loss: 0.3886 - val_accuracy: 0.9003
# Epoch 38/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.3774 - accuracy: 0.9052 - val_loss: 0.3847 - val_accuracy: 0.8992
# Epoch 39/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.3756 - accuracy: 0.9043 - val_loss: 0.3828 - val_accuracy: 0.9000
# Epoch 40/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.3726 - accuracy: 0.9047 - val_loss: 0.3686 - val_accuracy: 0.9078
# Epoch 41/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.3691 - accuracy: 0.9057 - val_loss: 0.3705 - val_accuracy: 0.9057
# Epoch 42/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.3695 - accuracy: 0.9060 - val_loss: 0.3620 - val_accuracy: 0.9034
# Epoch 43/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.3644 - accuracy: 0.9069 - val_loss: 0.3528 - val_accuracy: 0.9082
# Epoch 44/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.3595 - accuracy: 0.9080 - val_loss: 0.3633 - val_accuracy: 0.9054
# Epoch 45/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.3584 - accuracy: 0.9087 - val_loss: 0.3573 - val_accuracy: 0.9078
# Epoch 46/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.3546 - accuracy: 0.9082 - val_loss: 0.3589 - val_accuracy: 0.9053
# Epoch 47/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.3522 - accuracy: 0.9107 - val_loss: 0.3827 - val_accuracy: 0.8981
# Epoch 48/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.3501 - accuracy: 0.9107 - val_loss: 0.3536 - val_accuracy: 0.9062
# Epoch 49/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.3471 - accuracy: 0.9113 - val_loss: 0.3493 - val_accuracy: 0.9122
# Epoch 50/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.3422 - accuracy: 0.9123 - val_loss: 0.3501 - val_accuracy: 0.9097
# Epoch 51/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.3416 - accuracy: 0.9127 - val_loss: 0.3524 - val_accuracy: 0.9094
# Epoch 52/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.3396 - accuracy: 0.9131 - val_loss: 0.3448 - val_accuracy: 0.9090
# Epoch 53/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.3374 - accuracy: 0.9136 - val_loss: 0.3386 - val_accuracy: 0.9126
# Epoch 54/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.3375 - accuracy: 0.9129 - val_loss: 0.3476 - val_accuracy: 0.9090
# Epoch 55/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.3339 - accuracy: 0.9139 - val_loss: 0.3363 - val_accuracy: 0.9128
# Epoch 56/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.3309 - accuracy: 0.9150 - val_loss: 0.3331 - val_accuracy: 0.9150
# Epoch 57/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.3289 - accuracy: 0.9150 - val_loss: 0.3321 - val_accuracy: 0.9139
# Epoch 58/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.3264 - accuracy: 0.9161 - val_loss: 0.3555 - val_accuracy: 0.9049
# Epoch 59/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.3261 - accuracy: 0.9161 - val_loss: 0.4024 - val_accuracy: 0.8850
# Epoch 60/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.3270 - accuracy: 0.9150 - val_loss: 0.3325 - val_accuracy: 0.9147
# Epoch 61/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.3217 - accuracy: 0.9172 - val_loss: 0.3344 - val_accuracy: 0.9128
# Epoch 62/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.3188 - accuracy: 0.9176 - val_loss: 0.3628 - val_accuracy: 0.9026
# Epoch 63/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.3208 - accuracy: 0.9172 - val_loss: 0.3267 - val_accuracy: 0.9155
# Epoch 64/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.3212 - accuracy: 0.9173 - val_loss: 0.3323 - val_accuracy: 0.9131
# Epoch 65/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.3181 - accuracy: 0.9172 - val_loss: 0.3443 - val_accuracy: 0.9084
# Epoch 66/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.3165 - accuracy: 0.9174 - val_loss: 0.3317 - val_accuracy: 0.9133
# Epoch 67/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.3140 - accuracy: 0.9197 - val_loss: 0.3397 - val_accuracy: 0.9121
# Epoch 68/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.3125 - accuracy: 0.9194 - val_loss: 0.3261 - val_accuracy: 0.9170
# Epoch 69/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.3136 - accuracy: 0.9194 - val_loss: 0.3219 - val_accuracy: 0.9145
# Epoch 70/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.3158 - accuracy: 0.9180 - val_loss: 0.3210 - val_accuracy: 0.9144
# Epoch 71/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.3080 - accuracy: 0.9216 - val_loss: 0.3202 - val_accuracy: 0.9169
# Epoch 72/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.3071 - accuracy: 0.9211 - val_loss: 0.3191 - val_accuracy: 0.9161
# Epoch 73/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.3097 - accuracy: 0.9188 - val_loss: 0.3209 - val_accuracy: 0.9166
# Epoch 74/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.3063 - accuracy: 0.9212 - val_loss: 0.3199 - val_accuracy: 0.9145
# Epoch 75/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.3054 - accuracy: 0.9212 - val_loss: 0.3217 - val_accuracy: 0.9144
# Epoch 76/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.3086 - accuracy: 0.9200 - val_loss: 0.3184 - val_accuracy: 0.9155
# Epoch 77/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.3025 - accuracy: 0.9207 - val_loss: 0.3189 - val_accuracy: 0.9154
# Epoch 78/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.3028 - accuracy: 0.9215 - val_loss: 0.3176 - val_accuracy: 0.9175
# Epoch 79/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.3015 - accuracy: 0.9225 - val_loss: 0.3236 - val_accuracy: 0.9135
# Epoch 80/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.3013 - accuracy: 0.9222 - val_loss: 0.3152 - val_accuracy: 0.9162
# Epoch 81/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2984 - accuracy: 0.9223 - val_loss: 0.3304 - val_accuracy: 0.9139
# Epoch 82/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.3001 - accuracy: 0.9215 - val_loss: 0.3188 - val_accuracy: 0.9162
# Epoch 83/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.3001 - accuracy: 0.9204 - val_loss: 0.3261 - val_accuracy: 0.9103
# Epoch 84/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2957 - accuracy: 0.9243 - val_loss: 0.3082 - val_accuracy: 0.9189
# Epoch 85/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2945 - accuracy: 0.9235 - val_loss: 0.3194 - val_accuracy: 0.9150
# Epoch 86/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2962 - accuracy: 0.9233 - val_loss: 0.3082 - val_accuracy: 0.9185
# Epoch 87/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2942 - accuracy: 0.9239 - val_loss: 0.3188 - val_accuracy: 0.9189
# Epoch 88/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2918 - accuracy: 0.9251 - val_loss: 0.3080 - val_accuracy: 0.9162
# Epoch 89/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2969 - accuracy: 0.9244 - val_loss: 0.3062 - val_accuracy: 0.9204
# Epoch 90/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2936 - accuracy: 0.9230 - val_loss: 0.3116 - val_accuracy: 0.9178
# Epoch 91/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2926 - accuracy: 0.9248 - val_loss: 0.3012 - val_accuracy: 0.9224
# Epoch 92/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2945 - accuracy: 0.9240 - val_loss: 0.3203 - val_accuracy: 0.9140
# Epoch 93/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2913 - accuracy: 0.9253 - val_loss: 0.3098 - val_accuracy: 0.9187
# Epoch 94/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2897 - accuracy: 0.9255 - val_loss: 0.3008 - val_accuracy: 0.9206
# Epoch 95/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2885 - accuracy: 0.9253 - val_loss: 0.3204 - val_accuracy: 0.9165
# Epoch 96/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2871 - accuracy: 0.9268 - val_loss: 0.3136 - val_accuracy: 0.9212
# Epoch 97/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2877 - accuracy: 0.9251 - val_loss: 0.3035 - val_accuracy: 0.9206
# Epoch 98/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2873 - accuracy: 0.9258 - val_loss: 0.3026 - val_accuracy: 0.9219
# Epoch 99/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2879 - accuracy: 0.9257 - val_loss: 0.3013 - val_accuracy: 0.9225
# Epoch 100/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2837 - accuracy: 0.9273 - val_loss: 0.3055 - val_accuracy: 0.9200
# Epoch 101/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2839 - accuracy: 0.9275 - val_loss: 0.3167 - val_accuracy: 0.9139
# Epoch 102/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2842 - accuracy: 0.9274 - val_loss: 0.2979 - val_accuracy: 0.9231
# Epoch 103/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2854 - accuracy: 0.9269 - val_loss: 0.3027 - val_accuracy: 0.9201
# Epoch 104/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2801 - accuracy: 0.9281 - val_loss: 0.3065 - val_accuracy: 0.9196
# Epoch 105/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2816 - accuracy: 0.9282 - val_loss: 0.3031 - val_accuracy: 0.9215
# Epoch 106/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2826 - accuracy: 0.9278 - val_loss: 0.3049 - val_accuracy: 0.9236
# Epoch 107/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2809 - accuracy: 0.9280 - val_loss: 0.3048 - val_accuracy: 0.9222
# Epoch 108/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2789 - accuracy: 0.9286 - val_loss: 0.3079 - val_accuracy: 0.9187
# Epoch 109/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2819 - accuracy: 0.9271 - val_loss: 0.2967 - val_accuracy: 0.9227
# Epoch 110/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2797 - accuracy: 0.9286 - val_loss: 0.2913 - val_accuracy: 0.9259
# Epoch 111/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2772 - accuracy: 0.9277 - val_loss: 0.2998 - val_accuracy: 0.9244
# Epoch 112/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2795 - accuracy: 0.9287 - val_loss: 0.2973 - val_accuracy: 0.9219
# Epoch 113/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2776 - accuracy: 0.9289 - val_loss: 0.2938 - val_accuracy: 0.9258
# Epoch 114/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2761 - accuracy: 0.9298 - val_loss: 0.2955 - val_accuracy: 0.9254
# Epoch 115/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2789 - accuracy: 0.9283 - val_loss: 0.3020 - val_accuracy: 0.9186
# Epoch 116/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2746 - accuracy: 0.9302 - val_loss: 0.3125 - val_accuracy: 0.9156
# Epoch 117/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2759 - accuracy: 0.9290 - val_loss: 0.2859 - val_accuracy: 0.9252
# Epoch 118/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2743 - accuracy: 0.9304 - val_loss: 0.2930 - val_accuracy: 0.9233
# Epoch 119/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2746 - accuracy: 0.9287 - val_loss: 0.3019 - val_accuracy: 0.9205
# Epoch 120/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2729 - accuracy: 0.9310 - val_loss: 0.3055 - val_accuracy: 0.9222
# Epoch 121/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2733 - accuracy: 0.9307 - val_loss: 0.3014 - val_accuracy: 0.9221
# Epoch 122/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2733 - accuracy: 0.9301 - val_loss: 0.3013 - val_accuracy: 0.9222
# Epoch 123/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2733 - accuracy: 0.9297 - val_loss: 0.2886 - val_accuracy: 0.9279
# Epoch 124/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2732 - accuracy: 0.9301 - val_loss: 0.2978 - val_accuracy: 0.9225
# Epoch 125/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2717 - accuracy: 0.9305 - val_loss: 0.2978 - val_accuracy: 0.9210
# Epoch 126/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2714 - accuracy: 0.9312 - val_loss: 0.2907 - val_accuracy: 0.9254
# Epoch 127/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2714 - accuracy: 0.9306 - val_loss: 0.2924 - val_accuracy: 0.9252
# Epoch 128/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2683 - accuracy: 0.9306 - val_loss: 0.2896 - val_accuracy: 0.9240
# Epoch 129/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2691 - accuracy: 0.9315 - val_loss: 0.2882 - val_accuracy: 0.9261
# Epoch 130/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2713 - accuracy: 0.9305 - val_loss: 0.2980 - val_accuracy: 0.9210
# Epoch 131/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2665 - accuracy: 0.9316 - val_loss: 0.2862 - val_accuracy: 0.9275
# Epoch 132/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2698 - accuracy: 0.9303 - val_loss: 0.2973 - val_accuracy: 0.9225
# Epoch 133/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2691 - accuracy: 0.9311 - val_loss: 0.2999 - val_accuracy: 0.9244
# Epoch 134/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2682 - accuracy: 0.9323 - val_loss: 0.2958 - val_accuracy: 0.9218
# Epoch 135/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2659 - accuracy: 0.9319 - val_loss: 0.3010 - val_accuracy: 0.9206
# Epoch 136/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2666 - accuracy: 0.9320 - val_loss: 0.3087 - val_accuracy: 0.9180
# Epoch 137/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2689 - accuracy: 0.9324 - val_loss: 0.2969 - val_accuracy: 0.9205
# Epoch 138/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2673 - accuracy: 0.9316 - val_loss: 0.2968 - val_accuracy: 0.9225
# Epoch 139/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2666 - accuracy: 0.9323 - val_loss: 0.3004 - val_accuracy: 0.9227
# Epoch 140/200
# 938/938 [==============================] - 18s 19ms/step - loss: 0.2653 - accuracy: 0.9330 - val_loss: 0.2862 - val_accuracy: 0.9256
# Epoch 141/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2649 - accuracy: 0.9335 - val_loss: 0.3025 - val_accuracy: 0.9201
# Epoch 142/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2653 - accuracy: 0.9324 - val_loss: 0.2969 - val_accuracy: 0.9235
# Epoch 143/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2658 - accuracy: 0.9327 - val_loss: 0.2929 - val_accuracy: 0.9240
# Epoch 144/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2652 - accuracy: 0.9333 - val_loss: 0.2922 - val_accuracy: 0.9244
# Epoch 145/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2625 - accuracy: 0.9333 - val_loss: 0.2919 - val_accuracy: 0.9246
# Epoch 146/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2617 - accuracy: 0.9333 - val_loss: 0.2856 - val_accuracy: 0.9271
# Epoch 147/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2624 - accuracy: 0.9329 - val_loss: 0.2952 - val_accuracy: 0.9260
# Epoch 148/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2641 - accuracy: 0.9327 - val_loss: 0.2986 - val_accuracy: 0.9231
# Epoch 149/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2612 - accuracy: 0.9339 - val_loss: 0.2871 - val_accuracy: 0.9252
# Epoch 150/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2629 - accuracy: 0.9338 - val_loss: 0.2942 - val_accuracy: 0.9236
# Epoch 151/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2669 - accuracy: 0.9317 - val_loss: 0.2878 - val_accuracy: 0.9246
# Epoch 152/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2634 - accuracy: 0.9333 - val_loss: 0.2919 - val_accuracy: 0.9230
# Epoch 153/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2616 - accuracy: 0.9345 - val_loss: 0.2938 - val_accuracy: 0.9256
# Epoch 154/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2605 - accuracy: 0.9346 - val_loss: 0.2954 - val_accuracy: 0.9246
# Epoch 155/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2597 - accuracy: 0.9344 - val_loss: 0.2873 - val_accuracy: 0.9236
# Epoch 156/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2620 - accuracy: 0.9341 - val_loss: 0.2955 - val_accuracy: 0.9194
# Epoch 157/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2585 - accuracy: 0.9349 - val_loss: 0.2894 - val_accuracy: 0.9284
# Epoch 158/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2610 - accuracy: 0.9349 - val_loss: 0.2899 - val_accuracy: 0.9268
# Epoch 159/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2590 - accuracy: 0.9346 - val_loss: 0.2887 - val_accuracy: 0.9262
# Epoch 160/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2594 - accuracy: 0.9337 - val_loss: 0.2923 - val_accuracy: 0.9249
# Epoch 161/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2580 - accuracy: 0.9352 - val_loss: 0.2896 - val_accuracy: 0.9245
# Epoch 162/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2588 - accuracy: 0.9352 - val_loss: 0.3022 - val_accuracy: 0.9220
# Epoch 163/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2594 - accuracy: 0.9344 - val_loss: 0.2840 - val_accuracy: 0.9268
# Epoch 164/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2562 - accuracy: 0.9359 - val_loss: 0.2974 - val_accuracy: 0.9252
# Epoch 165/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2593 - accuracy: 0.9354 - val_loss: 0.3011 - val_accuracy: 0.9236
# Epoch 166/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2584 - accuracy: 0.9340 - val_loss: 0.2887 - val_accuracy: 0.9275
# Epoch 167/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2574 - accuracy: 0.9348 - val_loss: 0.2748 - val_accuracy: 0.9291
# Epoch 168/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2548 - accuracy: 0.9347 - val_loss: 0.2924 - val_accuracy: 0.9296
# Epoch 169/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2554 - accuracy: 0.9352 - val_loss: 0.2853 - val_accuracy: 0.9302
# Epoch 170/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2556 - accuracy: 0.9366 - val_loss: 0.3001 - val_accuracy: 0.9224
# Epoch 171/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2585 - accuracy: 0.9348 - val_loss: 0.2921 - val_accuracy: 0.9233
# Epoch 172/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2547 - accuracy: 0.9365 - val_loss: 0.2854 - val_accuracy: 0.9283
# Epoch 173/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2556 - accuracy: 0.9365 - val_loss: 0.2889 - val_accuracy: 0.9273
# Epoch 174/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2520 - accuracy: 0.9370 - val_loss: 0.2898 - val_accuracy: 0.9264
# Epoch 175/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2534 - accuracy: 0.9373 - val_loss: 0.2908 - val_accuracy: 0.9279
# Epoch 176/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2559 - accuracy: 0.9352 - val_loss: 0.2834 - val_accuracy: 0.9280
# Epoch 177/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2553 - accuracy: 0.9357 - val_loss: 0.2823 - val_accuracy: 0.9249
# Epoch 178/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2541 - accuracy: 0.9362 - val_loss: 0.2877 - val_accuracy: 0.9252
# Epoch 179/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2538 - accuracy: 0.9359 - val_loss: 0.2949 - val_accuracy: 0.9212
# Epoch 180/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2557 - accuracy: 0.9362 - val_loss: 0.2869 - val_accuracy: 0.9261
# Epoch 181/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2488 - accuracy: 0.9387 - val_loss: 0.2904 - val_accuracy: 0.9255
# Epoch 182/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2560 - accuracy: 0.9356 - val_loss: 0.2832 - val_accuracy: 0.9269
# Epoch 183/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2557 - accuracy: 0.9353 - val_loss: 0.2845 - val_accuracy: 0.9281
# Epoch 184/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2540 - accuracy: 0.9369 - val_loss: 0.2851 - val_accuracy: 0.9268
# Epoch 185/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2513 - accuracy: 0.9365 - val_loss: 0.3023 - val_accuracy: 0.9222
# Epoch 186/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2502 - accuracy: 0.9374 - val_loss: 0.2892 - val_accuracy: 0.9259
# Epoch 187/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2503 - accuracy: 0.9385 - val_loss: 0.2856 - val_accuracy: 0.9274
# Epoch 188/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2520 - accuracy: 0.9368 - val_loss: 0.2999 - val_accuracy: 0.9230
# Epoch 189/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2511 - accuracy: 0.9379 - val_loss: 0.2972 - val_accuracy: 0.9230
# Epoch 190/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2516 - accuracy: 0.9372 - val_loss: 0.2862 - val_accuracy: 0.9262
# Epoch 191/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2536 - accuracy: 0.9365 - val_loss: 0.2801 - val_accuracy: 0.9298
# Epoch 192/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2502 - accuracy: 0.9379 - val_loss: 0.2827 - val_accuracy: 0.9254
# Epoch 193/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2503 - accuracy: 0.9384 - val_loss: 0.2848 - val_accuracy: 0.9286
# Epoch 194/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2515 - accuracy: 0.9370 - val_loss: 0.2829 - val_accuracy: 0.9284
# Epoch 195/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2500 - accuracy: 0.9371 - val_loss: 0.2843 - val_accuracy: 0.9301
# Epoch 196/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2493 - accuracy: 0.9386 - val_loss: 0.2887 - val_accuracy: 0.9241
# Epoch 197/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2489 - accuracy: 0.9379 - val_loss: 0.2874 - val_accuracy: 0.9302
# Epoch 198/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2491 - accuracy: 0.9380 - val_loss: 0.2878 - val_accuracy: 0.9255
# Epoch 199/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2484 - accuracy: 0.9377 - val_loss: 0.2791 - val_accuracy: 0.9266
# Epoch 200/200
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2494 - accuracy: 0.9373 - val_loss: 0.2927 - val_accuracy: 0.9252
# Evaluating...
# Training data:
# 938/938 [==============================] - 14s 15ms/step - loss: 0.2100 - accuracy: 0.9512
#   Training : loss 0.210 - acc 0.951
# Cross-validation data:
# 125/125 [==============================] - 2s 15ms/step - loss: 0.2921 - accuracy: 0.9256
#   Cross-val: loss 0.292 - acc 0.926
# Test data:
# 32/32 [==============================] - 0s 6ms/step - loss: 0.2799 - accuracy: 0.9285
#   Testing  : loss 0.280 - acc 0.928

# %%
model_save_path5 = os.path.join(MODEL_SAVE_DIR, 'kr_fashion_cnn_l2_do_aug.h5')
kru.save_model(model, model_save_path5)
del model
# Out:
# Keras model saved to /content/drive/My Drive/Colab Notebooks/keras/model_states/kr_fashion_cnn_l2_do_aug.h5

# %% [markdown]
# #### Observation - model with Image Augmentation
# See [this Colab Notebook](https://colab.research.google.com/drive/1brSHFOnPQTo0-9vQRC6oslZjAGRbzWuY) for _examples on inserting tables inside markdown cells_
# >Configuration | Training Acc | Cross-val Acc | Test Acc
# >:---|:---:|:---:|:---:|
# >**Base Model**|99-100%|91-92%|90-91%
# >**L2 Regularization**|98-99%|92-93%|92-93%
# >**Dropout Reg**|99-100%|93-94%|93-94%
# >**Both L2 & Dropout Reg**|99-100%|93-94%|94-95%
# >**With Image Aug**|95-96%|92-93%|92-93%
#
# * Notice that the cross-validation plots are tracking the training plots (both loss and accuracy) - there is some divergence, but very little.
# * We observe a 3% difference between training and cross-validation accuracy, which indicates that we have some overfitting, but not much.
# * Extrapolating the loss and accuracy curves, it appears that they will diverge further if we train for more epochs. At the 100th epoch divergence is ~2%

# %%
model_save_path5 = os.path.join(MODEL_SAVE_DIR, 'kr_fashion_cnn_l2_do_aug.h5')
model = kru.load_model(model_save_path5)
print(model.summary())
# Out:
# Keras model loaded from /content/drive/My Drive/Colab Notebooks/keras/model_states/kr_fashion_cnn_l2_do_aug.h5
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 28, 64)        640
#
#  batch_normalization (BatchN  (None, 28, 28, 64)       256
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 26, 26, 64)        36928
#
#  batch_normalization_1 (Batc  (None, 26, 26, 64)       256
#  hNormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 64)       0
#  )
#
#  dropout (Dropout)           (None, 13, 13, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 13, 13, 128)       73856
#
#  batch_normalization_2 (Batc  (None, 13, 13, 128)      512
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 11, 11, 128)       147584
#
#  batch_normalization_3 (Batc  (None, 11, 11, 128)      512
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 128)        0
#  2D)
#
#  dropout_1 (Dropout)         (None, 5, 5, 128)         0
#
#  conv2d_4 (Conv2D)           (None, 5, 5, 256)         295168
#
#  batch_normalization_4 (Batc  (None, 5, 5, 256)        1024
#  hNormalization)
#
#  conv2d_5 (Conv2D)           (None, 3, 3, 256)         590080
#
#  batch_normalization_5 (Batc  (None, 3, 3, 256)        1024
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 1, 1, 256)        0
#  2D)
#
#  dropout_2 (Dropout)         (None, 1, 1, 256)         0
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense (Dense)               (None, 1024)              263168
#
#  dropout_3 (Dropout)         (None, 1024)              0
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  dropout_4 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 1,940,938
# Trainable params: 1,939,146
# Non-trainable params: 1,792
# _________________________________________________________________
# None

# %%
do_predictions(model, X_test, y_test, test_images, test_labels, 
               plot_title=plot_title_aug)
# Out:
# Evaluating against test data...
# 63/63 [==============================] - 0s 3ms/step - loss: 0.2799 - accuracy: 0.9285
#   - Test data: loss 0.280 - acc 0.928
# Displaying sample predictions...

# %%
del model

# %% [markdown]
# ## Summary
# * In this workbook we created a CNN with Keras to classify the Fashion-MNIST dataset.
# * Since the images are more complex than our digits images, the model was more complex than the MNIST Digits model
# * The base model overfit the training data significantly (~8%), but we were able to reduce this by implementing regularization techniques like L2 regularization and dropout regularization
# * Finally, we implemented Image Augmentation, where we observed that our cross-validation curves tracked the training curves for most of the iterations. We did not see significant degredation of performance viz-a-viz the regularized versions without Image Augmentation.
# # <center> - - END - - </center>
