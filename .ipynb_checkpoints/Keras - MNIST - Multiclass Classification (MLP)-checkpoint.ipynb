# %% [markdown]
# # MNIST - Multiclass Classification with Keras
# <br/><center><img src="files/images/keras-tensorflow-logo.jpg" height="100"></center>
#
# This notebook illustrates how to build a Multilayer Perceptron (MLP) network with Keras to classify hand-written digits from the MNIST dataset. We'll be using Keras from Tensorflow 2.0 implementation.

# %%
# imports
import warnings
warnings.filterwarnings('ignore')

import os, sys, random, math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# tweaks for libraries
np.set_printoptions(precision=6, linewidth=1024, suppress=True)
plt.style.use('seaborn')
sns.set_style('darkgrid')
sns.set_context('notebook',font_scale=1.10)

# Keras imports
import tensorflow as tf
print(f"Using Tensorflow version: {tf.__version__}")
USING_TF2 = tf.__version__.startswith("2")

SEED = 123
random.seed(SEED)
np.random.seed(SEED)
if USING_TF2:
    tf.random.set_seed(SEED)
else:
    tf.compat.v1.set_random_seed(SEED)
# Out:
# Using Tensorflow version: 2.0.0

# %% [markdown]
# ## Loading Data
# * We'll load the data from `tf.keras.datasets.mnist` package.
# * Next, we'll split the _test_ dataset into _cross-validation_ and _test_ sets in `80:20` ratio.
# * We'll normalize the images, so that all values are between `0.0` and `1.0`
#
# Why split the `test` dataset and not the `train` dataset?
# * Prof. Andrew Ng advises, in his `Structured ML` course on Coursera, that the cross-val and test datasets should be drawn from the same population! Hence we split the `test` dataset.

# %%
def load_data(debug=False):
    from tensorflow.keras.datasets.mnist import load_data
    
    (X_train, y_train), (X_test, y_test) = load_data()
    if debug:
        print(f"After loading...")
        print(f"   - X_train.shape = {X_train.shape}, y_train.shape = {y_train.shape}, " +
              f"X_test.shape = {X_test.shape}, y_train.shape = {y_train.shape}")
        
    # shuffle the datasets, to get rid of any implicit sorting
    indexes = np.random.permutation(np.arange(X_train.shape[0]))
    X_train, y_train = X_train[indexes], y_train[indexes]
    indexes = np.random.permutation(np.arange(X_test.shape[0]))
    X_test, y_test = X_test[indexes], y_test[indexes]
    
    # split X_test into cross-val & test sets in 80:20 
    num_recs = int(0.80 * X_test.shape[0])
    X_val, y_val = X_test[:num_recs], y_test[:num_recs]
    X_test, y_test = X_test[num_recs:], y_test[num_recs:]
    if debug:
        print(f"After splitting...")
        print(f"   - X_train.shape = {X_train.shape}, y_train.shape = {y_train.shape}, " +
              f"X_val.shape = {X_val.shape}, y_val.shape = {y_val.shape}, " +
              f"X_test.shape = {X_test.shape}, y_test.shape = {y_test.shape}")
    
    # normalize the images
    X_train = X_train.astype('float32') / 255.0
    X_val = X_val.astype('float32') / 255.0
    X_test = X_test.astype('float32') / 255.0
    
    # resize images
    X_train = np.expand_dims(X_train, axis=3)
    X_val = np.expand_dims(X_val, axis=3)
    X_test = np.expand_dims(X_test, axis=3)
    
    if debug:
        print(f"Before returning...")
        print(f"   - X_train.shape = {X_train.shape}, y_train.shape = {y_train.shape}, " +
              f"X_val.shape = {X_val.shape}, y_val.shape = {y_val.shape}, " +
              f"X_test.shape = {X_test.shape}, y_test.shape = {y_test.shape}")
    
    return (X_train, y_train), (X_val, y_val), (X_test, y_test)

# %%
def display_sample(sample_images, sample_labels, sample_predictions=None, num_rows=5, num_cols=10,
                   plot_title=None, fig_size=None):
    
    import seaborn as sns
  
    """ display a random selection of images & corresponding labels, optionally with predictions
        The display is laid out in a grid of num_rows x num_col cells
        If sample_predictions are provided, then each cell's title displays the prediction (if it matches
        actual)
        or actual/prediction if there is a mismatch
    """
    assert sample_images.shape[0] == num_rows * num_cols

    with sns.axes_style("whitegrid"):
        sns.set_context("notebook", font_scale=1.1)
        sns.set_style({"font.sans-serif": ["Verdana", "Arial", "Calibri", "DejaVu Sans"]})

        f, ax = plt.subplots(num_rows, num_cols, figsize=((14, 10) if fig_size is None else fig_size),
            gridspec_kw={"wspace": 0.05, "hspace": 0.35}, squeeze=True)

        for r in range(num_rows):
            for c in range(num_cols):
                image_index = r * num_cols + c
                ax[r, c].axis("off")
                # show selected image
                sample_image = np.squeeze(sample_images[image_index], axis=2)
                ax[r, c].imshow(sample_image, cmap="Greys", interpolation='nearest')

                if sample_predictions is None:
                    # show the actual labels in the cell title
                    title = ax[r, c].set_title("%d" % sample_labels[image_index])
                else:
                    # else check if prediction matches actual value
                    true_label = sample_labels[image_index]
                    pred_label = sample_predictions[image_index]
                    prediction_matches_true = (true_label == pred_label)
                    if prediction_matches_true:
                        # if actual == prediction, cell title is prediction shown in green font
                        title = "%d" % true_label
                        title_color = 'g'
                    else:
                        # if actual != prediction, cell title is actua/prediction in red font
                        title = '%d/%d' % (true_label, pred_label)
                        title_color = 'r'
                    # display cell title
                    title = ax[r, c].set_title(title)
                    plt.setp(title, color=title_color)
        # set plot title, if one specified
        if plot_title is not None:
            f.suptitle(plot_title)

        plt.show()
        plt.close()

# %%
(X_train, y_train), (X_val, y_val), (X_test, y_test) = \
    load_data(debug=True)
# Out:
# After loading...
#    - X_train.shape = (60000, 28, 28), y_train.shape = (60000,), X_test.shape = (10000, 28, 28), y_train.shape = (60000,)
# After splitting...
#    - X_train.shape = (60000, 28, 28), y_train.shape = (60000,), X_val.shape = (8000, 28, 28), y_val.shape = (8000,), X_test.shape = (2000, 28, 28), y_test.shape = (2000,)
# Before returning...
#    - X_train.shape = (60000, 28, 28, 1), y_train.shape = (60000,), X_val.shape = (8000, 28, 28, 1), y_val.shape = (8000,), X_test.shape = (2000, 28, 28, 1), y_test.shape = (2000,)

# %%
# display a sample of the loaded dataset
SAMPLE_SIZE = 50
rand_indexes = np.random.randint(0, X_test.shape[0], SAMPLE_SIZE)
sample_images = X_test[rand_indexes]
sample_labels = y_test[rand_indexes]
display_sample(sample_images, sample_labels, plot_title=f'Sample of {SAMPLE_SIZE} images')

# %% [markdown]
# ## Building The Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
import kr_helper_funcs as kru

# %%
# global hyper parameters
IMAGE_HEIGHT, IMAGE_WIDTH, NUM_CHANNELS, NUM_CLASSES = 28, 28, 1, 10
NUM_EPOCHS, BATCH_SIZE, LEARNING_RATE, L2_REG = 25, 64, 0.001, 0.0005
MODEL_SAVE_DIR = os.path.join('.', 'model_states')

# %% [markdown]
# We'll build the model using the Keras `Sequential` API, with 3 `Dense` layers. We'll use the `Adam` optimizer to optimize a `sparse_categorical_crossentropy` losss. We will also track `sparse_categorical_accuracy` metric apart from the `loss` metric.
#
# **NOTE**:
# * We **did not** `one-hot-encode` the class labels. Hence we use the `sparse_categorical_crossentropy` loss metric.
# * Since our images are all 3D shaped `(28, 28, 1)`, hence we have flattened the images using the `Flatten` layer before feeding to the `Dense` layers.

# %%
def build_model(l2_loss_lambda = None):
    l2_reg = None if l2_loss_lambda is None else l2(l2_loss_lambda)

    model = Sequential([
        Flatten(input_shape=(IMAGE_HEIGHT, IMAGE_WIDTH, NUM_CHANNELS)),
        Dense(128, activation='relu', kernel_regularizer=l2_reg),
        Dropout(0.10),
        Dense(64, activation='relu', kernel_regularizer=l2_reg),
        Dropout(0.10),
        Dense(NUM_CLASSES, activation='softmax')
    ])
    opt = Adam(learning_rate=LEARNING_RATE)
    model.compile(optimizer=opt, loss='sparse_categorical_crossentropy', 
                  metrics=['sparse_categorical_accuracy'])
    return model

# %%
model = build_model(l2_loss_lambda=L2_REG)
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               100480
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                650
# =================================================================
# Total params: 109,386
# Trainable params: 109,386
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
hist = model.fit(X_train, y_train, epochs=NUM_EPOCHS, batch_size=BATCH_SIZE,
                 validation_data=(X_val, y_val))
# Out:
# Train on 60000 samples, validate on 8000 samples
# Epoch 1/25
# 60000/60000 [==============================] - 7s 117us/sample - loss: 0.4431 - sparse_categorical_accuracy: 0.9034 - val_loss: 0.2588 - val_sparse_categorical_accuracy: 0.9555
# Epoch 2/25
# 60000/60000 [==============================] - 5s 84us/sample - loss: 0.2558 - sparse_categorical_accuracy: 0.9553 - val_loss: 0.1998 - val_sparse_categorical_accuracy: 0.9697
# Epoch 3/25
# 60000/60000 [==============================] - 5s 82us/sample - loss: 0.2168 - sparse_categorical_accuracy: 0.9633 - val_loss: 0.1810 - val_sparse_categorical_accuracy: 0.9729
# Epoch 4/25
# 60000/60000 [==============================] - 5s 85us/sample - loss: 0.1961 - sparse_categorical_accuracy: 0.9663 - val_loss: 0.1668 - val_sparse_categorical_accuracy: 0.9760
# Epoch 5/25
# 60000/60000 [==============================] - 5s 88us/sample - loss: 0.1827 - sparse_categorical_accuracy: 0.9697 - val_loss: 0.1654 - val_sparse_categorical_accuracy: 0.9761
# Epoch 6/25
# 60000/60000 [==============================] - 5s 89us/sample - loss: 0.1738 - sparse_categorical_accuracy: 0.9721 - val_loss: 0.1525 - val_sparse_categorical_accuracy: 0.9760
# Epoch 7/25
# 60000/60000 [==============================] - 5s 84us/sample - loss: 0.1670 - sparse_categorical_accuracy: 0.9727 - val_loss: 0.1572 - val_sparse_categorical_accuracy: 0.9758
# Epoch 8/25
# 60000/60000 [==============================] - 5s 87us/sample - loss: 0.1626 - sparse_categorical_accuracy: 0.9739 - val_loss: 0.1476 - val_sparse_categorical_accuracy: 0.9776
# Epoch 9/25
# 60000/60000 [==============================] - 5s 85us/sample - loss: 0.1533 - sparse_categorical_accuracy: 0.9764 - val_loss: 0.1439 - val_sparse_categorical_accuracy: 0.9791
# Epoch 10/25
# 60000/60000 [==============================] - 5s 87us/sample - loss: 0.1539 - sparse_categorical_accuracy: 0.9754 - val_loss: 0.1395 - val_sparse_categorical_accuracy: 0.9790
# Epoch 11/25
# 60000/60000 [==============================] - 5s 86us/sample - loss: 0.1517 - sparse_categorical_accuracy: 0.9755 - val_loss: 0.1423 - val_sparse_categorical_accuracy: 0.9784
# Epoch 12/25
# 60000/60000 [==============================] - 5s 88us/sample - loss: 0.1479 - sparse_categorical_accuracy: 0.9766 - val_loss: 0.1475 - val_sparse_categorical_accuracy: 0.9771
# Epoch 13/25
# 60000/60000 [==============================] - 5s 88us/sample - loss: 0.1443 - sparse_categorical_accuracy: 0.9771 - val_loss: 0.1424 - val_sparse_categorical_accuracy: 0.9784
# Epoch 14/25
# 60000/60000 [==============================] - 5s 87us/sample - loss: 0.1439 - sparse_categorical_accuracy: 0.9775 - val_loss: 0.1470 - val_sparse_categorical_accuracy: 0.9758
# Epoch 15/25
# 60000/60000 [==============================] - 5s 85us/sample - loss: 0.1423 - sparse_categorical_accuracy: 0.9778 - val_loss: 0.1405 - val_sparse_categorical_accuracy: 0.9775
# Epoch 16/25
# 60000/60000 [==============================] - 5s 89us/sample - loss: 0.1406 - sparse_categorical_accuracy: 0.9777 - val_loss: 0.1382 - val_sparse_categorical_accuracy: 0.9799
# Epoch 17/25
# 60000/60000 [==============================] - 6s 92us/sample - loss: 0.1417 - sparse_categorical_accuracy: 0.9777 - val_loss: 0.1449 - val_sparse_categorical_accuracy: 0.9758
# Epoch 18/25
# 60000/60000 [==============================] - 6s 93us/sample - loss: 0.1403 - sparse_categorical_accuracy: 0.9779 - val_loss: 0.1393 - val_sparse_categorical_accuracy: 0.9787
# Epoch 19/25
# 60000/60000 [==============================] - 5s 91us/sample - loss: 0.1371 - sparse_categorical_accuracy: 0.9783 - val_loss: 0.1387 - val_sparse_categorical_accuracy: 0.9800
# Epoch 20/25
# 60000/60000 [==============================] - 6s 94us/sample - loss: 0.1390 - sparse_categorical_accuracy: 0.9778 - val_loss: 0.1366 - val_sparse_categorical_accuracy: 0.9801
# Epoch 21/25
# 60000/60000 [==============================] - 5s 91us/sample - loss: 0.1371 - sparse_categorical_accuracy: 0.9785 - val_loss: 0.1413 - val_sparse_categorical_accuracy: 0.9781
# Epoch 22/25
# 60000/60000 [==============================] - 6s 94us/sample - loss: 0.1350 - sparse_categorical_accuracy: 0.9793 - val_loss: 0.1333 - val_sparse_categorical_accuracy: 0.9812
# Epoch 23/25
# 60000/60000 [==============================] - 5s 87us/sample - loss: 0.1350 - sparse_categorical_accuracy: 0.9790 - val_loss: 0.1350 - val_sparse_categorical_accuracy: 0.9803
# Epoch 24/25
# 60000/60000 [==============================] - 6s 93us/sample - loss: 0.1358 - sparse_categorical_accuracy: 0.9790 - val_loss: 0.1363 - val_sparse_categorical_accuracy: 0.9787
# Epoch 25/25
# 60000/60000 [==============================] - 5s 87us/sample - loss: 0.1354 - sparse_categorical_accuracy: 0.9790 - val_loss: 0.1312 - val_sparse_categorical_accuracy: 0.9794

# %%
kru.show_plots(hist.history, metric='sparse_categorical_accuracy')

# %%
loss, acc = model.evaluate(X_train, y_train, verbose=0)
print(f"Training data -> loss: {loss:.4f}, acc: {acc:.4f}")
loss, acc = model.evaluate(X_val, y_val, verbose=0)
print(f"Cross-val data -> loss: {loss:.4f}, acc: {acc:.4f}")
loss, acc = model.evaluate(X_test, y_test, verbose=0)
print(f"Test data -> loss: {loss:.4f}, acc: {acc:.4f}")
# Out:
# Training data -> loss: 0.1032, acc: 0.9906
# Cross-val data -> loss: 0.1312, acc: 0.9794
# Test data -> loss: 0.1331, acc: 0.9820

# %% [markdown]
# **Observations:**
#
# >Model | Training Acc | Cross-Val Acc | Testing Acc
# >:---|:---:|:---:|:---:|
# >**Keras Model**|99.06%|97.94%|98.20%|
#
# * The model gives us a test accuracy of `~98%`, which is pretty good!
# * There is `~2%` difference between `training accuracy` (`99.06%`) and `Cross-val accuracy` (`97.94%`), which implies that there is _some_ overfitting of the model to training data.
#     * Perhaps a greater value for `L2_REG` or `Dropout` percentage should improve this (i.e. reduce the difference)
# * There is not much difference between `Cross-val accuracy` (`97.94%`) and `Test accuracy` (`98.20%`) - this should be the case as both cross-val and test datasets came from the same *population*

# %%
MODEL_NAME = 'kr_mnist_mlp'
MODEL_PATH = os.path.join(MODEL_SAVE_DIR, MODEL_NAME)

# %%
kru.save_model(model, MODEL_PATH)
del model
# Out:
# Saved model to file ./model_states/kr_mnist_mlp.h5

# %% [markdown]
# ## Running Predictions

# %%
MODEL_NAME = 'kr_mnist_mlp'
MODEL_PATH = os.path.join(MODEL_SAVE_DIR, MODEL_NAME)

# %%
model = kru.load_model(MODEL_PATH)
print(model.summary())
# Out:
# Loaded Keras model from ./model_states/kr_mnist_mlp.h5
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               100480
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                650
# =================================================================
# Total params: 109,386
# Trainable params: 109,386
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
y_pred = np.argmax(model.predict(X_test), axis=1)
y_pred[:20]
# Out:
# array([4, 5, 4, 0, 7, 1, 9, 9, 1, 3, 0, 0, 5, 1, 9, 4, 1, 6, 7, 5])

# %%
y_test[:20]
# Out:
# array([4, 5, 4, 0, 7, 1, 9, 9, 1, 3, 0, 0, 5, 1, 9, 4, 1, 6, 7, 3], dtype=uint8)

# %%
print(f"We got {(y_pred == y_test).sum()}/{y_test.shape[0]} correct!")
# Out:
# We got 1964/2000 correct!

# %%
# display predictions
SAMPLE_SIZE = 60
rand_indexes = np.random.randint(0, X_test.shape[0], SAMPLE_SIZE)
sample_images = X_test[rand_indexes]
sample_labels = y_test[rand_indexes]
sample_predictions = y_pred[rand_indexes]
display_sample(sample_images, sample_labels, sample_predictions, num_rows=5, num_cols=12,
               plot_title=f'Sample predictions for {SAMPLE_SIZE} images')

# %% [markdown]
# # <center> -- END -- </center>
